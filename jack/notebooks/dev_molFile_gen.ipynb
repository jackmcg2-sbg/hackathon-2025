# %% [markdown]
# # Developing Methods to Generate/Retrieve mol Files to provide a Full Chemical Specification of all Molecules in the openTECR dataset

# %%
import os
import pandas as pd
import re
import subprocess
from rdkit import Chem
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
# import the necessary csv files - to extract info for further processing
mapped_ids = '/home/jackmcgoldrick/openTECR/results/openTECR_mapped_metabolites.csv'

initial_data = '/home/jackmcgoldrick/openTECR/data/TECRDB.csv'

# %%
# convert mapped data to a df
mapped_mets = pd.read_csv(mapped_ids)

# %%
mapped_mets.head()
# Out:
#   KEGG_ID                                              CHEBI  \
# 0  C04752  CHEBI:16629; CHEBI:57841; CHEBI_11612; CHEBI_1...
# 1  C00407  CHEBI:17191; CHEBI:32604; CHEBI:32605; CHEBI:3...
# 2  C01545  CHEBI:17935; CHEBI_11268; CHEBI_17935; CHEBI_2...
# 3  C00417  CHEBI:16383; CHEBI:32805; CHEBI_10482; CHEBI_1...
# 4  C00197  CHEBI:17050; CHEBI:17794; CHEBI:57998; CHEBI:5...
#
#                                      BiGG Metabolite  \
# 0                             bigg.metabolite:2mahmp
# 1                             bigg.metabolite:ile__L
# 2                              bigg.metabolite:octal
# 3  bigg.metabolite:HC00342; bigg.metabolite:acon;...
# 4                                bigg.metabolite:3pg
#
#                                                 HMDB  \
# 0                                   hmdb:HMDB0304168
# 1  hmdb:HMDB0000172; hmdb:HMDB00172; hmdb:HMDB003...
# 2                   hmdb:HMDB0001140; hmdb:HMDB01140
# 3  hmdb:HMDB0000072; hmdb:HMDB0000461; hmdb:HMDB0...
# 4  hmdb:HMDB0000807; hmdb:HMDB0060180; hmdb:HMDB0...
#
#                                              MetaCyc  \
# 0  metacyc.compound:AMINO-HYDROXYMETHYL-METHYLPYR...
# 1  metacyc.compound:CPD-12149; metacyc.compound:C...
# 2                           metacyc.compound:CPD-371
# 3                     metacyc.compound:CIS-ACONITATE
# 4                               metacyc.compound:G3P
#
#                                              SABIORK  \
# 0            sabiork.compound:1832; newSearch?q=1832
# 1  sabiork.compound:23116; sabiork.compound:70; n...
# 2            sabiork.compound:5652; newSearch?q=5652
# 3            sabiork.compound:2043; newSearch?q=2043
# 4  sabiork.compound:21216; sabiork.compound:30; n...
#
#                                                 SEED          MNX  \
# 0       seed.compound:cpd02894; M_cpd02894; cpd02894  MNXM1101289
# 1  seed.compound:cpd00322; seed.compound:cpd15139...  MNXM1366448
# 2  seed.compound:cpd01088; seed.compound:cpd15619...     MNXM2705
# 3       seed.compound:cpd00331; M_cpd00331; cpd00331  MNXM1092518
# 4  seed.compound:cpd00169; seed.compound:cpd30741...   MNXM727604
#
#                                            VMH  \
# 0                                          NaN
# 1                          vmhmetabolite:ile_L
# 2                                          NaN
# 3  vmhmetabolite:HC00342; vmhmetabolite:acon_C
# 4                            vmhmetabolite:3pg
#
#                                             Reactome  \
# 0                                                NaN
# 1  reactome:R-ALL-113537; reactome:R-ALL-30102; r...
# 2                                                NaN
# 3                                                NaN
# 4       reactome:R-ALL-29728; reactome:R-ALL-6799493
#
#                     SwissLipids  \
# 0                           NaN
# 1                           NaN
# 2  SLM:000389951; SLM:000389951
# 3                           NaN
# 4  SLM:000489958; SLM:000489958
#
#                                             EnviPath  \
# 0                                                NaN
# 1                                                NaN
# 2  9dcb30dc-d751-4434-8d9c-68b4f5453145; 8421e286...
# 3               643481e5-a35b-477e-8665-70f4dca66baa
# 4               47064115-384f-43ee-b9e2-5e9d7aed5217
#
#                                    Extra Identifiers
# 0  2mahmp; M_2mahmp; M_C04752; compound?id=AMINO-...
# 1  M_ile__L; ile-L; ile__L; kegg.drug:D00065; C16...
# 2  M_octal; octal; 9dcb30dc-d751-4434-8d9c-68b4f5...
# 3  HC00342; M_HC00342; M_acon; M_acon_C; acon; ac...
# 4  3pg; M_3pg; 47064115-384f-43ee-b9e2-5e9d7aed52...

# %%
def mnx_inchi(mnx_id):
    """
    Function to query the ReconX Knowledge Graph for the InChI string
    associated with a given MNX identifier.
    """

    # Define the SPARQL endpoint
    sparql_endpoint = "http://sbg:7200/repositories/ReconXKG"
    sparql = SPARQLWrapper(sparql_endpoint)
    sparql.setReturnFormat(JSON)

    # SPARQL query with dynamic MNX ID
    query = f"""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX mnx: <https://rdf.metanetx.org/schema/>
    PREFIX chem: <https://rdf.metanetx.org/chem/>

    SELECT ?mnx ?inchi
    WHERE {{
        # ?mnx a mnx:CHEM ;
             mnx:inchi ?inchi ;
             rdfs:label ?mnx_identifier .

        FILTER(REGEX(STR(?mnx_identifier), "^{mnx_id}$"))
    }}
    """

    # Set the query
    sparql.setQuery(query)

    # Execute and process the results
    try:
        results = sparql.query().convert()
        bindings = results["results"]["bindings"]

        # Extract and return InChI strings
        inchi_list = [entry["inchi"]["value"] for entry in bindings]
        return inchi_list

    except Exception as e:
        print(f"An error occurred: {e}")
        return []

# %%
mnx_id = "MNXM2705"
inchi_strings = mnx_inchi(mnx_id)
print(f"InChI strings for {mnx_id}: {inchi_strings}")
# Out:
# InChI strings for MNXM2705: ['InChI=1S/C8H16O/c1-2-3-4-5-6-7-8-9/h8H,2-7H2,1H3']

# %%
# Add a new column for InChIs
mapped_mets["InChI"] = mapped_mets["MNX"].apply(lambda mnx_id: "; ".join(mnx_inchi(mnx_id)))

print(mapped_mets)
# Out:
#     KEGG_ID                                              CHEBI  \
# 0    C04752  CHEBI:16629; CHEBI:57841; CHEBI_11612; CHEBI_1...
# 1    C00407  CHEBI:17191; CHEBI:32604; CHEBI:32605; CHEBI:3...
# 2    C01545  CHEBI:17935; CHEBI_11268; CHEBI_17935; CHEBI_2...
# 3    C00417  CHEBI:16383; CHEBI:32805; CHEBI_10482; CHEBI_1...
# 4    C00197  CHEBI:17050; CHEBI:17794; CHEBI:57998; CHEBI:5...
# ..      ...                                                ...
# 598  C04105  CHEBI:18080; CHEBI:48068; CHEBI:58372; CHEBI:5...
# 599  C02588  CHEBI:17616; CHEBI_12784; CHEBI_17616; CHEBI_2...
# 600  C03127                                                NaN
# 601  C00041  CHEBI_57972; CHEBI:16977; CHEBI:229589; CHEBI:...
# 602  C00137  CHEBI:17268; CHEBI_10601; CHEBI_12826; CHEBI_1...
#
#                                        BiGG Metabolite  \
# 0                               bigg.metabolite:2mahmp
# 1                               bigg.metabolite:ile__L
# 2                                bigg.metabolite:octal
# 3    bigg.metabolite:HC00342; bigg.metabolite:acon;...
# 4                                  bigg.metabolite:3pg
# ..                                                 ...
# 598                                                NaN
# 599                                                NaN
# 600                                                NaN
# 601                             bigg.metabolite:ala__L
# 602                              bigg.metabolite:inost
#
#                                                   HMDB  \
# 0                                     hmdb:HMDB0304168
# 1    hmdb:HMDB0000172; hmdb:HMDB00172; hmdb:HMDB003...
# 2                     hmdb:HMDB0001140; hmdb:HMDB01140
# 3    hmdb:HMDB0000072; hmdb:HMDB0000461; hmdb:HMDB0...
# 4    hmdb:HMDB0000807; hmdb:HMDB0060180; hmdb:HMDB0...
# ..                                                 ...
# 598                                                NaN
# 599                   hmdb:HMDB0003648; hmdb:HMDB03648
# 600                                                NaN
# 601                   hmdb:HMDB0000161; hmdb:HMDB00161
# 602  hmdb:HMDB0000211; hmdb:HMDB0002256; hmdb:HMDB0...
#
#                                                MetaCyc  \
# 0    metacyc.compound:AMINO-HYDROXYMETHYL-METHYLPYR...
# 1    metacyc.compound:CPD-12149; metacyc.compound:C...
# 2                             metacyc.compound:CPD-371
# 3                       metacyc.compound:CIS-ACONITATE
# 4                                 metacyc.compound:G3P
# ..                                                 ...
# 598  metacyc.compound:CPD-15124; metacyc.compound:C...
# 599                         metacyc.compound:CHOCOLA_A
# 600                                                NaN
# 601                   metacyc.compound:L-ALPHA-ALANINE
# 602                                                NaN
#
#                                                SABIORK  \
# 0              sabiork.compound:1832; newSearch?q=1832
# 1    sabiork.compound:23116; sabiork.compound:70; n...
# 2              sabiork.compound:5652; newSearch?q=5652
# 3              sabiork.compound:2043; newSearch?q=2043
# 4    sabiork.compound:21216; sabiork.compound:30; n...
# ..                                                 ...
# 598            sabiork.compound:7082; newSearch?q=7082
# 599            sabiork.compound:2455; newSearch?q=2455
# 600                                                NaN
# 601                sabiork.compound:67; newSearch?q=67
# 602                                                NaN
#
#                                                   SEED          MNX  \
# 0         seed.compound:cpd02894; M_cpd02894; cpd02894  MNXM1101289
# 1    seed.compound:cpd00322; seed.compound:cpd15139...  MNXM1366448
# 2    seed.compound:cpd01088; seed.compound:cpd15619...     MNXM2705
# 3         seed.compound:cpd00331; M_cpd00331; cpd00331  MNXM1092518
# 4    seed.compound:cpd00169; seed.compound:cpd30741...   MNXM727604
# ..                                                 ...          ...
# 598  seed.compound:cpd02536; seed.compound:cpd19162...   MNXM726703
# 599       seed.compound:cpd01691; M_cpd01691; cpd01691  MNXM1137721
# 600                                                NaN   MNXM741223
# 601       seed.compound:cpd00035; M_cpd00035; cpd00035  MNXM1105732
# 602       seed.compound:cpd00121; M_cpd00121; cpd00121  MNXM1365428
#
#                                              VMH  \
# 0                                            NaN
# 1                            vmhmetabolite:ile_L
# 2                                            NaN
# 3    vmhmetabolite:HC00342; vmhmetabolite:acon_C
# 4                              vmhmetabolite:3pg
# ..                                           ...
# 598    vmhmetabolite:25d5o2a; vmhmetabolite:mucl
# 599                                          NaN
# 600                                          NaN
# 601                          vmhmetabolite:ala_L
# 602                          vmhmetabolite:inost
#
#                                               Reactome  \
# 0                                                  NaN
# 1    reactome:R-ALL-113537; reactome:R-ALL-30102; r...
# 2                                                  NaN
# 3                                                  NaN
# 4         reactome:R-ALL-29728; reactome:R-ALL-6799493
# ..                                                 ...
# 598                                                NaN
# 599  reactome:R-ALL-2534404; reactome:R-ALL-2534405...
# 600                                                NaN
# 601  reactome:R-ALL-29432; reactome:R-ALL-352036; r...
# 602       reactome:R-ALL-426910; reactome:R-ALL-429130
#
#                       SwissLipids  \
# 0                             NaN
# 1                             NaN
# 2    SLM:000389951; SLM:000389951
# 3                             NaN
# 4    SLM:000489958; SLM:000489958
# ..                            ...
# 598                           NaN
# 599  SLM:000000509; SLM:000000509
# 600                           NaN
# 601                           NaN
# 602                           NaN
#
#                                               EnviPath  \
# 0                                                  NaN
# 1                                                  NaN
# 2    9dcb30dc-d751-4434-8d9c-68b4f5453145; 8421e286...
# 3                 643481e5-a35b-477e-8665-70f4dca66baa
# 4                 47064115-384f-43ee-b9e2-5e9d7aed5217
# ..                                                 ...
# 598                                                NaN
# 599                                                NaN
# 600                                                NaN
# 601               1aad160f-1c5e-48e0-9473-6305321b31ed
# 602                                                NaN
#
#                                      Extra Identifiers  \
# 0    2mahmp; M_2mahmp; M_C04752; compound?id=AMINO-...
# 1    M_ile__L; ile-L; ile__L; kegg.drug:D00065; C16...
# 2    M_octal; octal; 9dcb30dc-d751-4434-8d9c-68b4f5...
# 3    HC00342; M_HC00342; M_acon; M_acon_C; acon; ac...
# 4    3pg; M_3pg; 47064115-384f-43ee-b9e2-5e9d7aed52...
# ..                                                 ...
# 598  C14610; M_C04105; M_C14610; compound?id=CPD-15...
# 599  kegg.drug:D00164; M_C02588; D00164; M_D00164; ...
# 600                                           M_C03127
# 601  M_ala__L; ala-L; ala__L; 1aad160f-1c5e-48e0-94...
# 602  M_inost; inost; kegg.drug:D08079; M_C00137; D0...
#
#                                                  InChI
# 0    InChI=1S/C6H11N3O7P2/c1-4-8-2-5(6(7)9-4)3-15-1...
# 1    InChI=1S/C6H13NO2/c1-3-4(2)5(7)6(8)9/h4-5H,3,7...
# 2     InChI=1S/C8H16O/c1-2-3-4-5-6-7-8-9/h8H,2-7H2,1H3
# 3    InChI=1S/C6H6O6/c7-4(8)1-3(6(11)12)2-5(9)10/h1...
# 4    InChI=1S/C3H7O7P/c4-2(3(5)6)1-10-11(7,8)9/h2,4...
# ..                                                 ...
# 598  InChI=1S/C6H6O4/c7-5(8)3-4-1-2-6(9)10-4/h1-2,4...
# 599  InChI=1S/C36H60O2/c1-7-8-9-10-11-12-13-14-15-1...
# 600
# 601  InChI=1S/C3H7NO2/c1-2(4)3(5)6/h2H,4H2,1H3,(H,5...
# 602  InChI=1S/C6H12O6/c7-1-2(8)4(10)6(12)5(11)3(1)9...
#
# [603 rows x 14 columns]

# %%
# save to csv file
mapped_mets.to_csv("/home/jackmcgoldrick/openTECR/results/mapping_openTECR_inchis.csv")

# %% [markdown]
# ## Retrieving KEGG related mol Files

# %% [markdown]
# This section will attempt to access the set of mol Files, from KEGG, related to the identifiers above. Later, a structure check will be implemented (likely with the inchi1 software) to ensure the molecule structures have fully defined stereochemistry, and to ensure other structural identifiers are consistent. Of course, some molecules, such as macrocycles will cause more difficulties than other linear/branched molecules.

# %% [markdown]
# **HOLD OFF ON THIS FOR NOW, CANNOT ACCESS 2013 API CURRENTLY VIA WEBARCHIVES.ORG**

# %% [markdown]
# ## Generating molFiles directly from retrieved InChIKeys

# %%
# call the csv file containing inchis - error with above code, will regnerate later
csv_path = "/home/jackmcgoldrick/openTECR/results/structural_mapping/mapping_openTECR_inchis.csv"

# %%
# generate the df
mapped_inchis = pd.read_csv(csv_path)

# %%
mapped_inchis.head()
# Out:
#    Unnamed: 0 KEGG_ID                                              CHEBI  \
# 0           0  C04752  CHEBI:16629; CHEBI:57841; CHEBI_11612; CHEBI_1...
# 1           1  C00407  CHEBI:17191; CHEBI:32604; CHEBI:32605; CHEBI:3...
# 2           2  C01545  CHEBI:17935; CHEBI_11268; CHEBI_17935; CHEBI_2...
# 3           3  C00417  CHEBI:16383; CHEBI:32805; CHEBI_10482; CHEBI_1...
# 4           4  C00197  CHEBI:17050; CHEBI:17794; CHEBI:57998; CHEBI:5...
#
#                                      BiGG Metabolite  \
# 0                             bigg.metabolite:2mahmp
# 1                             bigg.metabolite:ile__L
# 2                              bigg.metabolite:octal
# 3  bigg.metabolite:HC00342; bigg.metabolite:acon;...
# 4                                bigg.metabolite:3pg
#
#                                                 HMDB  \
# 0                                   hmdb:HMDB0304168
# 1  hmdb:HMDB0000172; hmdb:HMDB00172; hmdb:HMDB003...
# 2                   hmdb:HMDB0001140; hmdb:HMDB01140
# 3  hmdb:HMDB0000072; hmdb:HMDB0000461; hmdb:HMDB0...
# 4  hmdb:HMDB0000807; hmdb:HMDB0060180; hmdb:HMDB0...
#
#                                              MetaCyc  \
# 0  metacyc.compound:AMINO-HYDROXYMETHYL-METHYLPYR...
# 1  metacyc.compound:CPD-12149; metacyc.compound:C...
# 2                           metacyc.compound:CPD-371
# 3                     metacyc.compound:CIS-ACONITATE
# 4                               metacyc.compound:G3P
#
#                                              SABIORK  \
# 0            sabiork.compound:1832; newSearch?q=1832
# 1  sabiork.compound:23116; sabiork.compound:70; n...
# 2            sabiork.compound:5652; newSearch?q=5652
# 3            sabiork.compound:2043; newSearch?q=2043
# 4  sabiork.compound:21216; sabiork.compound:30; n...
#
#                                                 SEED          MNX  \
# 0       seed.compound:cpd02894; M_cpd02894; cpd02894  MNXM1101289
# 1  seed.compound:cpd00322; seed.compound:cpd15139...  MNXM1366448
# 2  seed.compound:cpd01088; seed.compound:cpd15619...     MNXM2705
# 3       seed.compound:cpd00331; M_cpd00331; cpd00331  MNXM1092518
# 4  seed.compound:cpd00169; seed.compound:cpd30741...   MNXM727604
#
#                                            VMH  \
# 0                                          NaN
# 1                          vmhmetabolite:ile_L
# 2                                          NaN
# 3  vmhmetabolite:HC00342; vmhmetabolite:acon_C
# 4                            vmhmetabolite:3pg
#
#                                             Reactome  \
# 0                                                NaN
# 1  reactome:R-ALL-113537; reactome:R-ALL-30102; r...
# 2                                                NaN
# 3                                                NaN
# 4       reactome:R-ALL-29728; reactome:R-ALL-6799493
#
#                     SwissLipids  \
# 0                           NaN
# 1                           NaN
# 2  SLM:000389951; SLM:000389951
# 3                           NaN
# 4  SLM:000489958; SLM:000489958
#
#                                             EnviPath  \
# 0                                                NaN
# 1                                                NaN
# 2  9dcb30dc-d751-4434-8d9c-68b4f5453145; 8421e286...
# 3               643481e5-a35b-477e-8665-70f4dca66baa
# 4               47064115-384f-43ee-b9e2-5e9d7aed5217
#
#                                    Extra Identifiers  \
# 0  2mahmp; M_2mahmp; M_C04752; compound?id=AMINO-...
# 1  M_ile__L; ile-L; ile__L; kegg.drug:D00065; C16...
# 2  M_octal; octal; 9dcb30dc-d751-4434-8d9c-68b4f5...
# 3  HC00342; M_HC00342; M_acon; M_acon_C; acon; ac...
# 4  3pg; M_3pg; 47064115-384f-43ee-b9e2-5e9d7aed52...
#
#                                                InChI
# 0  InChI=1S/C6H11N3O7P2/c1-4-8-2-5(6(7)9-4)3-15-1...
# 1  InChI=1S/C6H13NO2/c1-3-4(2)5(7)6(8)9/h4-5H,3,7...
# 2   InChI=1S/C8H16O/c1-2-3-4-5-6-7-8-9/h8H,2-7H2,1H3
# 3  InChI=1S/C6H6O6/c7-4(8)1-3(6(11)12)2-5(9)10/h1...
# 4  InChI=1S/C3H7O7P/c4-2(3(5)6)1-10-11(7,8)9/h2,4...

# %%
# first determine how many metabolites had an inchi returned
inchi_absent = mapped_inchis[mapped_inchis["InChI"].isnull()]

# %%
inchi_absent
# Out:
#      Unnamed: 0 KEGG_ID                                              CHEBI  \
# 13           13  C01653  CHEBI:29183; CHEBI_10694; CHEBI_15191; CHEBI_2...
# 20           20  C01277              CHEBI_58178; CHEBI:58178; CHEBI_61083
# 33           33  C00787  CHEBI:29182; CHEBI_10692; CHEBI_15189; CHEBI_2...
# 45           45  C01636  CHEBI:29171; CHEBI_10673; CHEBI_15167; CHEBI_2...
# 46           46  C04618                                                NaN
# 51           51  C02988                                                NaN
# 54           54  C00126                                                NaN
# 63           63  C03875                                                NaN
# 111         111  C06020  CHEBI:27833; CHEBI_25292; CHEBI_27833; CHEBI_6870
# 147         147  C04246                         CHEBI:132146; CHEBI_132146
# 157         157  C01643  CHEBI:29178; CHEBI_10682; CHEBI_15178; CHEBI_2...
# 166         166  C02839                                                NaN
# 168         168  C01644  CHEBI:29174; CHEBI_10683; CHEBI_15179; CHEBI_2...
# 177         177  C00125                                                NaN
# 223         223  C02163                                                NaN
# 228         228  C01931                                                NaN
# 238         238  C03939                                                NaN
# 264         264  C02992                                                NaN
# 316         316  C01003                                                NaN
# 327         327  C00229                                                NaN
# 392         392  C02553                                                NaN
# 400         400  C04688                                                NaN
# 431         431  C00342                                                NaN
# 433         433  C01281                                                NaN
# 437         437  C01194                                                NaN
# 444         444  C06567                                                NaN
# 476         476  C06021  CHEBI:33913; CHEBI_23391; CHEBI_33913; CHEBI_3890
# 484         484  C03688  CHEBI:13850; CHEBI:16139; CHEBI_13845; CHEBI_1...
# 492         492  C01648  CHEBI:29184; CHEBI_10687; CHEBI_15183; CHEBI_2...
# 508         508  C01650  CHEBI:29179; CHEBI_10689; CHEBI_15186; CHEBI_2...
# 525         525  C01651  CHEBI:29180; CHEBI_10690; CHEBI_15187; CHEBI_2...
# 543         543  C01646  CHEBI:29185; CHEBI_10685; CHEBI_15181; CHEBI_2...
# 546         546  C01209  CHEBI:17330; CHEBI:58107; CHEBI_14566; CHEBI_1...
# 554         554  C01299                                                NaN
# 555         555  C00343                                                NaN
# 570         570  C00001  CHEBI:15377; CHEBI:29374; CHEBI:29375; CHEBI:3...
# 578         578  C02554                                                NaN
# 589         589  C03511                                                NaN
# 600         600  C03127                                                NaN
#
#                BiGG Metabolite                              HMDB  \
# 13     bigg.metabolite:trnaval                               NaN
# 20   bigg.metabolite:pail4p_hs                               NaN
# 33     bigg.metabolite:trnatyr                               NaN
# 45     bigg.metabolite:trnaarg                               NaN
# 46                         NaN                               NaN
# 51                         NaN                               NaN
# 54                         NaN                               NaN
# 63                         NaN                               NaN
# 111                        NaN                               NaN
# 147                        NaN                               NaN
# 157    bigg.metabolite:trnahis                               NaN
# 166                        NaN                               NaN
# 168    bigg.metabolite:trnaile                               NaN
# 177                        NaN                               NaN
# 223                        NaN                               NaN
# 228                        NaN                               NaN
# 238                        NaN                               NaN
# 264                        NaN                               NaN
# 316                        NaN                               NaN
# 327                        NaN                               NaN
# 392                        NaN                               NaN
# 400   bigg.metabolite:3hmrsACP                               NaN
# 431      bigg.metabolite:trdrd                               NaN
# 433                        NaN                               NaN
# 437                        NaN                               NaN
# 444                        NaN                               NaN
# 476                        NaN                               NaN
# 484                        NaN                               NaN
# 492    bigg.metabolite:trnaphe                               NaN
# 508    bigg.metabolite:trnaser                               NaN
# 525    bigg.metabolite:trnathr                               NaN
# 543    bigg.metabolite:trnalys                               NaN
# 546     bigg.metabolite:malACP                               NaN
# 554                        NaN                               NaN
# 555                        NaN                               NaN
# 570        bigg.metabolite:h2o  hmdb:HMDB0002111; hmdb:HMDB02111
# 578                        NaN                               NaN
# 589                        NaN                               NaN
# 600                        NaN                               NaN
#
#                                        MetaCyc  \
# 13                  metacyc.compound:VAL-tRNAs
# 20                                         NaN
# 33                  metacyc.compound:TYR-tRNAs
# 45                  metacyc.compound:ARG-tRNAs
# 46                                         NaN
# 51                                         NaN
# 54                                         NaN
# 63                   metacyc.compound:CPD-8563
# 111                                        NaN
# 147                                        NaN
# 157                 metacyc.compound:HIS-tRNAs
# 166                                        NaN
# 168                 metacyc.compound:ILE-tRNAs
# 177                                        NaN
# 223                                        NaN
# 228                                        NaN
# 238                                        NaN
# 264                                        NaN
# 316                  metacyc.compound:CPD-8564
# 327                                        NaN
# 392                                        NaN
# 400                                        NaN
# 431                                        NaN
# 433  metacyc.compound:Glutamine-synthetase-Tyr
# 437                                        NaN
# 444                                        NaN
# 476                                        NaN
# 484                                        NaN
# 492                 metacyc.compound:PHE-tRNAs
# 508                 metacyc.compound:SER-tRNAs
# 525                 metacyc.compound:THR-tRNAs
# 543                 metacyc.compound:LYS-tRNAs
# 546                                        NaN
# 554                                        NaN
# 555                                        NaN
# 570                     metacyc.compound:WATER
# 578                                        NaN
# 589                                        NaN
# 600                                        NaN
#
#                                      SABIORK  \
# 13                                       NaN
# 20                                       NaN
# 33   sabiork.compound:3838; newSearch?q=3838
# 45   sabiork.compound:3837; newSearch?q=3837
# 46                                       NaN
# 51                                       NaN
# 54                                       NaN
# 63                                       NaN
# 111                                      NaN
# 147                                      NaN
# 157  sabiork.compound:3842; newSearch?q=3842
# 166                                      NaN
# 168  sabiork.compound:3832; newSearch?q=3832
# 177                                      NaN
# 223                                      NaN
# 228                                      NaN
# 238                                      NaN
# 264                                      NaN
# 316                                      NaN
# 327                                      NaN
# 392                                      NaN
# 400                                      NaN
# 431                                      NaN
# 433                                      NaN
# 437                                      NaN
# 444                                      NaN
# 476                                      NaN
# 484  sabiork.compound:3033; newSearch?q=3033
# 492  sabiork.compound:3847; newSearch?q=3847
# 508  sabiork.compound:3848; newSearch?q=3848
# 525  sabiork.compound:3803; newSearch?q=3803
# 543  sabiork.compound:3845; newSearch?q=3845
# 546                                      NaN
# 554                                      NaN
# 555                                      NaN
# 570      sabiork.compound:40; newSearch?q=40
# 578                                      NaN
# 589                                      NaN
# 600                                      NaN
#
#                                                   SEED           MNX  \
# 13   seed.compound:cpd11924; seed.compound:cpd28318...     MNXM90885
# 20                                                 NaN   MNXM1103886
# 33        seed.compound:cpd11751; M_cpd11751; cpd11751     MNXM90668
# 45   seed.compound:cpd11907; seed.compound:cpd22281...     MNXM90751
# 46        seed.compound:cpd11478; M_cpd11478; cpd11478    MNXM728726
# 51                                                 NaN    MNXM741218
# 54                                                 NaN    MNXM731957
# 63        seed.compound:cpd12412; M_cpd12412; cpd12412     MNXM92465
# 111       seed.compound:cpd12809; M_cpd12809; cpd12809      MNXM5822
# 147       seed.compound:cpd11465; M_cpd11465; cpd11465    MNXM728706
# 157  seed.compound:cpd11914; seed.compound:cpd27218...     MNXM90878
# 166                                                NaN    MNXM741213
# 168  seed.compound:cpd11915; seed.compound:cpd27269...     MNXM90879
# 177                                                NaN    MNXM731952
# 223                                                NaN    MNXM741228
# 228                                                NaN    MNXM741243
# 238                                                NaN    MNXM727673
# 264                                                NaN    MNXM741233
# 316       seed.compound:cpd11799; M_cpd11799; cpd11799     MNXM96087
# 327                                                NaN    MNXM740694
# 392                                                NaN    MNXM741352
# 400       seed.compound:cpd11484; M_cpd11484; cpd11484    MNXM728567
# 431       seed.compound:cpd11421; M_cpd11421; cpd11421    MNXM741334
# 433       seed.compound:cpd11838; M_cpd11838; cpd11838     MNXM96102
# 437                                                NaN    MNXM730330
# 444       seed.compound:cpd12884; M_cpd12884; cpd12884    MNXM727599
# 476       seed.compound:cpd12810; M_cpd12810; cpd12810      MNXM5691
# 484       seed.compound:cpd14957; M_cpd14957; cpd14957     MNXM91491
# 492  seed.compound:cpd11919; seed.compound:cpd27782...     MNXM90753
# 508  seed.compound:cpd11921; seed.compound:cpd28152...     MNXM91028
# 525  seed.compound:cpd11922; seed.compound:cpd28225...     MNXM90883
# 543  seed.compound:cpd11917; seed.compound:cpd27388...     MNXM90881
# 546                                                NaN    MNXM731937
# 554       seed.compound:cpd11841; M_cpd11841; cpd11841    MNXM728693
# 555                                                NaN    MNXM729077
# 570       seed.compound:cpd00001; M_cpd00001; cpd00001  WATER; WATER
# 578                                                NaN    MNXM741265
# 589                                                NaN    MNXM741194
# 600                                                NaN    MNXM741223
#
#                                              VMH  \
# 13                                           NaN
# 20                       vmhmetabolite:pail4p_hs
# 33                                           NaN
# 45                                           NaN
# 46   vmhmetabolite:3hbacp; vmhmetabolite:HC01321
# 51                                           NaN
# 54                                           NaN
# 63                                           NaN
# 111                         vmhmetabolite:mecfsp
# 147  vmhmetabolite:2beacp; vmhmetabolite:HC01255
# 157                                          NaN
# 166                                          NaN
# 168                                          NaN
# 177                                          NaN
# 223                                          NaN
# 228                                          NaN
# 238                                          NaN
# 264                                          NaN
# 316                                          NaN
# 327                                          NaN
# 392                                          NaN
# 400                        vmhmetabolite:HC01335
# 431                          vmhmetabolite:trdrd
# 433                                          NaN
# 437                                          NaN
# 444                          vmhmetabolite:pnclt
# 476                          vmhmetabolite:cfesp
# 484                                          NaN
# 492                                          NaN
# 508                                          NaN
# 525                                          NaN
# 543                                          NaN
# 546                         vmhmetabolite:malACP
# 554                                          NaN
# 555                                          NaN
# 570                            vmhmetabolite:h2o
# 578                                          NaN
# 589                                          NaN
# 600                                          NaN
#
#                                               Reactome  \
# 13                                                 NaN
# 20                                                 NaN
# 33                                                 NaN
# 45                                                 NaN
# 46                                                 NaN
# 51                                                 NaN
# 54                                                 NaN
# 63                                                 NaN
# 111                                                NaN
# 147                                                NaN
# 157                                                NaN
# 166                                                NaN
# 168                                                NaN
# 177                                                NaN
# 223                                                NaN
# 228                                                NaN
# 238                                                NaN
# 264                                                NaN
# 316                                                NaN
# 327                                                NaN
# 392                                                NaN
# 400                                                NaN
# 431                                                NaN
# 433                                                NaN
# 437                                                NaN
# 444                                                NaN
# 476                             reactome:R-ALL-9758893
# 484                                                NaN
# 492                                                NaN
# 508                                                NaN
# 525                                                NaN
# 543                                                NaN
# 546                                                NaN
# 554                                                NaN
# 555                                                NaN
# 570  reactome:R-ALL-109276; reactome:R-ALL-113518; ...
# 578                                                NaN
# 589                                                NaN
# 600                                                NaN
#
#                       SwissLipids  \
# 13                            NaN
# 20   SLM:000000346; SLM:000000346
# 33                            NaN
# 45                            NaN
# 46                            NaN
# 51                            NaN
# 54                            NaN
# 63                            NaN
# 111                           NaN
# 147                           NaN
# 157                           NaN
# 166                           NaN
# 168                           NaN
# 177                           NaN
# 223                           NaN
# 228                           NaN
# 238                           NaN
# 264                           NaN
# 316                           NaN
# 327                           NaN
# 392                           NaN
# 400                           NaN
# 431                           NaN
# 433                           NaN
# 437                           NaN
# 444                           NaN
# 476                           NaN
# 484                           NaN
# 492                           NaN
# 508                           NaN
# 525                           NaN
# 543                           NaN
# 546                           NaN
# 554                           NaN
# 555                           NaN
# 570                           NaN
# 578                           NaN
# 589                           NaN
# 600                           NaN
#
#                                               EnviPath  \
# 13                                                 NaN
# 20                                                 NaN
# 33                                                 NaN
# 45                                                 NaN
# 46                                                 NaN
# 51                                                 NaN
# 54                                                 NaN
# 63                                                 NaN
# 111                                                NaN
# 147                                                NaN
# 157                                                NaN
# 166                                                NaN
# 168                                                NaN
# 177                                                NaN
# 223                                                NaN
# 228                                                NaN
# 238                                                NaN
# 264                                                NaN
# 316                                                NaN
# 327                                                NaN
# 392                                                NaN
# 400                                                NaN
# 431                                                NaN
# 433                                                NaN
# 437                                                NaN
# 444                                                NaN
# 476                                                NaN
# 484                                                NaN
# 492                                                NaN
# 508                                                NaN
# 525                                                NaN
# 543                                                NaN
# 546                                                NaN
# 554                                                NaN
# 555                                                NaN
# 570  969d0227-3069-4e44-9525-7ae7bad84170; 799908db...
# 578                                                NaN
# 589                                                NaN
# 600                                                NaN
#
#                                      Extra Identifiers InChI
# 13   M_trnaval; trnaval; M_C01653; compound?id=VAL-...   NaN
# 20         M_pail4p_hs; pail4p_hs; M_C01277; pail4p_hs   NaN
# 33   M_trnatyr; trnatyr; M_C00787; compound?id=TYR-...   NaN
# 45   M_trnaarg; trnaarg; M_C01636; compound?id=ARG-...   NaN
# 46                           M_C04618; 3hbacp; HC01321   NaN
# 51                                            M_C02988   NaN
# 54                                            M_C00126   NaN
# 63                      M_C03875; compound?id=CPD-8563   NaN
# 111                                   M_C06020; mecfsp   NaN
# 147                          M_C04246; 2beacp; HC01255   NaN
# 157  M_trnahis; trnahis; M_C01643; compound?id=HIS-...   NaN
# 166                                           M_C02839   NaN
# 168  M_trnaile; trnaile; M_C01644; compound?id=ILE-...   NaN
# 177                                           M_C00125   NaN
# 223                                           M_C02163   NaN
# 228                                           M_C01931   NaN
# 238                                           M_C03939   NaN
# 264                                           M_C02992   NaN
# 316                     M_C01003; compound?id=CPD-8564   NaN
# 327                                           M_C00229   NaN
# 392                                           M_C02553   NaN
# 400            3hmrsACP; M_3hmrsACP; M_C04688; HC01335   NaN
# 431                    M_trdrd; trdrd; M_C00342; trdrd   NaN
# 433     M_C01281; compound?id=Glutamine-synthetase-Tyr   NaN
# 437                                           M_C01194   NaN
# 444                                    M_C06567; pnclt   NaN
# 476                     M_C06021; R-ALL-9758893; cfesp   NaN
# 484                         C16240; M_C03688; M_C16240   NaN
# 492  M_trnaphe; trnaphe; M_C01648; compound?id=PHE-...   NaN
# 508  M_trnaser; trnaser; M_C01650; compound?id=SER-...   NaN
# 525  M_trnathr; trnathr; M_C01651; compound?id=THR-...   NaN
# 543  M_trnalys; trnalys; M_C01646; compound?id=LYS-...   NaN
# 546           M_malACP; malACP; M_C01209; 9623; malACP   NaN
# 554                                           M_C01299   NaN
# 555                                           M_C00343   NaN
# 570  M_h2o; h2o; 969d0227-3069-4e44-9525-7ae7bad841...   NaN
# 578                                           M_C02554   NaN
# 589                                           M_C03511   NaN
# 600                                           M_C03127   NaN

# %%
print(len(inchi_absent))
# Out:
# 39

# %% [markdown]
# For cases where there is no inchi for a molecule, could either try to retrieve a SMILES, and generate structures this way, or download mol files directly from KEGG, if they exist. Manual check first for prsence etc.
#
# - Use this newly generated dataframe **"inchi_absent"**, to return SMILES/molFiles for those molecules only where it is required
# - **NOTE** Will be returning molfiles from kegg regardless, but just incase they do not exist/ are not defined well , SMILES could be useful to have also

# %% [markdown]
# ### Returning SMILES for the Subset of molecules with no InChI string

# %%
def mnx_smiles(mnx_id):
    """
    Function to query the ReconX Knowledge Graph for the InChI string
    associated with a given MNX identifier.
    """

    # Define the SPARQL endpoint
    sparql_endpoint = "http://sbg:7200/repositories/ReconXKG"
    sparql = SPARQLWrapper(sparql_endpoint)
    sparql.setReturnFormat(JSON)

    # SPARQL query with dynamic MNX ID
    query = f"""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX mnx: <https://rdf.metanetx.org/schema/>
    
    select ?mnx ?smiles
    where{{
    # ?mnx a mnx:CHEM ;
    	 mnx:smiles ?smiles ;
    	 rdfs:label ?mnx_label . 
    FILTER(REGEX(?mnx_label, "^{mnx_id}$"))
    }}
    """

    # Set the query
    sparql.setQuery(query)

    # Execute and process the results
    try:
        results = sparql.query().convert()
        bindings = results["results"]["bindings"]

        # Extract and return InChI strings
        smiles_list = [entry["smiles"]["value"] for entry in bindings]
        return smiles_list

    except Exception as e:
        print(f"An error occurred: {e}")
        return []

# %%
inchi_absent = inchi_absent.copy()
inchi_absent["SMILES"] = inchi_absent["MNX"].apply(lambda mnx_id: "; ".join(mnx_smiles(mnx_id)))

print(inchi_absent)
# Out:
#      Unnamed: 0 KEGG_ID                                              CHEBI  \
# 13           13  C01653  CHEBI:29183; CHEBI_10694; CHEBI_15191; CHEBI_2...
# 20           20  C01277              CHEBI_58178; CHEBI:58178; CHEBI_61083
# 33           33  C00787  CHEBI:29182; CHEBI_10692; CHEBI_15189; CHEBI_2...
# 45           45  C01636  CHEBI:29171; CHEBI_10673; CHEBI_15167; CHEBI_2...
# 46           46  C04618                                                NaN
# 51           51  C02988                                                NaN
# 54           54  C00126                                                NaN
# 63           63  C03875                                                NaN
# 111         111  C06020  CHEBI:27833; CHEBI_25292; CHEBI_27833; CHEBI_6870
# 147         147  C04246                         CHEBI:132146; CHEBI_132146
# 157         157  C01643  CHEBI:29178; CHEBI_10682; CHEBI_15178; CHEBI_2...
# 166         166  C02839                                                NaN
# 168         168  C01644  CHEBI:29174; CHEBI_10683; CHEBI_15179; CHEBI_2...
# 177         177  C00125                                                NaN
# 223         223  C02163                                                NaN
# 228         228  C01931                                                NaN
# 238         238  C03939                                                NaN
# 264         264  C02992                                                NaN
# 316         316  C01003                                                NaN
# 327         327  C00229                                                NaN
# 392         392  C02553                                                NaN
# 400         400  C04688                                                NaN
# 431         431  C00342                                                NaN
# 433         433  C01281                                                NaN
# 437         437  C01194                                                NaN
# 444         444  C06567                                                NaN
# 476         476  C06021  CHEBI:33913; CHEBI_23391; CHEBI_33913; CHEBI_3890
# 484         484  C03688  CHEBI:13850; CHEBI:16139; CHEBI_13845; CHEBI_1...
# 492         492  C01648  CHEBI:29184; CHEBI_10687; CHEBI_15183; CHEBI_2...
# 508         508  C01650  CHEBI:29179; CHEBI_10689; CHEBI_15186; CHEBI_2...
# 525         525  C01651  CHEBI:29180; CHEBI_10690; CHEBI_15187; CHEBI_2...
# 543         543  C01646  CHEBI:29185; CHEBI_10685; CHEBI_15181; CHEBI_2...
# 546         546  C01209  CHEBI:17330; CHEBI:58107; CHEBI_14566; CHEBI_1...
# 554         554  C01299                                                NaN
# 555         555  C00343                                                NaN
# 570         570  C00001  CHEBI:15377; CHEBI:29374; CHEBI:29375; CHEBI:3...
# 578         578  C02554                                                NaN
# 589         589  C03511                                                NaN
# 600         600  C03127                                                NaN
#
#                BiGG Metabolite                              HMDB  \
# 13     bigg.metabolite:trnaval                               NaN
# 20   bigg.metabolite:pail4p_hs                               NaN
# 33     bigg.metabolite:trnatyr                               NaN
# 45     bigg.metabolite:trnaarg                               NaN
# 46                         NaN                               NaN
# 51                         NaN                               NaN
# 54                         NaN                               NaN
# 63                         NaN                               NaN
# 111                        NaN                               NaN
# 147                        NaN                               NaN
# 157    bigg.metabolite:trnahis                               NaN
# 166                        NaN                               NaN
# 168    bigg.metabolite:trnaile                               NaN
# 177                        NaN                               NaN
# 223                        NaN                               NaN
# 228                        NaN                               NaN
# 238                        NaN                               NaN
# 264                        NaN                               NaN
# 316                        NaN                               NaN
# 327                        NaN                               NaN
# 392                        NaN                               NaN
# 400   bigg.metabolite:3hmrsACP                               NaN
# 431      bigg.metabolite:trdrd                               NaN
# 433                        NaN                               NaN
# 437                        NaN                               NaN
# 444                        NaN                               NaN
# 476                        NaN                               NaN
# 484                        NaN                               NaN
# 492    bigg.metabolite:trnaphe                               NaN
# 508    bigg.metabolite:trnaser                               NaN
# 525    bigg.metabolite:trnathr                               NaN
# 543    bigg.metabolite:trnalys                               NaN
# 546     bigg.metabolite:malACP                               NaN
# 554                        NaN                               NaN
# 555                        NaN                               NaN
# 570        bigg.metabolite:h2o  hmdb:HMDB0002111; hmdb:HMDB02111
# 578                        NaN                               NaN
# 589                        NaN                               NaN
# 600                        NaN                               NaN
#
#                                        MetaCyc  \
# 13                  metacyc.compound:VAL-tRNAs
# 20                                         NaN
# 33                  metacyc.compound:TYR-tRNAs
# 45                  metacyc.compound:ARG-tRNAs
# 46                                         NaN
# 51                                         NaN
# 54                                         NaN
# 63                   metacyc.compound:CPD-8563
# 111                                        NaN
# 147                                        NaN
# 157                 metacyc.compound:HIS-tRNAs
# 166                                        NaN
# 168                 metacyc.compound:ILE-tRNAs
# 177                                        NaN
# 223                                        NaN
# 228                                        NaN
# 238                                        NaN
# 264                                        NaN
# 316                  metacyc.compound:CPD-8564
# 327                                        NaN
# 392                                        NaN
# 400                                        NaN
# 431                                        NaN
# 433  metacyc.compound:Glutamine-synthetase-Tyr
# 437                                        NaN
# 444                                        NaN
# 476                                        NaN
# 484                                        NaN
# 492                 metacyc.compound:PHE-tRNAs
# 508                 metacyc.compound:SER-tRNAs
# 525                 metacyc.compound:THR-tRNAs
# 543                 metacyc.compound:LYS-tRNAs
# 546                                        NaN
# 554                                        NaN
# 555                                        NaN
# 570                     metacyc.compound:WATER
# 578                                        NaN
# 589                                        NaN
# 600                                        NaN
#
#                                      SABIORK  \
# 13                                       NaN
# 20                                       NaN
# 33   sabiork.compound:3838; newSearch?q=3838
# 45   sabiork.compound:3837; newSearch?q=3837
# 46                                       NaN
# 51                                       NaN
# 54                                       NaN
# 63                                       NaN
# 111                                      NaN
# 147                                      NaN
# 157  sabiork.compound:3842; newSearch?q=3842
# 166                                      NaN
# 168  sabiork.compound:3832; newSearch?q=3832
# 177                                      NaN
# 223                                      NaN
# 228                                      NaN
# 238                                      NaN
# 264                                      NaN
# 316                                      NaN
# 327                                      NaN
# 392                                      NaN
# 400                                      NaN
# 431                                      NaN
# 433                                      NaN
# 437                                      NaN
# 444                                      NaN
# 476                                      NaN
# 484  sabiork.compound:3033; newSearch?q=3033
# 492  sabiork.compound:3847; newSearch?q=3847
# 508  sabiork.compound:3848; newSearch?q=3848
# 525  sabiork.compound:3803; newSearch?q=3803
# 543  sabiork.compound:3845; newSearch?q=3845
# 546                                      NaN
# 554                                      NaN
# 555                                      NaN
# 570      sabiork.compound:40; newSearch?q=40
# 578                                      NaN
# 589                                      NaN
# 600                                      NaN
#
#                                                   SEED           MNX  \
# 13   seed.compound:cpd11924; seed.compound:cpd28318...     MNXM90885
# 20                                                 NaN   MNXM1103886
# 33        seed.compound:cpd11751; M_cpd11751; cpd11751     MNXM90668
# 45   seed.compound:cpd11907; seed.compound:cpd22281...     MNXM90751
# 46        seed.compound:cpd11478; M_cpd11478; cpd11478    MNXM728726
# 51                                                 NaN    MNXM741218
# 54                                                 NaN    MNXM731957
# 63        seed.compound:cpd12412; M_cpd12412; cpd12412     MNXM92465
# 111       seed.compound:cpd12809; M_cpd12809; cpd12809      MNXM5822
# 147       seed.compound:cpd11465; M_cpd11465; cpd11465    MNXM728706
# 157  seed.compound:cpd11914; seed.compound:cpd27218...     MNXM90878
# 166                                                NaN    MNXM741213
# 168  seed.compound:cpd11915; seed.compound:cpd27269...     MNXM90879
# 177                                                NaN    MNXM731952
# 223                                                NaN    MNXM741228
# 228                                                NaN    MNXM741243
# 238                                                NaN    MNXM727673
# 264                                                NaN    MNXM741233
# 316       seed.compound:cpd11799; M_cpd11799; cpd11799     MNXM96087
# 327                                                NaN    MNXM740694
# 392                                                NaN    MNXM741352
# 400       seed.compound:cpd11484; M_cpd11484; cpd11484    MNXM728567
# 431       seed.compound:cpd11421; M_cpd11421; cpd11421    MNXM741334
# 433       seed.compound:cpd11838; M_cpd11838; cpd11838     MNXM96102
# 437                                                NaN    MNXM730330
# 444       seed.compound:cpd12884; M_cpd12884; cpd12884    MNXM727599
# 476       seed.compound:cpd12810; M_cpd12810; cpd12810      MNXM5691
# 484       seed.compound:cpd14957; M_cpd14957; cpd14957     MNXM91491
# 492  seed.compound:cpd11919; seed.compound:cpd27782...     MNXM90753
# 508  seed.compound:cpd11921; seed.compound:cpd28152...     MNXM91028
# 525  seed.compound:cpd11922; seed.compound:cpd28225...     MNXM90883
# 543  seed.compound:cpd11917; seed.compound:cpd27388...     MNXM90881
# 546                                                NaN    MNXM731937
# 554       seed.compound:cpd11841; M_cpd11841; cpd11841    MNXM728693
# 555                                                NaN    MNXM729077
# 570       seed.compound:cpd00001; M_cpd00001; cpd00001  WATER; WATER
# 578                                                NaN    MNXM741265
# 589                                                NaN    MNXM741194
# 600                                                NaN    MNXM741223
#
#                                              VMH  \
# 13                                           NaN
# 20                       vmhmetabolite:pail4p_hs
# 33                                           NaN
# 45                                           NaN
# 46   vmhmetabolite:3hbacp; vmhmetabolite:HC01321
# 51                                           NaN
# 54                                           NaN
# 63                                           NaN
# 111                         vmhmetabolite:mecfsp
# 147  vmhmetabolite:2beacp; vmhmetabolite:HC01255
# 157                                          NaN
# 166                                          NaN
# 168                                          NaN
# 177                                          NaN
# 223                                          NaN
# 228                                          NaN
# 238                                          NaN
# 264                                          NaN
# 316                                          NaN
# 327                                          NaN
# 392                                          NaN
# 400                        vmhmetabolite:HC01335
# 431                          vmhmetabolite:trdrd
# 433                                          NaN
# 437                                          NaN
# 444                          vmhmetabolite:pnclt
# 476                          vmhmetabolite:cfesp
# 484                                          NaN
# 492                                          NaN
# 508                                          NaN
# 525                                          NaN
# 543                                          NaN
# 546                         vmhmetabolite:malACP
# 554                                          NaN
# 555                                          NaN
# 570                            vmhmetabolite:h2o
# 578                                          NaN
# 589                                          NaN
# 600                                          NaN
#
#                                               Reactome  \
# 13                                                 NaN
# 20                                                 NaN
# 33                                                 NaN
# 45                                                 NaN
# 46                                                 NaN
# 51                                                 NaN
# 54                                                 NaN
# 63                                                 NaN
# 111                                                NaN
# 147                                                NaN
# 157                                                NaN
# 166                                                NaN
# 168                                                NaN
# 177                                                NaN
# 223                                                NaN
# 228                                                NaN
# 238                                                NaN
# 264                                                NaN
# 316                                                NaN
# 327                                                NaN
# 392                                                NaN
# 400                                                NaN
# 431                                                NaN
# 433                                                NaN
# 437                                                NaN
# 444                                                NaN
# 476                             reactome:R-ALL-9758893
# 484                                                NaN
# 492                                                NaN
# 508                                                NaN
# 525                                                NaN
# 543                                                NaN
# 546                                                NaN
# 554                                                NaN
# 555                                                NaN
# 570  reactome:R-ALL-109276; reactome:R-ALL-113518; ...
# 578                                                NaN
# 589                                                NaN
# 600                                                NaN
#
#                       SwissLipids  \
# 13                            NaN
# 20   SLM:000000346; SLM:000000346
# 33                            NaN
# 45                            NaN
# 46                            NaN
# 51                            NaN
# 54                            NaN
# 63                            NaN
# 111                           NaN
# 147                           NaN
# 157                           NaN
# 166                           NaN
# 168                           NaN
# 177                           NaN
# 223                           NaN
# 228                           NaN
# 238                           NaN
# 264                           NaN
# 316                           NaN
# 327                           NaN
# 392                           NaN
# 400                           NaN
# 431                           NaN
# 433                           NaN
# 437                           NaN
# 444                           NaN
# 476                           NaN
# 484                           NaN
# 492                           NaN
# 508                           NaN
# 525                           NaN
# 543                           NaN
# 546                           NaN
# 554                           NaN
# 555                           NaN
# 570                           NaN
# 578                           NaN
# 589                           NaN
# 600                           NaN
#
#                                               EnviPath  \
# 13                                                 NaN
# 20                                                 NaN
# 33                                                 NaN
# 45                                                 NaN
# 46                                                 NaN
# 51                                                 NaN
# 54                                                 NaN
# 63                                                 NaN
# 111                                                NaN
# 147                                                NaN
# 157                                                NaN
# 166                                                NaN
# 168                                                NaN
# 177                                                NaN
# 223                                                NaN
# 228                                                NaN
# 238                                                NaN
# 264                                                NaN
# 316                                                NaN
# 327                                                NaN
# 392                                                NaN
# 400                                                NaN
# 431                                                NaN
# 433                                                NaN
# 437                                                NaN
# 444                                                NaN
# 476                                                NaN
# 484                                                NaN
# 492                                                NaN
# 508                                                NaN
# 525                                                NaN
# 543                                                NaN
# 546                                                NaN
# 554                                                NaN
# 555                                                NaN
# 570  969d0227-3069-4e44-9525-7ae7bad84170; 799908db...
# 578                                                NaN
# 589                                                NaN
# 600                                                NaN
#
#                                      Extra Identifiers InChI  \
# 13   M_trnaval; trnaval; M_C01653; compound?id=VAL-...   NaN
# 20         M_pail4p_hs; pail4p_hs; M_C01277; pail4p_hs   NaN
# 33   M_trnatyr; trnatyr; M_C00787; compound?id=TYR-...   NaN
# 45   M_trnaarg; trnaarg; M_C01636; compound?id=ARG-...   NaN
# 46                           M_C04618; 3hbacp; HC01321   NaN
# 51                                            M_C02988   NaN
# 54                                            M_C00126   NaN
# 63                      M_C03875; compound?id=CPD-8563   NaN
# 111                                   M_C06020; mecfsp   NaN
# 147                          M_C04246; 2beacp; HC01255   NaN
# 157  M_trnahis; trnahis; M_C01643; compound?id=HIS-...   NaN
# 166                                           M_C02839   NaN
# 168  M_trnaile; trnaile; M_C01644; compound?id=ILE-...   NaN
# 177                                           M_C00125   NaN
# 223                                           M_C02163   NaN
# 228                                           M_C01931   NaN
# 238                                           M_C03939   NaN
# 264                                           M_C02992   NaN
# 316                     M_C01003; compound?id=CPD-8564   NaN
# 327                                           M_C00229   NaN
# 392                                           M_C02553   NaN
# 400            3hmrsACP; M_3hmrsACP; M_C04688; HC01335   NaN
# 431                    M_trdrd; trdrd; M_C00342; trdrd   NaN
# 433     M_C01281; compound?id=Glutamine-synthetase-Tyr   NaN
# 437                                           M_C01194   NaN
# 444                                    M_C06567; pnclt   NaN
# 476                     M_C06021; R-ALL-9758893; cfesp   NaN
# 484                         C16240; M_C03688; M_C16240   NaN
# 492  M_trnaphe; trnaphe; M_C01648; compound?id=PHE-...   NaN
# 508  M_trnaser; trnaser; M_C01650; compound?id=SER-...   NaN
# 525  M_trnathr; trnathr; M_C01651; compound?id=THR-...   NaN
# 543  M_trnalys; trnalys; M_C01646; compound?id=LYS-...   NaN
# 546           M_malACP; malACP; M_C01209; 9623; malACP   NaN
# 554                                           M_C01299   NaN
# 555                                           M_C00343   NaN
# 570  M_h2o; h2o; 969d0227-3069-4e44-9525-7ae7bad841...   NaN
# 578                                           M_C02554   NaN
# 589                                           M_C03511   NaN
# 600                                           M_C03127   NaN
#
#                                                 SMILES
# 13   [13CH3:1][CH2:2][CH:5]1[CH:7]([OH:17])[CH:8]([...
# 20   [13CH3:1][C:5](=[O:14])[O:25][CH2:3][C@H:7]([C...
# 33   [13CH3:1][CH2:2][CH:5]1[CH:7]([OH:17])[CH:8]([...
# 45   [13CH3:1][CH2:2][CH:5]1[CH:7]([OH:17])[CH:8]([...
# 46   [CH3:1][C@H:4]([CH2:3][C:5](=[O:7])[S:8][13CH3...
# 51   [13CH3:1][C@H:10]1[C@H:18]([OH:29])[C@H:21]([O...
# 54   [CH3:1][c:21]1[c:29]([CH2:11][CH2:13][C:41](=[...
# 63   [13CH3:1][C:4](=[N:8][C@@H:5]([CH2:3][O:14][P:...
# 111  [13CH3:1]/[C:22]1=[C:25]2\[C:31]([13CH3:4])([1...
# 147  [CH3:1]/[CH:3]=[CH:4]/[C:5](=[O:6])[S:7][13CH3:2]
# 157  [13CH3:1][CH2:2][CH:5]1[CH:7]([OH:17])[CH:8]([...
# 166  [13CH3:1][C@H:13]1[C@H:22]([OH:40])[C@H:25]([O...
# 168  [13CH3:1][CH2:2][CH:5]1[CH:7]([OH:17])[CH:8]([...
# 177  [CH3:1][c:21]1[c:29]([CH2:11][CH2:13][C:41](=[...
# 223  [13CH3:1][C@H:11]1[C@H:18]([OH:39])[C@H:21]([O...
# 228  [13CH3:1][C@H:11]1[C@H:18]([OH:28])[C@H:21]([O...
# 238                 [CH3:1][C:3](=[O:4])[S:5][13CH3:2]
# 264  [CH3:1][C@@H:8]([C@@H:15]([C:22](=[O:29])[O:39...
# 316  [13CH3:1][C:4](=[N:8][C@@H:5]([CH2:3][OH:9])[C...
# 327                                    [13CH3:1][SH:2]
# 392  [13CH3:1][C@H:8]1[C@H:15]([OH:25])[C@H:18]([O:...
# 400  [CH3:1][CH2:3][CH2:4][CH2:5][CH2:6][CH2:7][CH2...
# 431  [13CH3:1][C@@H:7]([C:12](=[N:16][C@@H:8]([13CH...
# 433  [13CH3:1][C:8](=[N:14][C@@H:11]([CH2:7][c:9]1[...
# 437  [13CH3:1][C:5](=[O:14])[O:23][CH2:3][CH:7]([CH...
# 444  [CH3:1][C:9]1([CH3:2])[C@H:5]([C:8](=[O:14])[O...
# 476  [13CH3:1]/[C:22]1=[C:25]2\[C:31]([13CH3:4])([1...
# 484                                   [13CH3:1][NH2:2]
# 492  [13CH3:1][CH2:2][CH:5]1[CH:7]([OH:17])[CH:8]([...
# 508  [13CH3:1][CH2:2][CH:5]1[CH:7]([OH:17])[CH:8]([...
# 525  [13CH3:1][CH2:2][CH:5]1[CH:7]([OH:17])[CH:8]([...
# 543  [13CH3:1][CH2:2][CH:5]1[CH:7]([OH:17])[CH:8]([...
# 546  [13CH3:1][S:8][C:4]([CH2:2][C:3](=[O:5])[OH:6]...
# 554  [13CH3:1][C:11](=[N:28][C@@H:14]([CH2:7][c:12]...
# 555  [13CH3:1][C@H:7]1[C:12]([OH:20])=[N:16][C@@H:8...
# 570
# 578  [CH3:1][CH:10]([CH3:2])[C@@H:16]([C:27](=[O:38...
# 589  [13CH3:1][C@H:13]1[C@H:21]([OH:30])[C@H:24]([O...
# 600  [CH3:1][CH2:5][C@H:11]([CH3:2])[C@@H:17]([C:28...

# %%
inchi_absent.to_csv("/home/jackmcgoldrick/openTECR/results/structural_mapping/inchis_absent.csv")

# %% [markdown]
# ## Generating Structures from InChI strings, and also SMILES (where needed)

# %%
# InChI string
inchi_string = "InChI=1S/C2H6O/c1-2-3/h3H,2H2,1H3"

# Convert InChI to RDKit Mol object
mol = Chem.MolFromInchi(inchi_string)
if mol is None:
    print("Failed to convert InChI to Mol object.")
else:
    # Write to MOL file
    with open("etoh.mol", "w") as mol_file:
        mol_file.write(Chem.MolToMolBlock(mol))
    print("MOL file saved as etoh.mol")
# Out:
# MOL file saved as etoh.mol

# %% [markdown]
# Now that we know the code above works to generate a mol file for a simple molecule such as **VMH:etoh**, the code should be adapted to run on the entire dataset of 603 metabolites (minus those which have no inchi key at present)
#
# First run will be to examine those molecules which have stereochemistry, and to determine whether or not stereochemistry is converted readily across from the inchi string to the generated mol file.

# %%
def gen_molFile(inchi, output_dir, dataframe, log_file="failures.log"):
    """
    Converts an InChI string into a mol file using RDKit and saves it, with debugging.
    
    Args:
        inchi (str): The InChI string of the molecule.
        output_dir (str): The full path to the directory to save the mol files.
        dataframe (pd.DataFrame): DataFrame containing the "InChI" and "KEGG_ID" columns.
        log_file (str): Path to the log file for recording failures.
    """
    try:
        # Retrieve the KEGG ID associated with the InChI
        row = dataframe[dataframe["InChI"] == inchi]
        if row.empty:
            raise ValueError(f"No KEGG ID found for InChI: {inchi}")
        kegg = row["KEGG_ID"].values[0]

        # Validate the InChI string
        if not inchi or not isinstance(inchi, str):
            raise ValueError(f"Invalid InChI string: {inchi}")

        # Convert the InChI string into an RDKit Mol object
        mol = Chem.MolFromInchi(inchi, sanitize=True, removeHs=True)
        if mol is None:
            raise ValueError(f"RDKit failed to convert InChI: {inchi}")

        # Construct the file path and ensure the output directory exists
        os.makedirs(output_dir, exist_ok=True)
        file_path = os.path.join(output_dir, f"{kegg}.mol")

        # Write the Mol object to a file
        with open(file_path, "w") as mol_file:
            mol_file.write(Chem.MolToMolBlock(mol))
        print(f"MOL file saved as {file_path}")

    except Exception as e:
        # Log the failure details
        with open(log_file, "a") as log:
            log.write(f"Failure for InChI: {inchi}, KEGG_ID: {row['KEGG_ID'].values[0] if not row.empty else 'N/A'}, Error: {e}\n")
        print(f"Error: {e}")

# %%
output_directory = "/home/jackmcgoldrick/openTECR/data/molFiles_Final"

for inchi in mapped_inchis["InChI"]:
    gen_molFile(inchi, output_directory, mapped_inchis)
# Out:
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04752.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00407.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01545.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00417.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00197.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00492.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00357.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C14177.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04442.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04741.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00469.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00013.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03149.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03167.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00942.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02052.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00979.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00318.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00160.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00189.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00123.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00294.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03017.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02571.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00300.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00870.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00499.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01551.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00109.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01142.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02930.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00311.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03392.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01157.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01217.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C05984.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03210.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00186.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03394.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01112.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03564.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00363.mol
# Error: No KEGG ID found for InChI: nan
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00256.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03044.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00114.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00624.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01100.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C16074.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C08492.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00252.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C05439.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02780.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00207.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03599.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00394.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00905.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01089.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02048.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03519.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02666.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01107.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00636.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C19636.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00014.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03150.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01113.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00129.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00257.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02160.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00546.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00232.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03521.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C06827.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02045.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02990.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00051.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00438.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00247.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00989.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03926.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00314.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C06473.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00239.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00956.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01026.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01188.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00131.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C05382.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C06156.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02181.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02763.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C19838.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01175.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00063.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C16688.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01697.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00086.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00159.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00515.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03232.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00075.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00085.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C05551.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03561.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00079.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04734.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00140.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00493.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00279.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00064.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00349.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03506.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03598.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00455.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02712.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00065.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C05268.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04738.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00083.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00191.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04751.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01835.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00124.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00099.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C06159.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02560.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00275.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00580.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00259.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02557.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00135.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00035.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00575.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00795.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01146.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00334.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00577.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C15025.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02278.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00208.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01013.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00166.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00415.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00310.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00061.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00475.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01732.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00143.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00352.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C05271.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00019.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C05402.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01144.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00387.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00203.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00212.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00084.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C05945.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01367.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00673.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03448.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00003.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00204.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00583.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00042.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00164.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02954.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01179.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01094.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02614.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00206.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00327.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02637.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C05665.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00219.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C16512.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00111.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00074.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00026.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00184.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02734.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00273.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04092.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00078.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00429.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01570.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00105.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00106.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03383.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00227.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00183.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02405.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00705.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00093.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00835.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00187.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00713.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00719.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02612.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04257.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04114.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00180.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00534.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02466.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00104.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01182.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03794.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00091.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01762.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01589.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04268.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03703.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00423.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00237.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00631.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00270.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01081.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C06019.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00036.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02147.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00100.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02636.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00266.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C11907.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00188.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00740.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00153.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03351.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00031.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00261.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02480.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00689.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00112.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01231.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03059.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C05437.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00163.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C14178.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C05598.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00047.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00024.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03360.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00062.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C06255.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00169.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00048.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04823.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00282.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00322.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00108.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00170.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01096.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03178.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00808.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00584.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00067.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02642.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01845.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00148.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03618.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00617.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00021.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03166.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00437.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C05512.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00479.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C05662.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00672.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00103.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00022.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03557.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02595.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00522.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00620.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00986.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00156.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00224.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03981.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00154.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00236.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00049.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00005.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00242.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00725.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00015.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01742.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03943.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00249.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00331.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02953.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04056.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00864.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00101.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00966.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00127.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00354.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00309.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00366.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00089.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03912.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02043.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00474.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00362.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01882.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00167.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00935.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00497.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03341.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00117.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00361.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00535.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00055.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00253.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00365.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03373.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00756.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00920.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C08240.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00130.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00346.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00288.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00498.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00785.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00006.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01172.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00037.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00360.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02226.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00558.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01267.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00424.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00008.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00121.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03483.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03410.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00116.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00073.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02718.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03082.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00020.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00392.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00118.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01236.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00052.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00122.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00081.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00579.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00199.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01620.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00119.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03459.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C11355.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00645.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00364.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00668.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00168.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00664.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00016.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03384.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01101.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00295.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C18054.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C06463.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03680.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00146.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01595.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03067.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00216.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00296.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00570.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00798.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00684.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00385.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00504.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01847.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01721.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00644.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00552.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03440.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00181.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01185.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04462.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00234.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01507.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C09814.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01286.mol
# [16:29:33] WARNING: not removing hydrogen atom without neighbors
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01131.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01487.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00222.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00683.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00842.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00077.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00058.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00332.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C08126.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C07064.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C05922.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00313.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01143.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03173.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00588.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01796.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00680.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C15673.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00810.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00185.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00033.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00010.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00307.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00235.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00217.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04137.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00333.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04707.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01244.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00254.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C11695.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00250.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C06219.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02295.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00147.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00508.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00501.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00007.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00882.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00002.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01235.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01099.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00940.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C06322.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00854.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00704.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00379.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00231.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00975.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00004.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02305.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02798.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00943.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00459.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04677.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00439.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02782.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00885.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01563.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00536.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00468.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C06468.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00445.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00603.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00155.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C05403.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02938.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00794.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00482.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00581.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00190.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C16310.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00599.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00337.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00376.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04654.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00414.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00029.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00861.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00559.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01213.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02115.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00280.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00922.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01613.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03406.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00473.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00095.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01087.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00944.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00178.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00299.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00951.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00263.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00666.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C06464.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00556.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C07756.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00739.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03064.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02280.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01008.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04348.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01936.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00152.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01127.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00214.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03314.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04377.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01412.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C07086.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03652.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02679.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00144.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03451.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00198.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01083.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00025.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03656.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01996.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01019.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00312.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C06142.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00059.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00449.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C05269.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00262.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C07761.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04188.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00507.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00476.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00243.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04421.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01352.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01005.mol
# Error: No KEGG ID found for InChI: nan
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00044.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04367.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00133.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02237.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00009.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00258.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04691.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00092.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01186.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C06749.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00441.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02022.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00043.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00408.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00590.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00968.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00248.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00096.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00345.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01103.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00440.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01384.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C05385.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01959.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00251.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02110.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04256.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00082.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00149.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00954.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00463.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03493.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C05979.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04327.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00158.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00233.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01904.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00877.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00027.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04105.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02588.mol
# Error: No KEGG ID found for InChI: nan
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00041.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00137.mol

# %% [markdown]
# ### Counting the Number of molFiles generated

# %% [markdown]
# Expected number of molFiles to be generated == 603-39 == **564 molFiles**
#
# Minus 39 comes from those mols without inchis , which will be generated from their SMILES in subsequent sections

# %%
def count_files_in_directory(directory_path):
    try:
        # Get the list of all entries in the directory
        entries = os.listdir(directory_path)
        # Filter out only the files
        file_count = sum(1 for entry in entries if os.path.isfile(os.path.join(directory_path, entry)))
        return file_count
    except FileNotFoundError:
        return "Error: Directory not found."
    except PermissionError:
        return "Error: Permission denied."
    except Exception as e:
        return f"Error: {str(e)}"

# %%
# Example usage:
directory_path = "/home/jackmcgoldrick/openTECR/data/molFiles_Final"
file_count = count_files_in_directory(directory_path)
print(f"Number of files in the directory: {file_count}")
# Out:
# Number of files in the directory: 564

# %% [markdown]
# Success!!

# %% [markdown]
# #### Generating molFiles for those Molecules with SMILES

# %%
def gen_molFile_fromSMILES(smiles, output_dir, dataframe, log_file="failures.log"):
    try:
        # Retrieve all KEGG IDs associated with the SMILES
        rows = dataframe[dataframe["SMILES"] == smiles]
        if rows.empty:
            raise ValueError(f"No KEGG ID found for SMILES: {smiles}")
        
        # Ensure the output directory exists
        os.makedirs(output_dir, exist_ok=True)
        
        # Iterate over each KEGG ID to create separate MOL files
        for _, row in rows.iterrows():
            kegg = row["KEGG_ID"]
            
            # Validate the SMILES string
            if not smiles or not isinstance(smiles, str):
                raise ValueError(f"Invalid SMILES string: {smiles}")
            
            # Convert the SMILES string into an RDKit Mol object
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                raise ValueError(f"RDKit failed to convert SMILES: {smiles}")
            
            # Construct the file path
            file_path = os.path.join(output_dir, f"{kegg}.mol")
            
            # Write the Mol object to a file
            with open(file_path, "w") as mol_file:
                mol_file.write(Chem.MolToMolBlock(mol))
            print(f"MOL file saved as {file_path}")

    except Exception as e:
        # Log the failure details
        with open(log_file, "a") as log:
            log.write(f"Failure for SMILES: {smiles}, KEGG_ID: {row['KEGG_ID'] if 'kegg' in locals() else 'N/A'}, Error: {e}\n")
        print(f"Error: {e}")

# %%
output_directory = "/home/jackmcgoldrick/openTECR/data/molFiles_Final"

for smiles in inchi_absent["SMILES"]:
    gen_molFile_fromSMILES(smiles, output_directory, inchi_absent)
# Out:
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01653.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00787.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01636.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01643.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01644.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01648.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01650.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01651.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01646.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01277.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01653.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00787.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01636.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01643.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01644.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01648.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01650.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01651.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01646.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01653.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00787.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01636.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01643.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01644.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01648.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01650.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01651.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01646.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04618.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02988.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00126.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03875.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C06020.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04246.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01653.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00787.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01636.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01643.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01644.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01648.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01650.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01651.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01646.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02839.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01653.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00787.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01636.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01643.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01644.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01648.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01650.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01651.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01646.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00125.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02163.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01931.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03939.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02992.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01003.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00229.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02553.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C04688.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00342.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01281.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01194.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C06567.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C06021.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03688.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01653.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00787.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01636.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01643.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01644.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01648.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01650.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01651.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01646.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01653.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00787.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01636.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01643.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01644.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01648.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01650.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01651.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01646.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01653.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00787.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01636.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01643.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01644.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01648.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01650.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01651.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01646.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01653.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00787.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01636.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01643.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01644.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01648.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01650.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01651.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01646.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01209.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C01299.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C00343.mol
# Error: Invalid SMILES string:
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C02554.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03511.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_Final/C03127.mol

# %%
# Example usage:
directory_path = "/home/jackmcgoldrick/openTECR/data/molFiles_Final"
file_count = count_files_in_directory(directory_path)
print(f"Number of files in the directory: {file_count}")
# Out:
# Number of files in the directory: 602

# %% [markdown]
# ### Testing a fix to the problem of tRNA molecules

# %%
def save_molfile(smiles, dataframe, output_dir, log_file):
    try:
        # Retrieve all KEGG IDs associated with the SMILES
        rows = dataframe[dataframe["SMILES"] == smiles]
        if rows.empty:
            raise ValueError(f"No KEGG ID found for SMILES: {smiles}")
        
        # Ensure the output directory exists
        os.makedirs(output_dir, exist_ok=True)
        
        # Iterate over each KEGG ID to create separate MOL files
        for _, row in rows.iterrows():
            kegg = row["KEGG_ID"]
            
            # Validate the SMILES string
            if not smiles or not isinstance(smiles, str):
                raise ValueError(f"Invalid SMILES string: {smiles}")
            
            # Convert the SMILES string into an RDKit Mol object
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                raise ValueError(f"RDKit failed to convert SMILES: {smiles}")
            
            # Construct the file path
            file_path = os.path.join(output_dir, f"{kegg}.mol")
            
            # Write the Mol object to a file
            with open(file_path, "w") as mol_file:
                mol_file.write(Chem.MolToMolBlock(mol))
            print(f"MOL file saved as {file_path}")

    except Exception as e:
        # Log the failure details
        with open(log_file, "a") as log:
            log.write(f"Failure for SMILES: {smiles}, KEGG_ID: {row['KEGG_ID'] if 'kegg' in locals() else 'N/A'}, Error: {e}\n")
        print(f"Error: {e}")

# %%
ouput_dir = "/home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3"

for smiles in inchi_absent['SMILES']:
    save_molfile(smiles, inchi_absent, ouput_dir, log_file="failures.log")
# Out:
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01653.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C00787.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01636.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01643.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01644.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01648.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01650.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01651.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01646.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01277.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01653.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C00787.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01636.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01643.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01644.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01648.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01650.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01651.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01646.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01653.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C00787.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01636.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01643.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01644.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01648.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01650.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01651.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01646.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C04618.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C02988.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C00126.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C03875.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C06020.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C04246.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01653.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C00787.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01636.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01643.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01644.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01648.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01650.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01651.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01646.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C02839.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01653.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C00787.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01636.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01643.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01644.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01648.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01650.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01651.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01646.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C00125.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C02163.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01931.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C03939.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C02992.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01003.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C00229.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C02553.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C04688.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C00342.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01281.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01194.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C06567.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C06021.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C03688.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01653.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C00787.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01636.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01643.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01644.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01648.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01650.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01651.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01646.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01653.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C00787.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01636.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01643.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01644.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01648.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01650.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01651.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01646.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01653.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C00787.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01636.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01643.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01644.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01648.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01650.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01651.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01646.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01653.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C00787.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01636.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01643.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01644.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01648.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01650.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01651.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01646.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01209.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C01299.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C00343.mol
# Error: Invalid SMILES string:
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C02554.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C03511.mol
# MOL file saved as /home/jackmcgoldrick/openTECR/data/molFiles_smiles_test3/C03127.mol

# %% [markdown]
# Now it works correctly
