# %% [markdown]
# # Utilising reconXMapper (SPARQL Query) to aid Free Text Mapping

# %% [markdown]
# Query suggests related identifiers based solely on name. If exact match is found, identifiers related to that metabolite are returned only. If partial matches are found, each partial match and related identifiers are returned. Will get messy with partial matches, so should seperate exact matches and partial matches into two different dataframes. Ideally majority will result in exact matches, but different naming conventions across papers and sites will render this unlikely. This process will still speed up mapping as it will suggest probable metabolites to look at, instead of manually searching sites.

# %%
import os
import pandas as pd
import re

# %% [markdown]
# Need to import openTECR recuration.csv and select 2 sheets, **table_metadata** and **actual data**
# - seperate into seperate dfs for now once extracted

# %%
# import the file
recuration = "/home/jackmcgoldrick/openTECR/data/openTECR recuration.xlsx"

# %%
table_metadata = pd.read_excel(recuration, sheet_name='table metadata')

# %%
table_metadata
# Out:
#       part  page  col l/r  table from top  \
# 0        1   522        1               1
# 1        1   522        1               2
# 2        1   522        2               1
# 3        1   522        2               2
# 4        1   522        2               3
# ...    ...   ...      ...             ...
# 1655     7  1386        1               1
# 1656     7  1386        2               1
# 1657     7  1386        2               2
# 1658     7  1387        1               1
# 1659     7  1387        2               1
#
#                                                reaction reference_code  \
# 0     benzyl alcohol(aq) + NAD(aq) = benzaldehyde(aq...      80COO/BLA
# 1      1-butanol(aq) + NAD(aq) = butanal(aq) + NADH(aq)          68ERI
# 2      1-butanol(aq) + NAD(aq) = butanal(aq) + NADH(aq)          83BRA
# 3     cyclohexanol(aq) + NAD(aq) = cyclohexanone(aq)...      59MER/TOM
# 4     cyclohexanol(aq) + NAD(aq) = cyclohexanone(aq)...      80COO/BLA
# ...                                                 ...            ...
# 1655  ATP(aq) + L-serine(aq) + tRNA-Ser(aq) = AMP(aq...         06AIR2
# 1656  ATP(aq) + L-arginine(aq) + tRNA-Arg(aq) = AMP(...          06AIR
# 1657  ATP(aq) + L-phenylalanine(aq) + tRNA-Phe(aq) =...         06AIR2
# 1658  ATP(aq) + L-histidine(aq) + tRNA-His(aq) = AMP...         06AIR2
# 1659  ATP(aq) + (deoxyribonucleotide)_{n}(aq) + (deo...      01DIC/BUR
#
#                  method                                buffer         pH  \
# 0     spectrophotometry                                     -  7.5 - 9.5
# 1     spectrophotometry  sodium pyrophosphate (0.01 mol dm-3)  8.2 - 8.4
# 2           calorimetry                Tris and glycylglycine        8.8
# 3     spectrophotometry            phosphate (0.001 mol dm-3)  7.2 - 9.5
# 4     spectrophotometry             Tris (0.1 mol dm-3) + HCl          8
# ...                 ...                                   ...        ...
# 1655      radioactivity          Hepes (0.050 mol dm-3) + KOH        7.4
# 1656      radioactivity          Hepes (0.050 mol dm-3) + KOH        7.4
# 1657      radioactivity          Hepes (0.050 mol dm-3) + KOH        7.4
# 1658      radioactivity          Hepes (0.050 mol dm-3) + KOH        7.4
# 1659  spectrophotometry            Tris (0.20 mol dm-3) + HCl          7
#
#                     Cofactor Evaluation effort_needed   table_code ECNumber  \
# 0                          -          C           low  80COO/BLA_2  1.1.1.1
# 1                          -          B           low      68ERI_3  1.1.1.1
# 2                          -          A           low      83BRA_4  1.1.1.1
# 3                          -          C           low  59MER/TOM_5  1.1.1.1
# 4                          -          B           low  80COO/BLA_6  1.1.1.1
# ...                      ...        ...           ...          ...      ...
# 1655            Mg(acetate)2          A           low  06AIR2_1505  6.1.1.1
# 1656            Mg(acetate)2          A           low          NaN  6.1.1.1
# 1657            Mg(acetate)2          A           low  06AIR2_1508  6.1.1.1
# 1658            Mg(acetate)2          A           low  06AIR2_1506  6.1.1.1
# 1659  MgCl2 (0.010 mol dm-3)          B          high          NaN  6.5.1.1
#
#                      Enzyme  \
# 0     alcohol dehydrogenase
# 1     alcohol dehydrogenase
# 2     alcohol dehydrogenase
# 3     alcohol dehydrogenase
# 4     alcohol dehydrogenase
# ...                     ...
# 1655   tyrosine-tRNA ligase
# 1656   tyrosine-tRNA ligase
# 1657   tyrosine-tRNA ligase
# 1658   tyrosine-tRNA ligase
# 1659                    NaN
#
#                                               reference curator comment
# 0     Cook, P.F.; Blanchard, J.S.; Cleland, W.W.; Bi...               1
# 1         Eriksson, C.E.; J. Food Sci.; 33, 525 (1968).               1
# 2     Brattlie, W.J.; "Thermochemistry of the Nicoti...               1
# 3     Merritt, A.D.; Tomkins, G.M.; J. Biol. Chem.; ...               1
# 4     Cook, P.F.; Blanchard, J.S.; Cleland, W.W.; Bi...               1
# ...                                                 ...             ...
# 1655                                                NaN           added
# 1656                                                NaN           added
# 1657                                                NaN           added
# 1658                                                NaN           added
# 1659                                                NaN           added
#
# [1660 rows x 17 columns]

# %%
# do the same for actual data
actual_data = pd.read_excel(recuration, sheet_name='actual data')

# %%
actual_data
# Out:
#                                                      id         EC  \
# 0     https://w3id.org/related-to/doi.org/10.5281/ze...    1.1.1.1
# 1     https://w3id.org/related-to/doi.org/10.5281/ze...    1.1.1.1
# 2     https://w3id.org/related-to/doi.org/10.5281/ze...    1.1.1.1
# 3     https://w3id.org/related-to/doi.org/10.5281/ze...    1.1.1.1
# 4     https://w3id.org/related-to/doi.org/10.5281/ze...    1.1.1.1
# ...                                                 ...        ...
# 5740  https://w3id.org/related-to/doi.org/10.5281/ze...    4.3.-.-
# 5741  https://w3id.org/related-to/doi.org/10.5281/ze...   4.1.2.43
# 5742  https://w3id.org/related-to/doi.org/10.5281/ze...   5.3.1.27
# 5743  https://w3id.org/related-to/doi.org/10.5281/ze...  2.4.1.216
# 5744  https://w3id.org/related-to/doi.org/10.5281/ze...  2.4.1.216
#
#      reference_code                                           reaction   K  \
# 0         80COO/BLA  benzyl alcohol(aq) + NAD(aq) = benzaldehyde(aq... NaN
# 1         80COO/BLA  benzyl alcohol(aq) + NAD(aq) = benzaldehyde(aq... NaN
# 2         80COO/BLA  benzyl alcohol(aq) + NAD(aq) = benzaldehyde(aq... NaN
# 3         80COO/BLA  benzyl alcohol(aq) + NAD(aq) = benzaldehyde(aq... NaN
# 4         80COO/BLA  benzyl alcohol(aq) + NAD(aq) = benzaldehyde(aq... NaN
# ...             ...                                                ...  ..
# 5740         +59BLA      THF(aq) + formaldehyde(aq) = 5,10-CH2-THF(aq) NaN
# 5741         +74FER  D-Ribulose 5-phosphate + Formaldehyde = D-arab... NaN
# 5742         +74FER  D-arabino-Hex-3-ulose 6-phosphate = D-Fructose... NaN
# 5743      01AND/LEV  ,-trehalose 6-phosphate(aq) + orthophosphate(a... NaN
# 5744      01AND/LEV  ,-trehalose 6-phosphate(aq) + orthophosphate(a... NaN
#
#       temperature  ionic_strength  p_h  p_mg      K_prime  ...  wrong_value  \
# 0          298.15             NaN  7.5   NaN      0.00098  ...          NaN
# 1          298.15             NaN  8.0   NaN      0.00310  ...          NaN
# 2          298.15             NaN  8.5   NaN      0.00980  ...          NaN
# 3          298.15             NaN  9.0   NaN      0.03100  ...          NaN
# 4          298.15             NaN  9.5   NaN      0.09800  ...          NaN
# ...           ...             ...  ...   ...          ...  ...          ...
# 5740       293.15             NaN  7.2   NaN   7700.00000  ...          NaN
# 5741       303.15             NaN  7.0   NaN  25000.00000  ...          NaN
# 5742       303.15             NaN  7.0   NaN    188.00000  ...          NaN
# 5743       308.15             NaN  7.0   NaN      0.03200  ...          NaN
# 5744       308.15             NaN  6.3   NaN      0.02600  ...          NaN
#
#       ph_not_present_in_pdf  missing_value_to_be_added  kprime_added  \
# 0                       NaN                        NaN           NaN
# 1                       NaN                        NaN           NaN
# 2                       NaN                        NaN           NaN
# 3                       NaN                        NaN           NaN
# 4                       NaN                        NaN           NaN
# ...                     ...                        ...           ...
# 5740                    NaN                        NaN           NaN
# 5741                    NaN                        NaN           NaN
# 5742                    NaN                        NaN           NaN
# 5743                    NaN                        NaN           NaN
# 5744                    NaN                        NaN           NaN
#
#      misannotated_value_type  todo_check_in_primary_literature  \
# 0                        NaN                               NaN
# 1                        NaN                               NaN
# 2                        NaN                               NaN
# 3                        NaN                               NaN
# 4                        NaN                               NaN
# ...                      ...                               ...
# 5740                     NaN                               NaN
# 5741                     NaN                               NaN
# 5742                     NaN                               NaN
# 5743                     NaN                               NaN
# 5744                     NaN                               NaN
#
#       value_given_with_approximate_sign  virtual_entry  \
# 0                                   NaN            NaN
# 1                                   NaN            NaN
# 2                                   NaN            NaN
# 3                                   NaN            NaN
# 4                                   NaN            NaN
# ...                                 ...            ...
# 5740                                NaN            NaN
# 5741                                NaN            NaN
# 5742                                NaN            NaN
# 5743                                NaN            NaN
# 5744                                NaN            NaN
#
#       typo_in_pdf_corrected_in_situ  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 5740                            NaN
# 5741                            NaN
# 5742                            NaN
# 5743                            NaN
# 5744                            NaN
#
#                                         additional data
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5740                                    [added by Elad]
# 5741                                    [added by Elad]
# 5742                                    [added by Elad]
# 5743  [presumably should have been in part 7, becaus...
# 5744  [presumably should have been in part 7, becaus...
#
# [5745 rows x 30 columns]

# %%
# extract empty "id" rows into new df for further analysis
unmapped_rxns = actual_data[actual_data["id"].isnull()]

# %%
unmapped_rxns
# Out:
#        id       EC reference_code  \
# 82    NaN  1.1.1.1      38SCH/HEL
# 83    NaN  1.1.1.1      38SCH/HEL
# 84    NaN  1.1.1.1      38SCH/HEL
# 85    NaN  1.1.1.1      38SCH/HEL
# 86    NaN  1.1.1.1      38SCH/HEL
# ...   ...      ...            ...
# 5558  NaN  4.6.1.3      02TEW/HAW
# 5560  NaN  4.6.1.3      02TEW/HAW
# 5564  NaN  5.1.1.1      03WAT/YAM
# 5630  NaN  6.1.1.1         06AIR2
# 5734  NaN  6.5.1.1      01DIC/BUR
#
#                                                reaction   K  temperature  \
# 82    ethanol(aq) + desamino NAD(aq) = acetaldehyde(... NaN       298.15
# 83    ethanol(aq) + desamino NAD(aq) = acetaldehyde(... NaN       298.15
# 84    ethanol(aq) + desamino NAD(aq) = acetaldehyde(... NaN       298.15
# 85    ethanol(aq) + desamino NAD(aq) = acetaldehyde(... NaN       298.15
# 86    ethanol(aq) + desamino NAD(aq) = acetaldehyde(... NaN       298.15
# ...                                                 ...  ..          ...
# 5558  2-dehydro-3-deoxy-D-arabino-heptonate 7-phosph... NaN       298.15
# 5560  2-dehydro-3-deoxy-D-arabino-heptonate 7-phosph... NaN       298.15
# 5564                      L-alanine(aq) = D-alanine(aq) NaN       310.15
# 5630  ATP(aq) + L-tyrosine(aq) + tRNA-Tyr(aq) = AMP(... NaN       303.15
# 5734  ATP(aq) + (deoxyribonucleotide)_n(aq) + (deoxy... NaN       298.15
#
#       ionic_strength   p_h  p_mg       K_prime  ...  wrong_value  \
# 82               NaN  6.39   NaN      0.000009  ...          NaN
# 83               NaN  6.60   NaN      0.000030  ...          NaN
# 84               NaN  6.85   NaN      0.000051  ...          NaN
# 85               NaN  7.18   NaN      0.000150  ...          NaN
# 86               NaN  7.31   NaN      0.000230  ...          NaN
# ...              ...   ...   ...           ...  ...          ...
# 5558             NaN  7.50   NaN      4.600000  ...          NaN
# 5560             NaN  7.46   NaN           NaN  ...          NaN
# 5564             NaN  9.00   NaN      0.800000  ...          NaN
# 5630             NaN  7.40  1.74      3.030000  ...          NaN
# 5734             NaN  7.00   NaN  38900.000000  ...          NaN
#
#       ph_not_present_in_pdf  missing_value_to_be_added  kprime_added  \
# 82                      NaN                        NaN           NaN
# 83                      NaN                        NaN           NaN
# 84                      NaN                        NaN           NaN
# 85                      NaN                        NaN           NaN
# 86                      NaN                        NaN           NaN
# ...                     ...                        ...           ...
# 5558                    NaN                        NaN           NaN
# 5560                    NaN                        NaN           NaN
# 5564                    NaN                        NaN           NaN
# 5630                    NaN                        NaN           NaN
# 5734                    NaN                        NaN           NaN
#
#      misannotated_value_type  todo_check_in_primary_literature  \
# 82                       NaN                               NaN
# 83                       NaN                               NaN
# 84                       NaN                               NaN
# 85                       NaN                               NaN
# 86                       NaN                               NaN
# ...                      ...                               ...
# 5558                     NaN                               NaN
# 5560                     NaN                               NaN
# 5564                     NaN                               1.0
# 5630                     NaN                               NaN
# 5734                     NaN                               NaN
#
#       value_given_with_approximate_sign  virtual_entry  \
# 82                                  NaN            NaN
# 83                                  NaN            NaN
# 84                                  NaN            NaN
# 85                                  NaN            NaN
# 86                                  NaN            NaN
# ...                                 ...            ...
# 5558                                NaN            NaN
# 5560                                NaN            NaN
# 5564                                NaN            NaN
# 5630                                NaN            NaN
# 5734                                NaN            NaN
#
#       typo_in_pdf_corrected_in_situ  \
# 82                              NaN
# 83                              NaN
# 84                              NaN
# 85                              NaN
# 86                              NaN
# ...                             ...
# 5558                            NaN
# 5560                            NaN
# 5564                            NaN
# 5630                            NaN
# 5734                            NaN
#
#                                         additional data
# 82                                                  NaN
# 83                                                  NaN
# 84                                                  NaN
# 85                                                  NaN
# 86                                                  NaN
# ...                                                 ...
# 5558  I_m = 0.065 mol/kg; [Kprime noted as K'm]; [co...
# 5560  I_m = 0.07 mol/kg; pMn = 3.30; [corrects https...
# 5564  [corrects https://w3id.org/related-to/doi.org/...
# 5630              c(Mg2+) = 18 mM; c(spermidine) = 1 mM
# 5734                                                NaN
#
# [1201 rows x 30 columns]

# %%
print(unmapped_rxns.columns)
# Out:
# Index(['id', 'EC', 'reference_code', 'reaction', 'K', 'temperature',
#        'ionic_strength', 'p_h', 'p_mg', 'K_prime', 'part', 'page', 'col l/r',
#        'table from top', 'entry nr',
#        'authoritative_version_of_a_duplicate_table', 'duplicate_table',
#        'solvent_reaction', 'enthalpy', 'error_correction', 'wrong_value',
#        'ph_not_present_in_pdf', 'missing_value_to_be_added', 'kprime_added',
#        'misannotated_value_type', 'todo_check_in_primary_literature',
#        'value_given_with_approximate_sign', 'virtual_entry',
#        'typo_in_pdf_corrected_in_situ', 'additional data'],
#       dtype='object')

# %% [markdown]
# 'reference_code' contains what we can potentially map to the values in the more reliable **table_metadata** dataframe (the reactions have been corrected for in this df)
#
# To map them to retrieve only reliable reactions which havent been mapped:
# - Extract both reference_code and reaction from unmapped_rxns
#
# - Compare these to reference_code and reaction in table_metadata
#
# - Save only reactions where both of these match in both dfs
#
# - Will produce a set of unmapped reactions, which have been corrected for
#
# - Proceed to work of this new set of reactions

# %% [markdown]
# ## Mapping reactions/ref codes from actual_data to table_metadata

# %%
# Perform an inner join on the columns "reference_code" and "reaction"
matched_data = table_metadata.merge(
    unmapped_rxns,
    on=["reference_code", "reaction"],  # Columns to match on
    how="inner"  # Only keep rows where matches are found
)

# Display the resulting DataFrame
print(matched_data)
# Out:
#      part_x  page_x  col l/r_x  table from top_x  \
# 0         1     525          2                 2
# 1         1     525          2                 2
# 2         1     525          2                 2
# 3         1     525          2                 2
# 4         1     525          2                 2
# ..      ...     ...        ...               ...
# 447       7    1381          1                 1
# 448       7    1381          1                 2
# 449       7    1381          1                 2
# 450       7    1381          2                 1
# 451       7    1385          1                 2
#
#                                               reaction reference_code  \
# 0    ethanol(aq) + desamino NAD(aq) = acetaldehyde(...      38SCH/HEL
# 1    ethanol(aq) + desamino NAD(aq) = acetaldehyde(...      38SCH/HEL
# 2    ethanol(aq) + desamino NAD(aq) = acetaldehyde(...      38SCH/HEL
# 3    ethanol(aq) + desamino NAD(aq) = acetaldehyde(...      38SCH/HEL
# 4    ethanol(aq) + desamino NAD(aq) = acetaldehyde(...      38SCH/HEL
# ..                                                 ...            ...
# 447  2-dehydro-3-deoxy-D-arabino-heptonate 7-phosph...      02TEW/HAW
# 448  2-dehydro-3-deoxy-D-arabino-heptonate 7-phosph...      02TEW/HAW
# 449  2-dehydro-3-deoxy-D-arabino-heptonate 7-phosph...      02TEW/HAW
# 450                      L-alanine(aq) = D-alanine(aq)      03WAT/YAM
# 451  ATP(aq) + L-tyrosine(aq) + tRNA-Tyr(aq) = AMP(...         06AIR2
#
#                 method                            buffer           pH  \
# 0    spectrophotometry                                 -  6.39 - 8.06
# 1    spectrophotometry                                 -  6.39 - 8.06
# 2    spectrophotometry                                 -  6.39 - 8.06
# 3    spectrophotometry                                 -  6.39 - 8.06
# 4    spectrophotometry                                 -  6.39 - 8.06
# ..                 ...                               ...          ...
# 447     chromatography                      Hepes + NaOH          7.5
# 448        calorimetry                      Hepes + NaOH          7.5
# 449        calorimetry                      Hepes + NaOH          7.5
# 450     chromatography  Bis-tris propane (0.10 mol dm-3)            9
# 451      radioactivity      Hepes (0.050 mol dm-3) + KOH          7.4
#
#                  Cofactor  ... wrong_value ph_not_present_in_pdf  \
# 0                       -  ...         NaN                   NaN
# 1                       -  ...         NaN                   NaN
# 2                       -  ...         NaN                   NaN
# 3                       -  ...         NaN                   NaN
# 4                       -  ...         NaN                   NaN
# ..                    ...  ...         ...                   ...
# 447  NAD(ox) and Zn2+(aq)  ...         NaN                   NaN
# 448  NAD(ox) and Zn2+(aq)  ...         NaN                   NaN
# 449  NAD(ox) and Zn2+(aq)  ...         NaN                   NaN
# 450                     -  ...         NaN                   NaN
# 451          Mg(acetate)2  ...         NaN                   NaN
#
#     missing_value_to_be_added kprime_added misannotated_value_type  \
# 0                         NaN          NaN                     NaN
# 1                         NaN          NaN                     NaN
# 2                         NaN          NaN                     NaN
# 3                         NaN          NaN                     NaN
# 4                         NaN          NaN                     NaN
# ..                        ...          ...                     ...
# 447                       NaN          NaN                     NaN
# 448                       NaN          NaN                     NaN
# 449                       NaN          NaN                     NaN
# 450                       NaN          NaN                     NaN
# 451                       NaN          NaN                     NaN
#
#     todo_check_in_primary_literature value_given_with_approximate_sign  \
# 0                                NaN                               NaN
# 1                                NaN                               NaN
# 2                                NaN                               NaN
# 3                                NaN                               NaN
# 4                                NaN                               NaN
# ..                               ...                               ...
# 447                              NaN                               NaN
# 448                              NaN                               NaN
# 449                              NaN                               NaN
# 450                              1.0                               NaN
# 451                              NaN                               NaN
#
#     virtual_entry typo_in_pdf_corrected_in_situ  \
# 0             NaN                           NaN
# 1             NaN                           NaN
# 2             NaN                           NaN
# 3             NaN                           NaN
# 4             NaN                           NaN
# ..            ...                           ...
# 447           NaN                           NaN
# 448           NaN                           NaN
# 449           NaN                           NaN
# 450           NaN                           NaN
# 451           NaN                           NaN
#
#                                        additional data
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 447  I_m = 0.07 mol/kg; pMn = 3.30; [corrects https...
# 448  I_m = 0.065 mol/kg; [Kprime noted as K'm]; [co...
# 449  I_m = 0.07 mol/kg; pMn = 3.30; [corrects https...
# 450  [corrects https://w3id.org/related-to/doi.org/...
# 451              c(Mg2+) = 18 mM; c(spermidine) = 1 mM
#
# [452 rows x 45 columns]

# %%
matched_data.to_csv('/home/jackmcgoldrick/openTECR/results/freeText_rxns_tobe_mapped.csv')

# %%
matched_data
# Out:
#      part_x  page_x  col l/r_x  table from top_x  \
# 0         1     525          2                 2
# 1         1     525          2                 2
# 2         1     525          2                 2
# 3         1     525          2                 2
# 4         1     525          2                 2
# ..      ...     ...        ...               ...
# 447       7    1381          1                 1
# 448       7    1381          1                 2
# 449       7    1381          1                 2
# 450       7    1381          2                 1
# 451       7    1385          1                 2
#
#                                               reaction reference_code  \
# 0    ethanol(aq) + desamino NAD(aq) = acetaldehyde(...      38SCH/HEL
# 1    ethanol(aq) + desamino NAD(aq) = acetaldehyde(...      38SCH/HEL
# 2    ethanol(aq) + desamino NAD(aq) = acetaldehyde(...      38SCH/HEL
# 3    ethanol(aq) + desamino NAD(aq) = acetaldehyde(...      38SCH/HEL
# 4    ethanol(aq) + desamino NAD(aq) = acetaldehyde(...      38SCH/HEL
# ..                                                 ...            ...
# 447  2-dehydro-3-deoxy-D-arabino-heptonate 7-phosph...      02TEW/HAW
# 448  2-dehydro-3-deoxy-D-arabino-heptonate 7-phosph...      02TEW/HAW
# 449  2-dehydro-3-deoxy-D-arabino-heptonate 7-phosph...      02TEW/HAW
# 450                      L-alanine(aq) = D-alanine(aq)      03WAT/YAM
# 451  ATP(aq) + L-tyrosine(aq) + tRNA-Tyr(aq) = AMP(...         06AIR2
#
#                 method                            buffer           pH  \
# 0    spectrophotometry                                 -  6.39 - 8.06
# 1    spectrophotometry                                 -  6.39 - 8.06
# 2    spectrophotometry                                 -  6.39 - 8.06
# 3    spectrophotometry                                 -  6.39 - 8.06
# 4    spectrophotometry                                 -  6.39 - 8.06
# ..                 ...                               ...          ...
# 447     chromatography                      Hepes + NaOH          7.5
# 448        calorimetry                      Hepes + NaOH          7.5
# 449        calorimetry                      Hepes + NaOH          7.5
# 450     chromatography  Bis-tris propane (0.10 mol dm-3)            9
# 451      radioactivity      Hepes (0.050 mol dm-3) + KOH          7.4
#
#                  Cofactor  ... wrong_value ph_not_present_in_pdf  \
# 0                       -  ...         NaN                   NaN
# 1                       -  ...         NaN                   NaN
# 2                       -  ...         NaN                   NaN
# 3                       -  ...         NaN                   NaN
# 4                       -  ...         NaN                   NaN
# ..                    ...  ...         ...                   ...
# 447  NAD(ox) and Zn2+(aq)  ...         NaN                   NaN
# 448  NAD(ox) and Zn2+(aq)  ...         NaN                   NaN
# 449  NAD(ox) and Zn2+(aq)  ...         NaN                   NaN
# 450                     -  ...         NaN                   NaN
# 451          Mg(acetate)2  ...         NaN                   NaN
#
#     missing_value_to_be_added kprime_added misannotated_value_type  \
# 0                         NaN          NaN                     NaN
# 1                         NaN          NaN                     NaN
# 2                         NaN          NaN                     NaN
# 3                         NaN          NaN                     NaN
# 4                         NaN          NaN                     NaN
# ..                        ...          ...                     ...
# 447                       NaN          NaN                     NaN
# 448                       NaN          NaN                     NaN
# 449                       NaN          NaN                     NaN
# 450                       NaN          NaN                     NaN
# 451                       NaN          NaN                     NaN
#
#     todo_check_in_primary_literature value_given_with_approximate_sign  \
# 0                                NaN                               NaN
# 1                                NaN                               NaN
# 2                                NaN                               NaN
# 3                                NaN                               NaN
# 4                                NaN                               NaN
# ..                               ...                               ...
# 447                              NaN                               NaN
# 448                              NaN                               NaN
# 449                              NaN                               NaN
# 450                              1.0                               NaN
# 451                              NaN                               NaN
#
#     virtual_entry typo_in_pdf_corrected_in_situ  \
# 0             NaN                           NaN
# 1             NaN                           NaN
# 2             NaN                           NaN
# 3             NaN                           NaN
# 4             NaN                           NaN
# ..            ...                           ...
# 447           NaN                           NaN
# 448           NaN                           NaN
# 449           NaN                           NaN
# 450           NaN                           NaN
# 451           NaN                           NaN
#
#                                        additional data
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 447  I_m = 0.07 mol/kg; pMn = 3.30; [corrects https...
# 448  I_m = 0.065 mol/kg; [Kprime noted as K'm]; [co...
# 449  I_m = 0.07 mol/kg; pMn = 3.30; [corrects https...
# 450  [corrects https://w3id.org/related-to/doi.org/...
# 451              c(Mg2+) = 18 mM; c(spermidine) = 1 mM
#
# [452 rows x 45 columns]

# %% [markdown]
# 451 reactions returned, many of which are the same, but different due to their pH etc. recorded in actual data.
#
# - Now need to extract metabolite names from this list using regex pattern, ensuring no duplicates are included

# %%
# access the contents of reaction column
reactions = matched_data['reaction']

reactions
# Out:
# 0      ethanol(aq) + desamino NAD(aq) = acetaldehyde(...
# 1      ethanol(aq) + desamino NAD(aq) = acetaldehyde(...
# 2      ethanol(aq) + desamino NAD(aq) = acetaldehyde(...
# 3      ethanol(aq) + desamino NAD(aq) = acetaldehyde(...
# 4      ethanol(aq) + desamino NAD(aq) = acetaldehyde(...
#                              ...
# 447    2-dehydro-3-deoxy-D-arabino-heptonate 7-phosph...
# 448    2-dehydro-3-deoxy-D-arabino-heptonate 7-phosph...
# 449    2-dehydro-3-deoxy-D-arabino-heptonate 7-phosph...
# 450                        L-alanine(aq) = D-alanine(aq)
# 451    ATP(aq) + L-tyrosine(aq) + tRNA-Tyr(aq) = AMP(...
# Name: reaction, Length: 452, dtype: object

# %% [markdown]
# ### Extracting metabolite names from reactions

# %%
matched_data['metabolites'] = matched_data['reaction'].str.findall(r"([A-Za-z0-9\s,\.\-'\(\)]+)(?=\s*\+|\s*\=|$)")

# %%
matched_data['metabolites']
# Out:
# 0      [ethanol(aq) ,  desamino NAD(aq) ,  acetaldehy...
# 1      [ethanol(aq) ,  desamino NAD(aq) ,  acetaldehy...
# 2      [ethanol(aq) ,  desamino NAD(aq) ,  acetaldehy...
# 3      [ethanol(aq) ,  desamino NAD(aq) ,  acetaldehy...
# 4      [ethanol(aq) ,  desamino NAD(aq) ,  acetaldehy...
#                              ...
# 447    [2-dehydro-3-deoxy-D-arabino-heptonate 7-phosp...
# 448    [2-dehydro-3-deoxy-D-arabino-heptonate 7-phosp...
# 449    [2-dehydro-3-deoxy-D-arabino-heptonate 7-phosp...
# 450                     [L-alanine(aq) ,  D-alanine(aq)]
# 451    [ATP(aq) ,  L-tyrosine(aq) ,  tRNA-Tyr(aq) ,  ...
# Name: metabolites, Length: 452, dtype: object

# %%
# need to strip (aq) etc. from each
def strip_state_specifiers(metabolites):
    if isinstance(metabolites, list):
        return [re.sub(r'\s*\(.*?\)', '', metabolite) for metabolite in metabolites]
    return metabolites

# %%
# apply to our use case
matched_data['metabolites'] = matched_data['metabolites'].apply(strip_state_specifiers)

print(matched_data)
# Out:
#      part_x  page_x  col l/r_x  table from top_x  \
# 0         1     525          2                 2
# 1         1     525          2                 2
# 2         1     525          2                 2
# 3         1     525          2                 2
# 4         1     525          2                 2
# ..      ...     ...        ...               ...
# 447       7    1381          1                 1
# 448       7    1381          1                 2
# 449       7    1381          1                 2
# 450       7    1381          2                 1
# 451       7    1385          1                 2
#
#                                               reaction reference_code  \
# 0    ethanol(aq) + desamino NAD(aq) = acetaldehyde(...      38SCH/HEL
# 1    ethanol(aq) + desamino NAD(aq) = acetaldehyde(...      38SCH/HEL
# 2    ethanol(aq) + desamino NAD(aq) = acetaldehyde(...      38SCH/HEL
# 3    ethanol(aq) + desamino NAD(aq) = acetaldehyde(...      38SCH/HEL
# 4    ethanol(aq) + desamino NAD(aq) = acetaldehyde(...      38SCH/HEL
# ..                                                 ...            ...
# 447  2-dehydro-3-deoxy-D-arabino-heptonate 7-phosph...      02TEW/HAW
# 448  2-dehydro-3-deoxy-D-arabino-heptonate 7-phosph...      02TEW/HAW
# 449  2-dehydro-3-deoxy-D-arabino-heptonate 7-phosph...      02TEW/HAW
# 450                      L-alanine(aq) = D-alanine(aq)      03WAT/YAM
# 451  ATP(aq) + L-tyrosine(aq) + tRNA-Tyr(aq) = AMP(...         06AIR2
#
#                 method                            buffer           pH  \
# 0    spectrophotometry                                 -  6.39 - 8.06
# 1    spectrophotometry                                 -  6.39 - 8.06
# 2    spectrophotometry                                 -  6.39 - 8.06
# 3    spectrophotometry                                 -  6.39 - 8.06
# 4    spectrophotometry                                 -  6.39 - 8.06
# ..                 ...                               ...          ...
# 447     chromatography                      Hepes + NaOH          7.5
# 448        calorimetry                      Hepes + NaOH          7.5
# 449        calorimetry                      Hepes + NaOH          7.5
# 450     chromatography  Bis-tris propane (0.10 mol dm-3)            9
# 451      radioactivity      Hepes (0.050 mol dm-3) + KOH          7.4
#
#                  Cofactor  ... ph_not_present_in_pdf  \
# 0                       -  ...                   NaN
# 1                       -  ...                   NaN
# 2                       -  ...                   NaN
# 3                       -  ...                   NaN
# 4                       -  ...                   NaN
# ..                    ...  ...                   ...
# 447  NAD(ox) and Zn2+(aq)  ...                   NaN
# 448  NAD(ox) and Zn2+(aq)  ...                   NaN
# 449  NAD(ox) and Zn2+(aq)  ...                   NaN
# 450                     -  ...                   NaN
# 451          Mg(acetate)2  ...                   NaN
#
#     missing_value_to_be_added kprime_added misannotated_value_type  \
# 0                         NaN          NaN                     NaN
# 1                         NaN          NaN                     NaN
# 2                         NaN          NaN                     NaN
# 3                         NaN          NaN                     NaN
# 4                         NaN          NaN                     NaN
# ..                        ...          ...                     ...
# 447                       NaN          NaN                     NaN
# 448                       NaN          NaN                     NaN
# 449                       NaN          NaN                     NaN
# 450                       NaN          NaN                     NaN
# 451                       NaN          NaN                     NaN
#
#     todo_check_in_primary_literature value_given_with_approximate_sign  \
# 0                                NaN                               NaN
# 1                                NaN                               NaN
# 2                                NaN                               NaN
# 3                                NaN                               NaN
# 4                                NaN                               NaN
# ..                               ...                               ...
# 447                              NaN                               NaN
# 448                              NaN                               NaN
# 449                              NaN                               NaN
# 450                              1.0                               NaN
# 451                              NaN                               NaN
#
#     virtual_entry typo_in_pdf_corrected_in_situ  \
# 0             NaN                           NaN
# 1             NaN                           NaN
# 2             NaN                           NaN
# 3             NaN                           NaN
# 4             NaN                           NaN
# ..            ...                           ...
# 447           NaN                           NaN
# 448           NaN                           NaN
# 449           NaN                           NaN
# 450           NaN                           NaN
# 451           NaN                           NaN
#
#                                        additional data  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 447  I_m = 0.07 mol/kg; pMn = 3.30; [corrects https...
# 448  I_m = 0.065 mol/kg; [Kprime noted as K'm]; [co...
# 449  I_m = 0.07 mol/kg; pMn = 3.30; [corrects https...
# 450  [corrects https://w3id.org/related-to/doi.org/...
# 451              c(Mg2+) = 18 mM; c(spermidine) = 1 mM
#
#                                            metabolites
# 0    [ethanol ,  desamino NAD ,  acetaldehyde ,  de...
# 1    [ethanol ,  desamino NAD ,  acetaldehyde ,  de...
# 2    [ethanol ,  desamino NAD ,  acetaldehyde ,  de...
# 3    [ethanol ,  desamino NAD ,  acetaldehyde ,  de...
# 4    [ethanol ,  desamino NAD ,  acetaldehyde ,  de...
# ..                                                 ...
# 447  [2-dehydro-3-deoxy-D-arabino-heptonate 7-phosp...
# 448  [2-dehydro-3-deoxy-D-arabino-heptonate 7-phosp...
# 449  [2-dehydro-3-deoxy-D-arabino-heptonate 7-phosp...
# 450                           [L-alanine ,  D-alanine]
# 451  [ATP ,  L-tyrosine ,  tRNA-Tyr ,  AMP ,  pyrop...
#
# [452 rows x 46 columns]

# %%
matched_data['metabolites']
# Out:
# 0      [ethanol ,  desamino NAD ,  acetaldehyde ,  de...
# 1      [ethanol ,  desamino NAD ,  acetaldehyde ,  de...
# 2      [ethanol ,  desamino NAD ,  acetaldehyde ,  de...
# 3      [ethanol ,  desamino NAD ,  acetaldehyde ,  de...
# 4      [ethanol ,  desamino NAD ,  acetaldehyde ,  de...
#                              ...
# 447    [2-dehydro-3-deoxy-D-arabino-heptonate 7-phosp...
# 448    [2-dehydro-3-deoxy-D-arabino-heptonate 7-phosp...
# 449    [2-dehydro-3-deoxy-D-arabino-heptonate 7-phosp...
# 450                             [L-alanine ,  D-alanine]
# 451    [ATP ,  L-tyrosine ,  tRNA-Tyr ,  AMP ,  pyrop...
# Name: metabolites, Length: 452, dtype: object

# %% [markdown]
# State specifiers removed, now to remove duplicates

# %%
# Initialising a set to store unique metabolite names
unique_mets = set()

# loop through lists in metabolites 
for mets in matched_data['metabolites']:
    if isinstance(mets, list):
        unique_mets.update(mets)

# convert set back to a list of unique metabolites
unique_mets_list = list(unique_mets)

print(unique_mets_list)
# Out:
# [' phosphoribosyl-1-O-', '', ' 2 L-methionine', ' L-carnitine ', ' cyclohexanol ', 'pyrophosphate ', ' 4-methyl-2-oxopentanooate ', ' pyrophosphate', ' L-tyrosine ', 'acetyl phosphate ', 'D-glucose 6-phosphate ', ' 15-oxo-prostaglandin E2 ', 'phosphorylcholine ', ' thiopyrophosphate ', 'D-fructose 1,6-bisphosphate ', ' D-sedoheptulose ', ' methyl viologen ', 'glycerol ', ' tRNA-Tyr ', ' diphosphate', ' acetyl phosphate ', ' H2O ', 'glycolate ', " 4'-methylacetanilide ", ' pyrophosphate ', ' D-glyceraldehyde 3-phosphate ', ' cyclooctanol ', 'ADP ', ' cis-hex-2-enoyl-CoA ', 'L-phenylalanine ', 'cycloheptanone', 'S-methylmethionine ', ' 2 ammonia ', ' maleate ', " 4'-chloroaniline", ' heteronicotinathiamine', ' desamino NAD ', ' dihydroxyacetone ', ' nicotinamide ', 'L-glutamine ', ' propionaldehyde', ' D-glycine', ' palmitic acid', '5-deoxypyridoxamine ', ' L-glutamate ', 'L-leucine ', ' 8 H2O ', ' cis-aconitate ', ' ADP-N1-oxide ', ' 1-butanol', " 4'-acetylacetanalide ", ' D-glyceraldehyde 3-phosphate', '-(', ' aniline', ' glycerone phosphate ', '2-propanol ', ' NADP', ' L-fructose', ' 3-ureidopropanoic acid', '6-amino-D-glucose 6-phosphate ', ' norpyridoxal ', 'L-glutamate ', ' phosphocreatine', ' 3-acetylpyridine adenine dinucleotide', ' carbon dioxide', ' ethyl 4-acetamidobenzoate ', ' 2 orthophosphate', 'cyclobutanone', ' 3-dehydroquinate ', 'cyclohexanone', ' oxaloacetate ', ' L-aspartate ', 'cycloheptaamylose ', 'D-rhamnose ', ' ethyl 4-aminobenzoate', ' pyruvate ', " 4'-aminoacetophenone", 'L-O-phosphoserine ', ' 5-oxo-D-gluconate ', " 4'-cyanoacetanilide ", ' cyclocreatine ', ' 7 D-glucose', ' glyoxylate', ' UDP-D-fucose', '5,6-dihydrouracil ', ' orthophosphate ', 'cyclohexaamylose ', ' H2O2', 'ethanol ', ' 2-oxovalerate ', ' L-erythrulose ', 'L-alanine ', ' corrinoid protein ', ' arachidonic acid', ' 6 D-glucose', ' NADPH', '5,6-dideoxyfructose 1-phosphate ', 'D-glycero-D-glucoheptitol ', ' sulfate ', " 4'-cyanoaniline", ' formate', ' ATP-N1-oxide ', ' phosphate ', ' CoA', 'benzyl alcohol', ' 3-acetylpyridine adenine dinucleotide ', ' 4-methyl-5--thiazole ', ' CoA ', 'L-threitol ', ' thymine ', ' ADP ', ' H2O', ' L-butyrylcarnitine', ' 6-amino-D-glucose 6-phosphate', '1-glycerol 3-phosphate ', ' ethanolamine ', ' citrate', ' dephosvitin', '-malate ', ' enol-oxaloacetate', ' benzyl acetate', 'cyclopentanone', ' L-tyrosyl-tRNA-Tyr', ' acetone', ' NADP ', ' NADPH ', ' 6-amino-D-glucose ', ' L-methionine', ' p-toluidine', ' glyoxylate ', ' UMP', ' 3-phospho-D-glyceroyl phosphate', ' GDP ', ' pyruvate kinase ', ' 2 H2O ', ' D-fructose 6-phosphate', '-3-hydroxyhexanoyl-CoA ', ' L-tryptophan ', ' imidazole ', ' 2 H2O', ' heteroanilithiamine', "orotidine 5'-phosphate ", ' L-alanine', ' lysozyme ', ' creatine ', ' 2-methylmaleate ', '2-heptanone', '5,6,7,8-tetrahydrofolate ', 'phosphoenolpyruvate ', 'anandamide ', ' butyl acetate ', 'butyryl-CoA ', 'thiamine ', 'acetyl-CoA ', ' D-glucose ', ' 6-amino-D-fructose 6-phosphate', ' cycloheptanol ', ' phosphonate ', ' hypoxanthine', ' phospholysozyme', '4-dimethylaminomethylbenzylamine ', "4-aminoazobenzene-4'-sulfonic acid ", 'isocitrate ', ' acetyl-CoA ', 'norpyridoxamine ', ' 5-deoxypyridoxal ', ' choline ', ' D-alanine', ' carbon monoxide ', ' 8 D-glucose', ' cyclopentanol ', '-2-heptanol ', 'D-glyceraldehyde 3-phosphate ', ' N-acetylimidazole ', ' 6-aminopenicillanic acid ', ' desamino NADH ', ' 2-oxoglutaramate ', ' phosvitin ', ' acetanilide ', ' 3-phospho-D-glycerate', 'methyl viologen ', ' phosphoenolpyruvate kinase', '2-octanone', 'L-asparagine ', ' AP-NADH ', ' O2 ', ' glycerone phosphate', ' acetone ', ' succinate ', ' L-glutamate', 'urea ', ' AP-NAD ', ' D-glucose 6-phosphate', 'keto-oxaloacetate ', ' D-fructose 1,6-bisphosphate', ' succinyl-CoA', ' NADH', " 4'-chloroacetanilide ", ' 5-methyluridine ', "5'-phosphate ", ')-2-octanol ', ' orthophosphate', ' 7 H2O ', ' 6 H2O ', 'citrate ', 'L-valine ', ' orotate ', '2-dehydro-3-deoxy-D-arabino-heptonate 7-phosphate ', ' 4-d ...

# %%
print(len(unique_mets_list)) # the list of metabolites before whitespace stripping
# Out:
# 259

# %%
# convert the metabolite list into df to inspect further for mistakes
unique_mets_df = pd.DataFrame(unique_mets_list, columns=['Metabolites'])

# %%
unique_mets_df.to_csv('/home/jackmcgoldrick/openTECR/results/list_metabolites_tobe_mapped.csv', index=False)

# %% [markdown]
# #### Stripping Whitespace from Each Compound, For correctness in SPARQL Query

# %%
############## stripping whitespace to xclude unwanted strings 

# Initialising a set to store unique metabolite names
unique_mets_stripped = set()

# loop through lists in metabolites 
for mets in matched_data['metabolites']:
    if isinstance(mets, list):
        unique_mets.update(m.strip() for m in mets)

# convert set back to a list of unique metabolites
unique_mets_striiped_list = list(unique_mets)

print(unique_mets_striiped_list)
# Out:
# ['', 'D-sedoheptulose', 'L-glutamate', 'carbon monoxide', 'phospholysozyme', 'cyclobutanol', 'D-rhamnulose', 'GTP', '-3-hydroxyhexanoyl-CoA', '2-oxo-4-methiolbutyrate', 'ADP-N1-oxide', 'heteroanilithiamine', 'cyclooctaamylose', '3-phospho-D-glyceroyl phosphate', 'L-O-phosphoserine', 'ethanol', 'cycloheptanone', 'L-homocysteine', 'L-mannose', '3-hydroxypyridine-4-aldehyde', 'NADH', 'L-glutamine', 'norpyridoxamine', ')-2-octanol', '2-oxoglutarate', 'O2', 'dihydroxyacetone', '6 D-glucose', "5'-phosphate", 'butyl acetate', '2-phospho-D-glycerate', 'prostaglandin E2', 'cyclohexanol', '-(', '-2-heptanol', '8 D-glucose', 'NADPH', 'GDP', 'cyclobutanone', 'cyclohexanone', 'acetone', 'phosphorylcholine', 'ethanolamine', '2-propanol', 'butyryl-CoA', 'L-tyrosine', '2-oxoglutaramate', '7,8-dihydrofolate', 'thiopyrophosphate', '5,6,7,8-tetrahydrofolate', 'phosphocreatine', 'UMP', '2-oxoisocaproate', '-malate', '2-dehydro-3-deoxy-D-arabino-heptonate 7-phosphate', '4-methyl-5--thiazole', 'L-butyrylcarnitine', 'D-gluconate', "4'-acetylacetanalide", 'creatine', 'D-glucose', '2-oxovalerate', 'ethyl 4-aminobenzoate', 'formate', '4-dimethylaminomethylbenzylamine', '3-acetylpyridine adenine dinucleotide', 'L-tyrosyl-tRNA-Tyr', '2 H2O', 'ammonia', 'D-rhamnose', "4-aminoazobenzene-4'-sulfonic acid", 'NAD', 'pyrophosphate', 'D-glyceraldehyde 3-phosphate', 'L-fructose', 'propionaldehyde', 'inosine', 'palmitoylethanolamide', 'phosphate', 'D-fructose 6-phosphate', '3-hydroxy-4-aminomethylpyridine', 'AP-NAD', 'cis-aconitate', '1-glycerol 3-phosphate', 'AP-NADH', 'cyclopentanol', 'methyl viologen', 'CoA', 'D-ribulose', 'L-valine', 'AMP', "orotidine 5'-phosphate", 'maleate', 'cyclopentanone', 'desamino NAD', 'phosphoenolpyruvate kinase', 'D-fructose 1,6-bisphosphate', 'phosphocyclocreatine', '6 H2O', 'L-leucine', '2 ammonia', 'diphosphate', '6-amino-D-fructose 6-phosphate', 'ethyl 4-acetamidobenzoate', 'glycerol', 'cyclooctanol', '1-butanol', '8 H2O', 'heteronicotinathiamine', '-2-methylmalate', 'benzyl alcohol', 'carbon dioxide', 'glycerone phosphate', 'D-glucose 6-phosphate', 'imidazole', '2-heptanone', 'L-threitol', 'methylcorrinoid protein', '4 reduced cytochrome c', '6-aminopenicillanic acid', 'palmitic acid', 'cycloheptaamylose', '3-dehydroquinate', "4'-chloroaniline", 'dephosvitin', 'H2O', 'cyclocreatine', 'L-carnitine', 'phosphonate', 'citrate', "4'-chloroacetanilide", 'L-methionine', 'L-asparagine', "4'-cyanoaniline", 'acetyl phosphate', '2 orthophosphate', 'lysozyme', 'L-tryptophan', 'NADP', '3-phospho-D-glycerate', 'indole', 'UDP-D-quinovose', 'arachidonic acid', '6-amino-D-glucose 6-phosphate', 'urea', "4'-aminoacetophenone", 'ATP-N1-oxide', '15-oxo-prostaglandin E2', 'acetanilide', 'orthophosphate', 'H2', 'trans-cinnamate', 'glyoxylate', '2-octanone', 'D-glycero-D-glucoheptitol', 'sulfate', '2 L-methionine', 'phosvitin', '4 cytochrome c', 'isocitrate', 'pyruvate kinase', 'orotate', 'nicotinamide', "adenosine 5'-phosphosulfate", 'phosphoribosyl-1-O-', '5,6-dideoxyfructose 1-phosphate', '5-oxo-D-gluconate', 'S-methylmethionine', "N-acetyl-4-aminoazobenzene-4'-sulfonic acid", 'UDP-D-fucose', 'cyclohexaamylose', '5,6-dihydrouracil', 'L-serine', '5-methyluridine', 'enol-oxaloacetate', 'ATP', 'N-acetylimidazole', '7 H2O', 'norpyridoxal', 'D-arabinose', 'anandamide', 'L-erythrulose', '5-deoxypyridoxal', 'L-aspartate', 'thiamine', 'acetyl-CoA', 'corrinoid protein', 'H2O2', '6-amino-D-glucose', '2-methylmaleate', 'L-phenylalanine', "4'-methylacetanilide", 'ADP', 'pyruvate', 'phosphoenolpyruvate', 'cis-hex-2-enoyl-CoA', '4-dimethylaminomethylbenzaldehyde', 'D-glycine', 'keto-oxaloacetate', 'tRNA-Tyr', 'thymine', 'succinyl-CoA', 'desamino NADH', 'acetaldehyde', '7 D-glucose', 'p-toluidine', 'hypoxanthine', 'L-alanine', 'choline', 'oxaloacetate', 'D-alanine', 'succinate', '3-ureidopropanoic acid', 'cycloheptanol', 'glycolate', '4-methyl-2-oxopentanooate', 'aniline', "4'-cyanoacetanilide", '5-deoxypyridoxamine', 'cyclooctanone', 'benzyl acetate', 'amoxicill ...

# %%
print(len(unique_mets_striiped_list))
# Out:
# 222

# %%
stripped_mets_df = pd.DataFrame(unique_mets_striiped_list, columns=(['Stripped Metabolites']))

# %%
# converting to csv to analyse outputs easily
stripped_mets_df.to_csv("/home/jackmcgoldrick/openTECR/results/stripped_mets_tobe_mapped.csv", index=False)

# %% [markdown]
# ### Removing problematic mets i.e "8 h20" and "6 glucophosphate" etc..

# %%
# not removing, stripping the digits, afterwards will discard any duplicate entries
## done to prevent possible loss of data 
stripped_mets_df['Metabolites'] = stripped_mets_df['Stripped Metabolites'].str.replace(r'^\d+\s', '', regex=True)

# %%
stripped_mets_df
# Out:
#     Stripped Metabolites          Metabolites
# 0
# 1        D-sedoheptulose      D-sedoheptulose
# 2            L-glutamate          L-glutamate
# 3        carbon monoxide      carbon monoxide
# 4        phospholysozyme      phospholysozyme
# ..                   ...                  ...
# 217  4'-cyanoacetanilide  4'-cyanoacetanilide
# 218  5-deoxypyridoxamine  5-deoxypyridoxamine
# 219        cyclooctanone        cyclooctanone
# 220       benzyl acetate       benzyl acetate
# 221          amoxicillin          amoxicillin
#
# [222 rows x 2 columns]

# %%
# update the corresponding csv file
stripped_mets_df.to_csv("/home/jackmcgoldrick/openTECR/results/stripped_mets_tobe_mapped.csv", index=False)

# %%
# Drop duplicate metabolite names
unique_cleaned_mets = stripped_mets_df.drop_duplicates(subset=['Metabolites'], keep='first')

# Display the resulting DataFrame
print(unique_cleaned_mets)
# Out:
#     Stripped Metabolites          Metabolites
# 0
# 1        D-sedoheptulose      D-sedoheptulose
# 2            L-glutamate          L-glutamate
# 3        carbon monoxide      carbon monoxide
# 4        phospholysozyme      phospholysozyme
# ..                   ...                  ...
# 217  4'-cyanoacetanilide  4'-cyanoacetanilide
# 218  5-deoxypyridoxamine  5-deoxypyridoxamine
# 219        cyclooctanone        cyclooctanone
# 220       benzyl acetate       benzyl acetate
# 221          amoxicillin          amoxicillin
#
# [212 rows x 2 columns]

# %%
# save to csv for manual corrections of hard to correct mets
unique_cleaned_mets.to_csv("/home/jackmcgoldrick/openTECR/results/mets_toBe_mapped_Final.csv", index=False)

# %% [markdown]
# Manually cleaned some of the entries which were problematic. Possibly some metabolites still not accounted for but 214 mets is a good start and covers majority of reactions.
#
# - 214 comes from the addition of two metabolites which were uncovered via manual inspection
#
# - When inspecting **mets_toBe_mapped_Final.csv** , note that "Stripped Metabolites" column was removed manually as it was no longer needed
