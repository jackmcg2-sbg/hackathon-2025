# %% [markdown]
# 2nd version, working on the 106 compounds that are unmapped after Roberts help!

# %%
import os
import pandas as pd
import re
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
# import the excel 
check_in = "/home/jackmcgoldrick/openTECR/data/2025_openTECR_hackathon_check-in.xlsx"

# %%
# convert to df
comp_matching = pd.read_excel(check_in, sheet_name="compound matching")

# %%
comp_matching
# Out:
#                        compound_name    kegg  appears in part 1  \
# 0                     benzyl alcohol  C00556                1.0
# 1                                NAD  C00003                1.0
# 2                       benzaldehyde  C00261                1.0
# 3                               NADH  C00004                1.0
# 4                          1-butanol  C06142                1.0
# ..                               ...     ...                ...
# 687                         thiamine     NaN                NaN
# 688                thiopyrophosphate     NaN                NaN
# 689                     UDP-D-fucose     NaN                NaN
# 690                  UDP-D-quinovose     NaN                NaN
# 691  uridine 3':5'-(cyclic)phosphate     NaN                NaN
#
#      appears in part 2  appears in part 3  appears in part 4  \
# 0                  NaN                NaN                NaN
# 1                  1.0                1.0                1.0
# 2                  NaN                NaN                NaN
# 3                  1.0                NaN                1.0
# 4                  NaN                NaN                NaN
# ..                 ...                ...                ...
# 687                NaN                NaN                NaN
# 688                NaN                NaN                NaN
# 689                NaN                NaN                NaN
# 690                NaN                NaN                NaN
# 691                NaN                NaN                NaN
#
#      appears in part 5  appears in part 6  appears in part 7
# 0                  NaN                NaN                NaN
# 1                  NaN                1.0                NaN
# 2                  NaN                NaN                NaN
# 3                  NaN                1.0                NaN
# 4                  NaN                NaN                NaN
# ..                 ...                ...                ...
# 687                NaN                NaN                NaN
# 688                NaN                NaN                NaN
# 689                NaN                NaN                NaN
# 690                NaN                NaN                NaN
# 691                NaN                NaN                NaN
#
# [692 rows x 9 columns]

# %%
# filter those which have no kegg - move to sep df
unmapped_comps = comp_matching[comp_matching['kegg'].isnull()]

# %%
unmapped_comps
# Out:
#                        compound_name kegg  appears in part 1  \
# 585       (3R)-3-hydroxyhexanoyl-CoA  NaN                NaN
# 586                (S)-(+)-2-octanol  NaN                NaN
# 587                   (S)-2-heptanol  NaN                NaN
# 588           1-glycerol 3-phosphate  NaN                NaN
# 589          15-oxo-prostaglandin E2  NaN                NaN
# ..                               ...  ...                ...
# 687                         thiamine  NaN                NaN
# 688                thiopyrophosphate  NaN                NaN
# 689                     UDP-D-fucose  NaN                NaN
# 690                  UDP-D-quinovose  NaN                NaN
# 691  uridine 3':5'-(cyclic)phosphate  NaN                NaN
#
#      appears in part 2  appears in part 3  appears in part 4  \
# 585                NaN                NaN                NaN
# 586                NaN                NaN                NaN
# 587                NaN                NaN                NaN
# 588                NaN                NaN                NaN
# 589                NaN                NaN                NaN
# ..                 ...                ...                ...
# 687                NaN                NaN                NaN
# 688                NaN                NaN                NaN
# 689                NaN                NaN                NaN
# 690                NaN                NaN                NaN
# 691                NaN                NaN                NaN
#
#      appears in part 5  appears in part 6  appears in part 7
# 585                NaN                NaN                NaN
# 586                NaN                NaN                NaN
# 587                NaN                NaN                NaN
# 588                NaN                NaN                NaN
# 589                NaN                NaN                NaN
# ..                 ...                ...                ...
# 687                NaN                NaN                NaN
# 688                NaN                NaN                NaN
# 689                NaN                NaN                NaN
# 690                NaN                NaN                NaN
# 691                NaN                NaN                NaN
#
# [107 rows x 9 columns]

# %%
# has the correct number of mets i.e 106

# now want to extract the compound_name into list
compounds = unmapped_comps['compound_name']

# %%
compounds
# Out:
# 585         (3R)-3-hydroxyhexanoyl-CoA
# 586                  (S)-(+)-2-octanol
# 587                     (S)-2-heptanol
# 588             1-glycerol 3-phosphate
# 589            15-oxo-prostaglandin E2
#                     ...
# 687                           thiamine
# 688                  thiopyrophosphate
# 689                       UDP-D-fucose
# 690                    UDP-D-quinovose
# 691    uridine 3':5'-(cyclic)phosphate
# Name: compound_name, Length: 107, dtype: object

# %%
def reconXMapper_name(name):
    """
    Query which returns best matches related to an input molecule's name.

    This query implements a strategy to:
    1. Look for exact matches (case-insensitive) and assign priority = 1.
    2. If no exact matches exist, suggest partial matches (priority = 2).

    Parameters:
        name (str): The molecule name to search for.

    Returns:
        List of dictionaries with 'mainName', 'coalescedValue', and 'priority'.
    """
    # Define the SPARQL endpoint
    sparql_endpoint = "http://sbg:7200/repositories/ReconXKG"
    sparql = SPARQLWrapper(sparql_endpoint)
    sparql.setReturnFormat(JSON)

    # SPARQL query
    query = f"""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX mnx: <https://rdf.metanetx.org/schema/>
    PREFIX reconx: <https://reconx.vital-it.ch/kg/>

    SELECT DISTINCT 
           # ?mainName
           (COALESCE(?xrefIDs, ?exactName, ?partialName, "N/A") AS ?coalescedValue)
           # ?priority
    WHERE {{
      ##############################################################################
      # Subquery 1: Retrieve the main chem info (?chemID, ?mainName, ?xrefIDs)
      ##############################################################################
      {{
        SELECT ?chemID ?mainName ?xrefIDs
        WHERE {{
          # ?chemID a mnx:CHEM ;
                  rdfs:comment ?mainName .

          BIND(?chemID AS ?tempChemID)

          # Possibly multiple cross-reference IDs
          {{
            # ?tempChemID mnx:chemXref ?xrefIDs .
          }}
          UNION
          # Fallback to binding the chem ID itself
          {{
            BIND(?tempChemID AS ?xrefIDs)
          }}
        }}
      }}

      ##############################################################################
      # Subquery 2: Exact match => priority=1
      ##############################################################################
      {{
        SELECT ?chemID (1 AS ?priority) ?exactName
        WHERE {{
          # ?chemID a mnx:CHEM ;
                  rdfs:comment ?exactName .

          FILTER(REGEX(?exactName, "^{name}$", "i"))
        }}
      }}
      UNION
      ##############################################################################
      # Subquery 3: Partial match => priority=2
      ##############################################################################
      {{
        SELECT ?chemID (2 AS ?priority) ?partialName
        WHERE {{
          # ?chemID a mnx:CHEM ;
                  mnx:chemXref/rdfs:comment ?partialName .

          FILTER(REGEX(?partialName, "\\b{name}\\b", "i"))

          # Exclude partial matches if an exact match exists globally
          FILTER NOT EXISTS {{
            # ?anyChem a mnx:CHEM ;
                     rdfs:comment ?anyExactName .

            FILTER(REGEX(?anyExactName, "^{name}$", "i"))
          }}
        }}
      }}
    }}
    ORDER BY ?priority
    """

    # Set the query string and execute
    sparql.setQuery(query)
    try:
        # Execute the query
        results = sparql.query().convert()
        bindings = results.get("results", {}).get("bindings", [])
        
        # Simplify the output
        simplified_results = []
        for result in bindings:
            simplified_results.append({
                "mainName": result.get("mainName", {}).get("value", "N/A"),
                "coalescedValue": result.get("coalescedValue", {}).get("value", "N/A"),
                "priority": int(result.get("priority", {}).get("value", "2"))  # Default to priority 2
            })
        
        return simplified_results
    except Exception as e:
        raise RuntimeError(f"SPARQL query failed: {e}")

# %% [markdown]
# ## Test 1: Run Query on 1 compound

# %%
# Search for a specific compound name
compound_name = "L-mannose"  # Replace this with the compound name you want to search for
matching_compounds = compounds[compounds == compound_name]

# Assuming matching_compounds is a pandas Series
test_compound = matching_compounds.iloc[0]  # Extract the first value

# Pass the extracted compound name to your function
result = reconXMapper_name(test_compound)

# Print the result
print(result)
# Out:
# [{'mainName': 'L-mannose', 'coalescedValue': 'https://identifiers.org/CHEBI:37676', 'priority': 1}, {'mainName': 'L-mannose', 'coalescedValue': 'http://purl.obolibrary.org/obo/CHEBI_37676', 'priority': 1}, {'mainName': 'L-mannose', 'coalescedValue': 'https://rdf.metanetx.org/chem/MNXM59481', 'priority': 1}]

# %%
def run_query_and_save_to_csv(series, output_path):
    """
    Run the SPARQL query for each compound in the pandas Series and save the results to a CSV file.

    Parameters:
        series (pd.Series): Series containing the compound names.
        output_path (str): Full file path to save the output CSV.

    Returns:
        None
    """
    # Ensure the directory exists
    os.makedirs(os.path.dirname(output_path), exist_ok=True)

    results = []

    for compound in series:
        try:
            # Run the query for the current compound
            query_result = reconXMapper_name(compound)
            
            # Simplify the output into a readable string
            readable_result = "; ".join(
                [
                    f"{res['mainName']} ({res['coalescedValue']}, Priority {res['priority']})"
                    for res in query_result
                ]
            )
        except Exception as e:
            readable_result = f"Error: {e}"

        # Append the compound and result to the list
        results.append({"compound": compound, "query_result": readable_result})

    # Convert to DataFrame and save to the specified file path
    results_df = pd.DataFrame(results)
    results_df.to_csv(output_path, index=False)
    print(f"Results saved to {output_path}")

# %%
# define output_dir to store csv
output_dir = "/home/jackmcgoldrick/openTECR/results/compounds_mapped_ver1.csv"

run_query_and_save_to_csv(compounds, output_dir)
# Out:
# Results saved to /home/jackmcgoldrick/openTECR/results/compounds_mapped_ver1.csv

# %% [markdown]
# ## Attempting to Map Remaining Rxns (470)

# %%
# import new csv with extra mets

new_data = "/home/jackmcgoldrick/openTECR/data/freeText_toMap.xlsx"

# %%
# read the correct sheet
new_mets = pd.read_excel(new_data, sheet_name='compound matching v2')

# %%
new_mets
# Out:
#                     compound_name    kegg  appears in part 1  \
# 0                  benzyl alcohol  C00556                1.0
# 1                             NAD  C00003                1.0
# 2                    benzaldehyde  C00261                1.0
# 3                            NADH  C00004                1.0
# 4                       1-butanol  C06142                1.0
# ...                           ...     ...                ...
# 1187        3-phenylpropionitrile     NaN                NaN
# 1188       2-phenylpropanoic acid     NaN                NaN
# 1189    (deoxyribonucleotide)_{n}     NaN                NaN
# 1190    (deoxyribonucleotide)_{m}     NaN                NaN
# 1191  (deoxyribonucleotide)_{m+n}     NaN                NaN
#
#       appears in part 2  appears in part 3  appears in part 4  \
# 0                   NaN                NaN                NaN
# 1                   1.0                1.0                1.0
# 2                   NaN                NaN                NaN
# 3                   1.0                NaN                1.0
# 4                   NaN                1.0                NaN
# ...                 ...                ...                ...
# 1187                NaN                NaN                NaN
# 1188                NaN                NaN                NaN
# 1189                NaN                NaN                NaN
# 1190                NaN                NaN                NaN
# 1191                NaN                NaN                NaN
#
#       appears in part 5  appears in part 6  appears in part 7
# 0                   NaN                NaN                1.0
# 1                   NaN                1.0                NaN
# 2                   NaN                NaN                NaN
# 3                   NaN                1.0                NaN
# 4                   NaN                NaN                1.0
# ...                 ...                ...                ...
# 1187                NaN                NaN                1.0
# 1188                NaN                NaN                1.0
# 1189                NaN                NaN                1.0
# 1190                NaN                NaN                1.0
# 1191                NaN                NaN                1.0
#
# [1192 rows x 9 columns]

# %%
# return entries where "kegg" is empty
compounds_unmapped = new_mets[new_mets['kegg'].isnull()]

# %%
compounds_unmapped
# Out:
#                     compound_name kegg  appears in part 1  appears in part 2  \
# 649                  desamino NAD  NaN                1.0                NaN
# 650                 desamino NADH  NaN                1.0                NaN
# 658     D-glycero-D-glucoheptitol  NaN                1.0                NaN
# 661            2-oxo-myo-inositol  NaN                1.0                NaN
# 663      2-oxo-4-hydroxybutanoate  NaN                1.0                NaN
# ...                           ...  ...                ...                ...
# 1187        3-phenylpropionitrile  NaN                NaN                NaN
# 1188       2-phenylpropanoic acid  NaN                NaN                NaN
# 1189    (deoxyribonucleotide)_{n}  NaN                NaN                NaN
# 1190    (deoxyribonucleotide)_{m}  NaN                NaN                NaN
# 1191  (deoxyribonucleotide)_{m+n}  NaN                NaN                NaN
#
#       appears in part 3  appears in part 4  appears in part 5  \
# 649                 NaN                NaN                NaN
# 650                 NaN                NaN                NaN
# 658                 NaN                NaN                NaN
# 661                 NaN                NaN                NaN
# 663                 NaN                NaN                NaN
# ...                 ...                ...                ...
# 1187                NaN                NaN                NaN
# 1188                NaN                NaN                NaN
# 1189                NaN                NaN                NaN
# 1190                NaN                NaN                NaN
# 1191                NaN                NaN                NaN
#
#       appears in part 6  appears in part 7
# 649                 NaN                NaN
# 650                 NaN                NaN
# 658                 NaN                NaN
# 661                 NaN                NaN
# 663                 NaN                NaN
# ...                 ...                ...
# 1187                NaN                1.0
# 1188                NaN                1.0
# 1189                NaN                1.0
# 1190                NaN                1.0
# 1191                NaN                1.0
#
# [471 rows x 9 columns]

# %%
compounds_2 = compounds_unmapped['compound_name']

# %%
compounds_2
# Out:
# 649                    desamino NAD
# 650                   desamino NADH
# 658       D-glycero-D-glucoheptitol
# 661              2-oxo-myo-inositol
# 663        2-oxo-4-hydroxybutanoate
#                    ...
# 1187          3-phenylpropionitrile
# 1188         2-phenylpropanoic acid
# 1189      (deoxyribonucleotide)_{n}
# 1190      (deoxyribonucleotide)_{m}
# 1191    (deoxyribonucleotide)_{m+n}
# Name: compound_name, Length: 471, dtype: object

# %%
# 470 entries unmapped and to run in ReconXKG
def query_sparql(endpoint_url, name_of_interest):
    """
    Query a SPARQL endpoint for chemical information based on the name of interest.

    :param endpoint_url: str, the SPARQL endpoint URL.
    :param name_of_interest: str, the exact name to search for (case-insensitive).
    :return: list of tuples, each containing the chemical ID and exact name.
    """
    # Define the SPARQL query with the name of interest
    sparql_query = f"""
    PREFIX mnx: <https://rdf.metanetx.org/schema/>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    SELECT ?chemID ?exactName
    WHERE {{
      # ?chemID a mnx:CHEM ;
              rdfs:comment ?exactName .
      FILTER(REGEX(?exactName, "^{name_of_interest}$", "i"))
    }}
    """

    # Initialize the SPARQL wrapper
    sparql = SPARQLWrapper(endpoint_url)
    sparql.setQuery(sparql_query)
    sparql.setReturnFormat(JSON)

    try:
        # Execute the query and process the results
        results = sparql.query().convert()
        output = []
        for result in results["results"]["bindings"]:
            chem_id = result["chemID"]["value"]
            exact_name = result["exactName"]["value"]
            output.append((chem_id, exact_name))
        return output
    except Exception as e:
        print(f"An error occurred: {e}")
        return []

# %%
import os
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON

def query_sparql(endpoint_url, name_of_interest):
    """
    Query a SPARQL endpoint for chemical information based on the name of interest.

    :param endpoint_url: str, the SPARQL endpoint URL.
    :param name_of_interest: str, the exact name to search for (case-insensitive).
    :return: list of dictionaries, each containing chemical ID and exact name.
    """
    # Escape the name_of_interest to avoid SPARQL injection or errors
    escaped_name = name_of_interest.replace('"', '\\"')

    sparql_query = f"""
    PREFIX mnx: <https://rdf.metanetx.org/schema/>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    SELECT ?chemID ?exactName
    WHERE {{
      # ?chemID a mnx:CHEM ;
              rdfs:comment ?exactName .
      FILTER(REGEX(?exactName, "^{escaped_name}$", "i"))
    }}
    """

    sparql = SPARQLWrapper(endpoint_url)
    sparql.setQuery(sparql_query)
    sparql.setReturnFormat(JSON)

    try:
        results = sparql.query().convert()
        output = []
        for result in results["results"]["bindings"]:
            output.append({
                "chemID": result["chemID"]["value"],
                "exactName": result["exactName"]["value"]
            })
        return output
    except Exception as e:
        print(f"An error occurred: {e}")
        print("Query that caused the error:")
        print(sparql_query)
        return []

def run_query_and_save(series, endpoint_url, output_path):
    """
    Run the SPARQL query for each compound in the pandas Series and save the results to a CSV file.

    Parameters:
        series (pd.Series): Series containing the compound names.
        endpoint_url (str): The SPARQL endpoint URL.
        output_path (str): Full file path to save the output CSV.

    Returns:
        None
    """
    # Ensure the directory exists
    os.makedirs(os.path.dirname(output_path), exist_ok=True)

    results = []

    for compound in series:
        try:
            # Run the query for the current compound
            query_result = query_sparql(endpoint_url, compound)

            # Simplify the output into a readable string
            readable_result = "; ".join(
                [
                    f"{res['exactName']} ({res['chemID']})"
                    for res in query_result
                ]
            ) if query_result else "No results found"
        except Exception as e:
            readable_result = f"Error: {e}"

        # Append the compound and result to the list
        results.append({"compound": compound, "query_result": readable_result})

    # Convert to DataFrame and save to the specified file path
    results_df = pd.DataFrame(results)
    results_df.to_csv(output_path, index=False)
    print(f"Results saved to {output_path}")

# %%
# Example usage
if __name__ == "__main__":
    # Replace with the actual SPARQL endpoint URL
    endpoint_url = "http://sbg:7200/repositories/ReconXKG"

   
    # Output file path
    output_csv_path = "/home/jackmcgoldrick/openTECR/results/chemical_query_results.csv"

    # Run the query and save results
    run_query_and_save(compounds_2, endpoint_url, output_csv_path)
# Out:
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 37.  Encountered: \'97\' (97), after prefix "\\"^5{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^5{\alpha}-pregnane-3{\alpha},17{\alpha},21-triol-20-one$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 37.  Encountered: \'97\' (97), after prefix "\\"^5{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^5{\alpha}-pregnane-17{\alpha},21-diol-3,20-dione$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 56.  Encountered: \'97\' (97), after prefix "\\"^5{\\\\beta}-pregnane-17{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^5{\beta}-pregnane-17{\alpha},21-diol-3,20-dione$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 37.  Encountered: \'97\' (97), after prefix "\\"^5{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^5{\alpha}-androstane-17{\alpha}-ol-3-one$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 37.  Encountered: \'97\' (97), after prefix "\\"^5{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^5{\alpha}-pregnane-3{\beta},17{\alpha},21-triol-20-one$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 65.  Encountered: \'97\' (97), after prefix "\\"^5{\\\\beta}-pregnane-3{\\\\beta},17{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^5{\beta}-pregnane-3{\beta},17{\alpha},21-triol-20-one$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 37.  Encountered: \'97\' (97), after prefix "\\"^5{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^5{\alpha}-pregnane-3{\beta},17{\alpha},21-triol-11,20-dione$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 37.  Encountered: \'97\' (97), after prefix "\\"^5{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^5{\alpha}-pregnane-17{\alpha},21-diol-3,11,20-trione$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 59.  Encountered: \'97\' (97), after prefix "\\"^4-pregnene-11{\\\\beta},17{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^4-pregnene-11{\beta},17{\alpha},21-triol-3,20-dione$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 59.  Encountered: \'97\' (97), after prefix "\\"^4-pregnene-11{\\\\beta},17{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^4-pregnene-11{\beta},17{\alpha}-diol-3,20,21-trione$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 36.  Encountered: \'97\' (97), after prefix "\\"^{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^{\alpha},{\alpha},{\alpha}-trifluoro-m-acetanilide$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 7\n^(2,6-{\x08eta}-D-fructosyl)n+1$\n       ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^(2,6-{\beta}-D-fructosyl)n+1$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b"Syntax error in query: Illegal repetition near index 12\n^5-amino-1-{\x08eta}-D-ribosyl-4-imidazolecarboxamide 5'-phosphate$\n            ^\n"
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^5-amino-1-{\beta}-D-ribosyl-4-imidazolecarboxamide 5'-phosphate$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 36.  Encountered: \'959\' (959), after prefix "\\"^{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^{\οmega}-methylpyridoxamine$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 36.  Encountered: \'959\' (959), after prefix "\\"^{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^{\οmega}-methylpyridoxal$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 6\n^ATP-{\x08eta}-S$\n      ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^ATP-{\beta}-S$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 6\n^ADP-{\x08eta}-S$\n      ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^ADP-{\beta}-S$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 50.  Encountered: \'97\' (97), after prefix "\\"^adenosine 5\\\'-({\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^adenosine 5'-({\alpha},{\beta}-methylene)triphosphate$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 50.  Encountered: \'97\' (97), after prefix "\\"^adenosine 5\\\'-({\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^adenosine 5'-({\alpha},{\beta}-methylene)diphosphate$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 40.  Encountered: \'97\' (97), after prefix "\\"^ATP-{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^ATP-{\alpha}-S$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 40.  Encountered: \'97\' (97), after prefix "\\"^ADP-{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^ADP-{\alpha}-S$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 40.  Encountered: \'103\' (103), after prefix "\\"^ATP-{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^ATP-{\gamma}-S$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 38.  Encountered: \'97\' (97), after prefix "\\"^L-{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^L-{\alpha}-glycerophosphate$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 43.  Encountered: \'97\' (97), after prefix "\\"^methyl {\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^methyl {\alpha}-D-glucopyranoside 6-phosphate$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 43.  Encountered: \'97\' (97), after prefix "\\"^methyl {\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^methyl {\alpha}-D-glucopyranose$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 9\n^methyl {\x08eta}-D-ribofuranoside 5-phosphate$\n         ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^methyl {\beta}-D-ribofuranoside 5-phosphate$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 9\n^methyl {\x08eta}-D-ribofuranose$\n         ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^methyl {\beta}-D-ribofuranose$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 43.  Encountered: \'97\' (97), after prefix "\\"^methyl {\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^methyl {\alpha}-D-glucopyranoside 4,6-(cyclic)phosphate$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 9\n^methyl {\x08eta}-D-ribofuranoside 3,5-(cyclic)phosphate$\n         ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^methyl {\beta}-D-ribofuranoside 3,5-(cyclic)phosphate$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 38.  Encountered: \'97\' (97), after prefix "\\"^O-{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^O-{\alpha}-D-glucopyranosyl-(1->4)n$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 43.  Encountered: \'97\' (97), after prefix "\\"^phenyl {\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^phenyl {\alpha}-maltoside$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 43.  Encountered: \'97\' (97), after prefix "\\"^phenyl {\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^phenyl {\alpha}-D-glucopyranoside$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 10\n^1-butyl {\x08eta}-D-glucopyranoside$\n          ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^1-butyl {\beta}-D-glucopyranoside$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 10\n^2-butyl {\x08eta}-D-glucopyranoside$\n          ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^2-butyl {\beta}-D-glucopyranoside$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 37.  Encountered: \'112\' (112), after prefix "\\"^({\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^({\pm})-2-butanol$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 8\n^ethyl {\x08eta}-D-glucopyranoside$\n        ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^ethyl {\beta}-D-glucopyranoside$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 9\n^methyl {\x08eta}-D-glucopyranoside$\n         ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^methyl {\beta}-D-glucopyranoside$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 20\n^2-methyl-1-propyl {\x08eta}-D-glucopyranoside$\n                    ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^2-methyl-1-propyl {\beta}-D-glucopyranoside$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 20\n^2-methyl-2-propyl {\x08eta}-D-glucopyranoside$\n                    ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^2-methyl-2-propyl {\beta}-D-glucopyranoside$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 11\n^1-propyl {\x08eta}-D-glucopyranoside$\n           ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^1-propyl {\beta}-D-glucopyranoside$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 11\n^2-propyl {\x08eta}-D-glucopyranoside$\n           ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^2-propyl {\beta}-D-glucopyranoside$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 6\n^3-O-{\x08eta}-D-galactopyranosyl-D-arabinose$\n      ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^3-O-{\beta}-D-galactopyranosyl-D-arabinose$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 38.  Encountered: \'97\' (97), after prefix "\\"^O-{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^O-{\alpha}-D-galactopyranosyl-(1->6)-O-{\alpha}-D-galactopyranosyl-(1->6)-{\alpha}-D-glucopyranose$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 11\n^maltosyl-{\x08eta}-cyclomaltoheptaose$\n           ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^maltosyl-{\beta}-cyclomaltoheptaose$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 37.  Encountered: \'97\' (97), after prefix "\\"^N{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^N{\alpha}-benzoyl-L-argininamide$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 37.  Encountered: \'97\' (97), after prefix "\\"^N{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^N{\alpha}-benzoyl-L-arginine$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 36.  Encountered: \'103\' (103), after prefix "\\"^{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^{\gamma}-glutamohydroxamic acid$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 41.  Encountered: \'97\' (97), after prefix "\\"^D(-)-{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^D(-)-{\alpha}-aminophenylacetic acid$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 47.  Encountered: \'97\' (97), after prefix "\\"^N-acetyl-L-{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^N-acetyl-L-{\alpha}-amino-n-butyrate$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 38.  Encountered: \'97\' (97), after prefix "\\"^L-{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^L-{\alpha}-amino-n-butyrate$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 36.  Encountered: \'103\' (103), after prefix "\\"^{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^{\gamma}-fluoroglutamate$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 2\n^{\x08eta}-alanylpantetheine$\n  ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^{\beta}-alanylpantetheine$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 38.  Encountered: \'97\' (97), after prefix "\\"^D-{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^D-{\alpha}-amino-n-butyrate$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 56.  Encountered: \'68\' (68), after prefix "\\"^(-)-4-carboxymethyl-{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^(-)-4-carboxymethyl-{\Delta}{\alpha}-but-2-en-4-olide$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 2\n^{\x08eta}-guanadinopropionate$\n  ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^{\beta}-guanadinopropionate$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 2\n^{\x08eta}-phosphoguanadinopropionate$\n  ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^{\beta}-phosphoguanadinopropionate$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 2\n^{\x08eta}-guanidinopropionate$\n  ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^{\beta}-guanidinopropionate$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 2\n^{\x08eta}-phosphoguanidinopropionate$\n  ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^{\beta}-phosphoguanidinopropionate$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 40.  Encountered: \'97\' (97), after prefix "\\"^6-O-{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^6-O-{\alpha}-D-galactopyranosyl-D-galactopyranose$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 40.  Encountered: \'97\' (97), after prefix "\\"^4-O-{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^4-O-{\alpha}-D-glucopyranosyl-D-fructofuranose$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 40.  Encountered: \'97\' (97), after prefix "\\"^3-O-{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^3-O-{\alpha}-D-glucopyranosyl-lyxopyranose$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 40.  Encountered: \'97\' (97), after prefix "\\"^1-O-{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^1-O-{\alpha}-D-mannopyranosyl-D-mannofuranose$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 40.  Encountered: \'97\' (97), after prefix "\\"^6-O-{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^6-O-{\alpha}-D-mannopyranose-D-mannopyranose$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 37.  Encountered: \'112\' (112), after prefix "\\"^({\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^({\pm})-cis-2-benzyl-1-cyclohexanol$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 37.  Encountered: \'112\' (112), after prefix "\\"^({\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^({\pm})-trans-2-benzyl-1-cyclohexanol$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 37.  Encountered: \'112\' (112), after prefix "\\"^({\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^({\pm})-2-hexanol$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 37.  Encountered: \'112\' (112), after prefix "\\"^({\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^({\pm})-cis-2-methyl-1-cyclohexanol$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 37.  Encountered: \'112\' (112), after prefix "\\"^({\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^({\pm})-trans-2-methyl-1-cyclohexanol$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b"Syntax error in query: Dangling meta character '+' near index 6\n^(S)-(+)-2-octanol$\n      ^\n"
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^(S)-(+)-2-octanol$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 37.  Encountered: \'112\' (112), after prefix "\\"^({\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^({\pm})-2-pentanol$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 37.  Encountered: \'112\' (112), after prefix "\\"^({\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^({\pm})-cis-2-phenyl-1-cyclohexanol$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 37.  Encountered: \'112\' (112), after prefix "\\"^({\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^({\pm})-trans-2-phenyl-1-cyclohexanol$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 37.  Encountered: \'112\' (112), after prefix "\\"^({\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^({\pm})-cis-2-phenyl-1-ethanol$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 37.  Encountered: \'112\' (112), after prefix "\\"^({\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^({\pm})-cis-2-phenyl-1-heptanol$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 37.  Encountered: \'112\' (112), after prefix "\\"^({\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^({\pm})-cis-2-phenyl-1-hexanol$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 37.  Encountered: \'112\' (112), after prefix "\\"^({\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^({\pm})-cis-2-phenyl-1-pentanol$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 37.  Encountered: \'112\' (112), after prefix "\\"^({\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^({\pm})-cis-2-phenyl-1-propanol$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal character range near index 8\n^poly[d-(A-T)]n$\n        ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^poly[d-(A-T)]n$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal character range near index 8\n^poly[d-(A-T))]n+1$\n        ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^poly[d-(A-T))]n+1$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b"Syntax error in query: Dangling meta character '+' near index 6\n^(R)-(+)-1-phenyl-1-butanol$\n      ^\n"
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^(R)-(+)-1-phenyl-1-butanol$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b"Syntax error in query: Dangling meta character '+' near index 6\n^(R)-(+)-1-phenyl 1-butyl acetate$\n      ^\n"
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^(R)-(+)-1-phenyl 1-butyl acetate$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b"Syntax error in query: Dangling meta character '+' near index 6\n^(R)-(+)-1-phenyl ethanol$\n      ^\n"
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^(R)-(+)-1-phenyl ethanol$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b"Syntax error in query: Dangling meta character '+' near index 6\n^(R)-(+)-1-phenyl ethyl acetate$\n      ^\n"
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^(R)-(+)-1-phenyl ethyl acetate$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b"Syntax error in query: Dangling meta character '+' near index 6\n^(R)-(+)-1-phenyl-1-propanol$\n      ^\n"
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^(R)-(+)-1-phenyl-1-propanol$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b"Syntax error in query: Dangling meta character '+' near index 6\n^(R)-(+)-1-phenyl-1-propyl acetate$\n      ^\n"
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^(R)-(+)-1-phenyl-1-propyl acetate$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 70.  Encountered: \'97\' (97), after prefix "\\"^cis-2-hydroxycyclopentanemethanol {\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^cis-2-hydroxycyclopentanemethanol {\alpha}-phosphate$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 72.  Encountered: \'97\' (97), after prefix "\\"^trans-2-hydroxycyclopentanemethanol {\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^trans-2-hydroxycyclopentanemethanol {\alpha}-phosphate$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 83.  Encountered: \'97\' (97), after prefix "\\"^(1R,2S)-trans-2-hydroxytetrahydrofuranmethanol {\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^(1R,2S)-trans-2-hydroxytetrahydrofuranmethanol {\alpha}-phosphate$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 36.  Encountered: \'97\' (97), after prefix "\\"^{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^{\alpha}-methylbenzylcyanide$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 8, column 36.  Encountered: \'97\' (97), after prefix "\\"^{\\\\"'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^{\alpha}-methylbenzene acetic acid$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 24\n^(deoxyribonucleotide)_{n}$\n                        ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^(deoxyribonucleotide)_{n}$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 24\n^(deoxyribonucleotide)_{m}$\n                        ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^(deoxyribonucleotide)_{m}$", "i"))
#     }
#
# An error occurred: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Syntax error in query: Illegal repetition near index 24\n^(deoxyribonucleotide)_{m+n}$\n                        ^\n'
# Query that caused the error:
#
#     PREFIX mnx: <https://rdf.metanetx.org/schema/>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?chemID ?exactName
#     WHERE {
#       ?chemID a mnx:CHEM ;
#               rdfs:comment ?exactName .
#       FILTER(REGEX(?exactName, "^(deoxyribonucleotide)_{m+n}$", "i"))
#     }
#
# Results saved to /home/jackmcgoldrick/openTECR/results/chemical_query_results.csv
