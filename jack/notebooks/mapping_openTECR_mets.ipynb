# %%
import pandas as pd 
import re
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
# link to csv file to import to df
openTECR_csv = '/home/jackmcgoldrick/openTECR/data/TECRDB.csv'

# %%
# converting to pandas df
data_openTECR = pd.read_csv(openTECR_csv)

# %%
data_openTECR.head()
# Out:
#                                                   id  \
# 0  https://w3id.org/related-to/doi.org/10.5281/ze...
# 1  https://w3id.org/related-to/doi.org/10.5281/ze...
# 2  https://w3id.org/related-to/doi.org/10.5281/ze...
# 3  https://w3id.org/related-to/doi.org/10.5281/ze...
# 4  https://w3id.org/related-to/doi.org/10.5281/ze...
#
#                                                  url  reference  \
# 0  http://xpdb.nist.gov/enzyme_thermodynamics/enz...  07LIN/ALG
# 1  http://xpdb.nist.gov/enzyme_thermodynamics/enz...      63GRE
# 2  http://xpdb.nist.gov/enzyme_thermodynamics/enz...  67ENG/DEN
# 3  http://xpdb.nist.gov/enzyme_thermodynamics/enz...  67ENG/DEN
# 4  http://xpdb.nist.gov/enzyme_thermodynamics/enz...  67ENG/DEN
#
#               method eval        EC                              enzyme_name  \
# 0  spectrophotometry    A  1.1.1.87             homoisocitrate dehydrogenase
# 1  spectrophotometry    C   3.5.4.9  methenyltetrahydrofolate cyclohydrolase
# 2  spectrophotometry    B   4.2.1.3                      aconitate hydratase
# 3  spectrophotometry    B   4.2.1.3                      aconitate hydratase
# 4  spectrophotometry    B   4.2.1.3                      aconitate hydratase
#
#                                             reaction  \
# 0  kegg:C05662 + kegg:C00003 = kegg:C00322 + kegg...
# 1            kegg:C00445 + kegg:C00001 = kegg:C00234
# 2                          kegg:C00311 = kegg:C00158
# 3                          kegg:C00311 = kegg:C00158
# 4                          kegg:C00311 = kegg:C00158
#
#                                          description   K  K_prime  \
# 0  (1R,2S)-1-hydroxybutane-1,2,4-tricarboxylate(a... NaN     0.45
# 1  5,10-methenyltetrahydrofolate(aq) + H2O(l) = 1... NaN     4.20
# 2                       isocitrate(aq) = citrate(aq) NaN    18.00
# 3                       isocitrate(aq) = citrate(aq) NaN    25.00
# 4                       isocitrate(aq) = citrate(aq) NaN    33.00
#
#    temperature  ionic_strength  p_h  p_mg
# 0       298.15             NaN  7.5   NaN
# 1       298.15             NaN  6.5   NaN
# 2       310.15             NaN  7.3  2.96
# 3       310.15             NaN  7.3  2.80
# 4       310.15             NaN  7.3  2.30

# %%
# kegg identifiers stored in 'reaction' column - retrieve into df series or py list
keggs_series = data_openTECR['reaction']

# %%
keggs_series
# Out:
# 0       kegg:C05662 + kegg:C00003 = kegg:C00322 + kegg...
# 1                 kegg:C00445 + kegg:C00001 = kegg:C00234
# 2                               kegg:C00311 = kegg:C00158
# 3                               kegg:C00311 = kegg:C00158
# 4                               kegg:C00311 = kegg:C00158
#                               ...
# 4539    kegg:C03373 + kegg:C00288 = kegg:C04751 + kegg...
# 4540    kegg:C00234 + kegg:C04677 = kegg:C00101 + kegg...
# 4541              kegg:C00101 + kegg:C00067 = kegg:C00143
# 4542              kegg:C00199 + kegg:C00067 = kegg:C06019
# 603

# %% [markdown]
# ## Linking to ReconXKG SPARQL endpoint to facilitate Molecule cross-mapping

# %% [markdown]
# ReconXKG is a knowledge graph containing info across multiple sites including VMH, MetaNetX, SwissLipids, Reactome and many more. This allows for metabolite entries across various platforms to be mapped accordingly. This resource will be leverage here in the form of a SPARQL query which will aim to return all Identifiers associated with an input Kegg Identifier.

# %%
def kegg_graphdb_single_row(kegg_id):
    # Regex patterns for each identifier type
    identifier_patterns = {
        "CHEBI": r"CHEBI",
        "BiGG Metabolite": r"bigg\.metabolite:",
        "HMDB": r"hmdb:",
        "KEGG Compound": r"kegg\.compound:",
        "MetaCyc": r"metacyc\.",
        "SABIORK": r"sabiork\.",
        "SEED": r"seed\.",
        "MNX": r"rdf\.metanetx\.org",
        "VMH": r"vmhmetabolite:",
        "Reactome": r"reactome:",
        "SwissLipids": r"SLM:",
        "EnviPath": r"envipath\."
    }

    # SPARQL query
    query = f"""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX mnx: <https://rdf.metanetx.org/schema/>
    PREFIX keggC: <https://www.genome.jp/kegg/>

    SELECT DISTINCT ?keggID ?relatedIDs
    WHERE {{
      # ?mnxChemID mnx:chemXref ?rawKeggUri .
      BIND(?mnxChemID AS ?tempChemID)
      FILTER(REGEX(STR(?rawKeggUri), "kegg", "i"))
      BIND(?rawKeggUri AS ?keggID)
      {{
        # ?tempChemID mnx:chemXref ?relatedIDs .
      }}
      UNION
      {{
        BIND(?tempChemID AS ?relatedIDs)
      }}
      # ?keggID rdfs:label ?keggLabel .
      FILTER(?relatedIDs != ?keggID)
      FILTER(REGEX(?keggLabel, "^keggC:{kegg_id}$", "i"))
    }}
    """
    sparql.setQuery(query)
    results = sparql.query().convert()

    # Initialize a single row for the given KEGG ID
    single_row = {
        "KEGG_ID": kegg_id,
        **{key: None for key in identifier_patterns.keys()},  # Initialize columns for each pattern
        "Extra Identifiers": []  # To store any unmatched identifiers
    }

    # Process results
    for entry in results["results"]["bindings"]:
        related_id = entry.get("relatedIDs", {}).get("value", "")
        matched = False

        # Match related_id against identifier patterns
        for identifier, pattern in identifier_patterns.items():
            if re.search(pattern, related_id, re.IGNORECASE):
                # If the column is empty, populate it; else append (optional depending on use case)
                if single_row[identifier] is None:
                    single_row[identifier] = related_id
                else:
                    # Optional: Store multiple matches for the same pattern
                    single_row[identifier] += f"; {related_id}"
                matched = True
                break

        # If no match, add to Extra Identifiers
        if not matched:
            single_row["Extra Identifiers"].append(related_id)

    # Convert "Extra Identifiers" to a string for storage
    single_row["Extra Identifiers"] = "; ".join(single_row["Extra Identifiers"])

    return single_row

# %% [markdown]
# ### Test 1

# %%
result = kegg_graphdb_single_row("C04752")
print(result)
# Out:
# {'KEGG_ID': 'C04752', 'CHEBI': 'https://identifiers.org/CHEBI:16629; https://identifiers.org/CHEBI:57841; http://purl.obolibrary.org/obo/CHEBI_11612; http://purl.obolibrary.org/obo/CHEBI_1194; http://purl.obolibrary.org/obo/CHEBI_11953; http://purl.obolibrary.org/obo/CHEBI_16629; http://purl.obolibrary.org/obo/CHEBI_19684; http://purl.obolibrary.org/obo/CHEBI_20308; http://purl.obolibrary.org/obo/CHEBI_57841', 'BiGG Metabolite': 'https://identifiers.org/bigg.metabolite:2mahmp', 'HMDB': 'https://identifiers.org/hmdb:HMDB0304168', 'KEGG Compound': 'https://identifiers.org/kegg.compound:C04752', 'MetaCyc': 'https://identifiers.org/metacyc.compound:AMINO-HYDROXYMETHYL-METHYLPYRIMIDINE-PP', 'SABIORK': 'https://identifiers.org/sabiork.compound:1832; https://sabiork.h-its.org/newSearch?q=1832', 'SEED': 'https://identifiers.org/seed.compound:cpd02894; https://modelseed.org/biochem/compounds/M_cpd02894; https://modelseed.org/biochem/compounds/cpd02894', 'MNX': 'https://rdf.metanetx.org/chem/MNXM1101289', 'VMH': None, 'Reactome': None, 'SwissLipids': None, 'EnviPath': None, 'Extra Identifiers': 'http://bigg.ucsd.edu/universal/metabolites/2mahmp; http://bigg.ucsd.edu/universal/metabolites/M_2mahmp; https://www.genome.jp/kegg/M_C04752; https://biocyc.org/compound?id=AMINO-HYDROXYMETHYL-METHYLPYRIMIDINE-PP'}

# %% [markdown]
# ### Test 2

# %%
test_keggs = ['C04752',
 'C00407',
 'C01545',
 'C00417',
 'C00197',
 'C00492',
 'C00357',
 'C14177',
 'C04442',
 'C04741',
 'C00469',]

# %%
all_results = [kegg_graphdb_single_row(kegg_id) for kegg_id in test_keggs]

# %%
test_keggs = pd.DataFrame(all_results)
print(test_keggs)
# Out:
#    KEGG_ID                                              CHEBI  \
# 0   C04752  https://identifiers.org/CHEBI:16629; https://i...
# 1   C00407  https://identifiers.org/CHEBI:17191; https://i...
# 2   C01545  https://identifiers.org/CHEBI:17935; http://pu...
# 3   C00417  https://identifiers.org/CHEBI:16383; https://i...
# 4   C00197  https://identifiers.org/CHEBI:17050; https://i...
# 5   C00492  https://identifiers.org/CHEBI:16634; https://i...
# 6   C00357  https://identifiers.org/CHEBI:15784; https://i...
# 7   C14177  https://identifiers.org/CHEBI:16585; https://i...
# 8   C04442  https://identifiers.org/CHEBI:15925; https://i...
# 9   C04741  https://identifiers.org/CHEBI:15544; https://i...
# 10  C00469  https://identifiers.org/CHEBI:16236; https://i...
#
#                                       BiGG Metabolite  \
# 0      https://identifiers.org/bigg.metabolite:2mahmp
# 1      https://identifiers.org/bigg.metabolite:ile__L
# 2       https://identifiers.org/bigg.metabolite:octal
# 3   https://identifiers.org/bigg.metabolite:HC0034...
# 4         https://identifiers.org/bigg.metabolite:3pg
# 5      https://identifiers.org/bigg.metabolite:raffin
# 6     https://identifiers.org/bigg.metabolite:acgam6p
# 7                                                None
# 8      https://identifiers.org/bigg.metabolite:2ddg6p
# 9    https://identifiers.org/bigg.metabolite:prostge1
# 10       https://identifiers.org/bigg.metabolite:etoh
#
#                                                  HMDB  \
# 0            https://identifiers.org/hmdb:HMDB0304168
# 1   https://identifiers.org/hmdb:HMDB0000172; http...
# 2   https://identifiers.org/hmdb:HMDB0001140; http...
# 3   https://identifiers.org/hmdb:HMDB0000072; http...
# 4   https://identifiers.org/hmdb:HMDB0000807; http...
# 5   https://identifiers.org/hmdb:HMDB0003213; http...
# 6   https://identifiers.org/hmdb:HMDB0001062; http...
# 7                                                None
# 8   https://identifiers.org/hmdb:HMDB0001376; http...
# 9   https://identifiers.org/hmdb:HMDB0001442; http...
# 10  https://identifiers.org/hmdb:HMDB0000108; http...
#
#                                         KEGG Compound  \
# 0        https://identifiers.org/kegg.compound:C04752
# 1   https://identifiers.org/kegg.compound:C00407; ...
# 2        https://identifiers.org/kegg.compound:C01545
# 3        https://identifiers.org/kegg.compound:C00417
# 4   https://identifiers.org/kegg.compound:C00197; ...
# 5        https://identifiers.org/kegg.compound:C00492
# 6        https://identifiers.org/kegg.compound:C00357
# 7        https://identifiers.org/kegg.compound:C14177
# 8        https://identifiers.org/kegg.compound:C04442
# 9        https://identifiers.org/kegg.compound:C04741
# 10       https://identifiers.org/kegg.compound:C00469
#
#                                               MetaCyc  \
# 0   https://identifiers.org/metacyc.compound:AMINO...
# 1   https://identifiers.org/metacyc.compound:CPD-1...
# 2    https://identifiers.org/metacyc.compound:CPD-371
# 3   https://identifiers.org/metacyc.compound:CIS-A...
# 4        https://identifiers.org/metacyc.compound:G3P
# 5   https://identifiers.org/metacyc.compound:CPD-1099
# 6                                                None
# 7                                                None
# 8                                                None
# 9   https://identifiers.org/metacyc.compound:ALPRO...
# 10      https://identifiers.org/metacyc.compound:ETOH
#
#                                               SABIORK  \
# 0   https://identifiers.org/sabiork.compound:1832;...
# 1   https://identifiers.org/sabiork.compound:23116...
# 2   https://identifiers.org/sabiork.compound:5652;...
# 3   https://identifiers.org/sabiork.compound:2043;...
# 4   https://identifiers.org/sabiork.compound:21216...
# 5   https://identifiers.org/sabiork.compound:1528;...
# 6   https://identifiers.org/sabiork.compound:1676;...
# 7                                                None
# 8   https://identifiers.org/sabiork.compound:1812;...
# 9   https://identifiers.org/sabiork.compound:7532;...
# 10  https://identifiers.org/sabiork.compound:56; h...
#
#                                                  SEED  \
# 0   https://identifiers.org/seed.compound:cpd02894...
# 1   https://identifiers.org/seed.compound:cpd00322...
# 2   https://identifiers.org/seed.compound:cpd01088...
# 3   https://identifiers.org/seed.compound:cpd00331...
# 4   https://identifiers.org/seed.compound:cpd00169...
# 5   https://identifiers.org/seed.compound:cpd00382...
# 6   https://identifiers.org/seed.compound:cpd00293...
# 7   https://identifiers.org/seed.compound:cpd09876...
# 8   https://identifiers.org/seed.compound:cpd02711...
# 9   https://identifiers.org/seed.compound:cpd02889...
# 10  https://identifiers.org/seed.compound:cpd00363...
#
#                                           MNX  \
# 0   https://rdf.metanetx.org/chem/MNXM1101289
# 1   https://rdf.metanetx.org/chem/MNXM1366448
# 2      https://rdf.metanetx.org/chem/MNXM2705
# 3   https://rdf.metanetx.org/chem/MNXM1092518
# 4    https://rdf.metanetx.org/chem/MNXM727604
# 5   https://rdf.metanetx.org/chem/MNXM1108339
# 6   https://rdf.metanetx.org/chem/MNXM1365474
# 7   https://rdf.metanetx.org/chem/MNXM1376409
# 8   https://rdf.metanetx.org/chem/MNXM1377059
# 9    https://rdf.metanetx.org/chem/MNXM730388
# 10  https://rdf.metanetx.org/chem/MNXM1108092
#
#                                                   VMH  \
# 0                                                None
# 1         https://identifiers.org/vmhmetabolite:ile_L
# 2                                                None
# 3   https://identifiers.org/vmhmetabolite:HC00342;...
# 4           https://identifiers.org/vmhmetabolite:3pg
# 5        https://identifiers.org/vmhmetabolite:raffin
# 6   https://identifiers.org/vmhmetabolite:acgam6p;...
# 7                                                None
# 8        https://identifiers.org/vmhmetabolite:2ddg6p
# 9      https://identifiers.org/vmhmetabolite:prostge1
# 10         https://identifiers.org/vmhmetabolite:etoh
#
#                                              Reactome  \
# 0                                                None
# 1   https://identifiers.org/reactome:R-ALL-113537;...
# 2                                                None
# 3                                                None
# 4   https://identifiers.org/reactome:R-ALL-29728; ...
# 5                                                None
# 6       https://identifiers.org/reactome:R-ALL-449703
# 7                                                None
# 8                                                None
# 9   https://identifiers.org/reactome:R-ALL-879519;...
# 10  https://identifiers.org/reactome:R-ALL-113748;...
#
#                                           SwissLipids  \
# 0                                                None
# 1                                                None
# 2   https://identifiers.org/SLM:000389951; https:/...
# 3                                                None
# 4   https://identifiers.org/SLM:000489958; https:/...
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9   https://identifiers.org/SLM:000390038; https:/...
# 10  https://identifiers.org/SLM:000390046; https:/...
#
#                                              EnviPath  \
# 0                                                None
# 1                                                None
# 2   https://envipath.org/package/32de3cf4-e3e6-416...
# 3   https://envipath.org/package/32de3cf4-e3e6-416...
# 4   https://envipath.org/package/650babc9-9d68-4b7...
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10  https://envipath.org/package/32de3cf4-e3e6-416...
#
#                                     Extra Identifiers
# 0   http://bigg.ucsd.edu/universal/metabolites/2ma...
# 1   http://bigg.ucsd.edu/universal/metabolites/M_i...
# 2   http://bigg.ucsd.edu/universal/metabolites/M_o...
# 3   http://bigg.ucsd.edu/universal/metabolites/HC0...
# 4   http://bigg.ucsd.edu/universal/metabolites/3pg...
# 5   http://bigg.ucsd.edu/universal/metabolites/M_r...
# 6   http://bigg.ucsd.edu/universal/metabolites/M_a...
# 7                 https://www.genome.jp/kegg/M_C14177
# 8   http://bigg.ucsd.edu/universal/metabolites/2dd...
# 9   http://bigg.ucsd.edu/universal/metabolites/M_p...
# 10  http://bigg.ucsd.edu/universal/metabolites/M_e...

# %%
test_keggs.to_csv("kegg_mappingtest_results.csv", index=False)

# %% [markdown]
# Test performed well, 55 seconds to process ten metabolites and retrieve there related identifiers. Will manually expect to ensure accuracy of results, once validated, will run full test to cross-map all metabolites in the NOOR dataset.

# %% [markdown]
# ## Running Code on Entire dataset

# %%
all_results = [kegg_graphdb_single_row(kegg_id) for kegg_id in kegg_ids]

# %%
all_results
# Out:
# [{'KEGG_ID': 'C04752',
#   'CHEBI': 'https://identifiers.org/CHEBI:16629; https://identifiers.org/CHEBI:57841; http://purl.obolibrary.org/obo/CHEBI_11612; http://purl.obolibrary.org/obo/CHEBI_1194; http://purl.obolibrary.org/obo/CHEBI_11953; http://purl.obolibrary.org/obo/CHEBI_16629; http://purl.obolibrary.org/obo/CHEBI_19684; http://purl.obolibrary.org/obo/CHEBI_20308; http://purl.obolibrary.org/obo/CHEBI_57841',
#   'BiGG Metabolite': 'https://identifiers.org/bigg.metabolite:2mahmp',
#   'HMDB': 'https://identifiers.org/hmdb:HMDB

#   'BiGG Metabolite': 'https://identifiers.org/bigg.metabolite:acgam6p',
#   'HMDB': 'https://identifiers.org/hmdb:HMDB0001062; https://identifiers.org/hmdb:HMDB01062',
#   'KEGG Compound': 'https://identifiers.org/kegg.compound:C00357',
#   'MetaCyc': None,
#   'SABIORK': 'https://identifiers.org/sabiork.compound:1676; https://sabiork.h-its.org/newSearch?q=1676',
#   'SEED': 'https://identifiers.org/seed.compound:cpd00293; https://identifiers.org/seed.compound:cpd33963; https://modelseed.org/biochem/compounds/M_cpd00293; https://modelseed.org/biochem/compounds/M_cpd33963; https://modelseed.org/biochem/compounds/cpd00293; https://modelseed.org/biochem/compounds/cpd33963',
#   'MNX': 'https://rdf.metanetx.org/chem/MNXM1365474',
#   'VMH': 'https://identifiers.org/vmhmetabolite:acgam6p; https://identifiers.org/vmhmetabolite:acglc13galacglcgal14acglcgalgluside_hs',
#   'Reactome': 'https://identifiers.org/reactome:R-ALL-449703',
#   'SwissLipids': None,
#   'EnviPath': None,
#   'Extra Identifiers': 'http://bigg.ucsd.edu/universal/metabolites/M_acgam6p; http://bigg.ucsd.edu/universal/metabolites/acgam6p; https://www.genome.jp/kegg/M_C00357; https://reactome.org/content/detail/R-ALL-449703; https://vmh.life/#metabolite/acgam6p; https://vmh.life/#metabolite/acglc13galacglcgal14acglcgalgluside_hs'},
#  {'KEGG_ID': 'C14177',
#   'CHEBI': 'https://identifiers.org/CHEBI:16585; https://identifiers.org/CHEBI:57825; http://purl.obolibrary.org/obo/CHEBI_14526; http://purl.obolibrary.org/obo/CHEBI_16585; http://purl.obolibrary.org/obo/CHEBI_25071; http://purl.obolibrary.org/obo/CHEBI_57825; http://purl.obolibrary.org/obo/CHEBI_6516',
#   'BiGG Metabolite': None,
#   'HMDB': None,
#   'KEGG Compound': 'https://identifiers.org/kegg.compound:C14177',
#   'MetaCyc': None,
#   'SABIORK': None,
#   'SEED': 'https://identifiers.org/seed.compound:cpd09876; https://modelseed.org/biochem/compounds/M_cpd09876; https://modelseed.org/biochem/compounds/cpd09876',
#   'MNX': 'https://rdf.metanetx.org/chem/MNXM1376409',
#   'VMH': None,
#   'Reactome': None,
#   'SwissLipids': None,
#   'EnviPath': None,
#   'Extra Identifiers': 'https://www.genome.jp/kegg/M_C14177'},
#  {'KEGG_ID': 'C04442',
#   'CHEBI': 'https://identifiers.org/CHEBI:15925; https://identifiers.org/CHEBI:57569; http://purl.obolibrary.org/obo/CHEBI_1051; http://purl.obolibrary.org/obo/CHEBI_11543; http://purl.obolibrary.org/obo/CHEBI_11551; http://purl.obolibrary.org/obo/CHEBI_12227; http://purl.obolibrary.org/obo/CHEBI_15925; http://purl.obolibrary.org/obo/CHEBI_19522; http://purl.obolibrary.org/obo/CHEBI_57569',
#   'BiGG Metabolite': 'https://identifiers.org/bigg.metabolite:2ddg6p',
#   'HMDB': 'https://identifiers.org/hmdb:HMDB0001376; https://identifiers.org/hmdb:HMDB01376',
#   'KEGG Compound': 'https://identifiers.org/kegg.compound:C04442',
#   'MetaCyc': None,
#   'SABIORK': 'https://identifiers.org/sabiork.compound:1812; https://sabiork.h-its.org/newSearch?q=1812',
#   'SEED': 'https://identifiers.org/seed.compound:cpd02711; https://modelseed.org/biochem/compounds/M_cpd02711; https://modelseed.org/biochem/compounds/cpd02711',
#   'MNX': 'https://rdf.metanetx.org/chem/MNXM1377059',
#   'VMH': 'https://identifiers.org/vmhmetabolite:2ddg6p',
#   'Reactome': None,
#   'SwissLipids': None,
#   'EnviPath': None,
#   'Extra Identifiers': 'http://bigg.ucsd.edu/universal/metabolites
https://identifiers.org/envipath:650babc9-9d68-4b73-9332-11972ca26f7b/compound/abed9fe0-f79d-499e-ad45-656e5927abdb; https://www.genome.jp/kegg/M_C00013; https://biocyc.org/compound?id=PPI; https://biocyc.org/compound?id=PYROPHOSPHATE-GROUP; https://reactome.org/content/detail/R-ALL-111294; https://reactome.org/content/detail/R-ALL-113541; https://reactome.org/content/detail/R-ALL-113542; https://reactome.org/content/detail/R-ALL-114654; https://reactome.org/content/detail/R-ALL-159450; https://reactome.org/content/detail/R-ALL-2046049; https://reactome.org/content/detail/R-ALL-389593; https://reactome.org/content/detail/R-ALL-6806656; https://vmh.life/#metabolite/ppi'},
#  {'KEGG_ID': 'C03149',
#   'CHEBI': 'https://identifiers.org/CHEBI:16621; https://identifiers.org/CHEBI:57838; http://purl.obolibrary.org/obo/CHEBI_12614; http://purl.obolibrary.org/obo/CHEBI_16621; http://purl.obolibrary.org/obo/CHEBI_21782; http://purl.obolibrary.org/obo/CHEBI_57838; http://purl.obolibrary.org/obo/CHEBI_7334',
#   'BiGG Metabolite': None,
#   'HMDB': None,
#   'KEGG Compound': 'https://identifiers.org/kegg.compound:C03149',
#   'MetaCyc': 'https://identifiers.org/metacyc.compound:CPD-12603',
#   'SABIORK': None,
#   'SEED': 'https://identifiers.org/seed.compound:cpd02015; https://modelseed.org/biochem/compounds/M_cpd02015; https://modelseed.org/biochem/compounds/cpd02015',
#   'MNX': 'https://rdf.metanetx.org/chem/MNXM5241',
#   'VMH': None,
#   'Reactome': None,
#   'SwissLipids': None,
#   'EnviPath': None,
#   'Extra Identifiers': 'https://www.genome.jp/kegg/M_C03149; https://biocyc.org/compound?id=CPD-12603'},
#  {'KEGG_ID': 'C01653',
#   'CHEBI': 'https://identifiers.org/CHEBI:29183; http://purl.obolibrary.org/obo/CHEBI_10694; http://purl.obolibrary.org/obo/CHEBI_15191; http://purl.obolibrary.org/obo/CHEBI_29183',
#   'BiGG Metabolite': 'https://identifiers.org/bigg.metabolite:trnaval',
#   'HMDB': None,
#   'KEGG Compound': 'https://identifiers.org/kegg.compound:C01653',
#   'MetaCyc': 'https://identifiers.org/metacyc.compound:VAL-tRNAs',
#   'SABIORK': None,
#   'SEED': 'https://identifiers.org/seed.compound:cpd11924; https://identifiers.org/seed.compound:cpd28318; https://modelseed.org/biochem/compounds/M_cpd11924; https://modelseed.org/biochem/compounds/M_cpd28318; https://modelseed.org/biochem/compounds/cpd11924; https://modelseed.org/biochem/compounds/cpd28318',
#   'MNX': 'https://rdf.metanetx.org/chem/MNXM90885',
#   'VMH': None,
#   'Reactome': None,
#   'SwissLipids': None,
#   'EnviPath': None,
#   'Extra Identifiers': 'http://bigg.ucsd.edu/universal/metabolites/M_trnaval; http://bigg.ucsd.edu/universal/metabolites/trnaval; https://www.genome.jp/kegg/M_C01653; https://biocyc.org/compound?id=VAL-tRNAs'},
#  {'KEGG_ID': 'C03167',
#   'CHEBI': 'https://identifiers.org/CHEBI:18124; https://identifiers.org/CHEBI:58383; http://purl.obolibrary.org/obo/CHEBI_11653; http://purl.obolibrary.org/obo/CHEBI_14823; http://purl.obolibrary.org/obo/CHEBI_18124; http://purl.obolibrary.org/obo/CHEBI_26070; http://purl.obolibrary.org/obo/CHEBI_45088; http://purl.obolibrary.org/obo/CHEBI_58383; http://purl.obolibrary.org/obo/CHEBI_8155',
#   'BiGG Metabolite': 'https://identifiers.org/bigg.metabolite:Pald',
#   'HMDB': 'https://identifiers.org/hmdb:HMDB0256485',
#   'KEGG Compound': 'https://identifiers.org/kegg.compound:C03167',
#   'MetaCyc': 'https://identifiers.org/metacyc.compound:CPD-551',
#   'SABIORK': 'https://identifiers.org/sabiork.compound:2686; https://sabiork.h-its.org/newSearch?q=2686',
#   'SEED': 'https://identifiers.org/seed.compound:cpd02024; https://modelseed.org/biochem/compounds/M_cpd02024; https://modelseed.org/biochem/compounds/cpd02024',
#   'MNX': 'https://rdf.metanetx.org/chem/MNXM803',
#   'VMH': 'https://identifiers.org/vmhmetabolite:ppaca',
#   'Reactome': None,
#   'SwissLipids': None,
#   'EnviPath': None,
#   'Extra Identifiers': 'http://bigg.ucsd.edu/universal/metabolites/M_Pald; http://bigg.ucsd.edu/universal/metabolites/Pald; https://www.genome.jp/kegg/M_C03167; https://biocyc.org/compound?id=CPD-551; https://vmh.life/#metabolite/ppaca'},
#  {'KEGG_ID': 'C00942',
#   'CHEBI': 'http://purl.obolibrary.org/obo/CHEBI
http://www.lipidmaps.org/data/LMSDRecord.php?LMID=LMFA01100048; https://biocyc.org/compound?id=LEU; https://reactome.org/content/detail/R-ALL-113580; https://reactome.org/content/detail/R-ALL-29588; https://reactome.org/content/detail/R-ALL-351964; https://vmh.life/#metabolite/leu_L'},
#  {'KEGG_ID': 'C00294',
#   'CHEBI': 'https://identifiers.org/CHEBI:17596; http://purl.obolibrary.org/obo/CHEBI_14456; http://purl.obolibrary.org/obo/CHEBI_17596; http://purl.obolibrary.org/obo/CHEBI_24841; http://purl.obolibrary.org/obo/CHEBI_44407; http://purl.obolibrary.org/obo/CHEBI_5927',
#   'BiGG Metabolite': 'https://identifiers.org/bigg.metabolite:ins',
#   'HMDB': 'https://identifiers.org/hmdb:HMDB0000195; https://identifiers.org/hmdb:HMDB00195; https://identifiers.org/hmdb:HMDB0247301',
#   'KEGG Compound': 'https://identifiers.org/kegg.compound:C00294',
#   'MetaCyc': 'https://identifiers.org/metacyc.compound:INOSINE',
#   'SABIORK': 'https://identifiers.org/sabiork.compound:1868; https://sabiork.h-its.org/newSearch?q=1868',
#   'SEED': 'https://identifiers.org/seed.compound:cpd00246; https://modelseed.org/biochem/compounds/M_cpd00246; https://modelseed.org/biochem/compounds/cpd00246',
#   'MNX': 'https://rdf.metanetx.org/chem/MNXM1103335',
#   'VMH': 'https://identifiers.org/vmhmetabolite:ins',
#   'Reactome': 'https://identifiers.org/reactome:R-ALL-727739; https://identifiers.org/reactome:R-ALL-83921; https://identifiers.org/reactome:R-ALL-83927',
#   'SwissLipids': None,
#   'EnviPath': None,
#   'Extra Identifiers': 'http://bigg.ucsd.edu/universal/metabolites/M_ins; http://bigg.ucsd.edu/universal/metabolites/ins; https://identifiers.org/kegg.drug:D00054; https://www.genome.jp/kegg/M_C00294; https://www.genome.jp/kegg/drug/D00054; https://www.genome.jp/kegg/drug/M_D00054; https://biocyc.org/compound?id=INOSINE; https://reactome.org/content/detail/R-ALL-727739; https://reactome.org/content/detail/R-ALL-83921; https://reactome.org/content/detail/R-ALL-83927; https://vmh.life/#metabolite/ins'},
#  {'KEGG_ID': 'C03017',
#   'CHEBI': 'https://identifiers.org/CHEBI:192090; https://identifiers.org/CHEBI:28867; https://identifiers.org/CHEBI:53210; http://purl.obolibrary.org/obo/CHEBI_192090; http://purl.obolibrary.org/obo/CHEBI_21972; http://purl.obolibrary.org/obo/CHEBI_28867; http://purl.obolibrary.org/obo/CHEBI_53210; http://purl.obolibrary.org/obo/CHEBI_7701; http://purl.obolibrary.org/obo/CHEBI_85465',
#   'BiGG Metabolite': 'https://identifiers.org/bigg.metabolite:pcrn',
#   'HMDB': 'https://identifiers.org/hmdb:HMDB0000824; https://identifiers.org/hmdb:HMDB0062514; https://identifiers.org/hmdb:HMDB00824; https://identifiers.org/hmdb:HMDB62514',
#   'KEGG Compound': 'https://identifiers.org/kegg.compound:C03017',
#   'MetaCyc': 'https://identifiers.org/metacyc.compound:CPD-19737; https://identifiers.org/metacyc.compound:CPD-25633',
#   'SABIORK': 'https://identifiers.org/sabiork.compound:2626; https://sabiork.h-its.org/newSearch?q=2626',
#   'SEED': 'https://identifiers.org/seed.compound:cpd01934; https://identifiers.org/seed.compound:cpd35355; https://modelseed.org/biochem/compounds/M_cpd01934; https://modelseed.org/biochem/compounds/M_cpd35355; https://modelseed.org/biochem/compounds/cpd01934; https://modelseed.org/biochem/compounds/cpd35355',
#   'MNX': 'https://rdf.metanetx.org/chem/MNXM1105887',
#   'VMH': 'https://identifiers.org/vmhmetabolite:HC02149; https://identifiers.org/vmhmetabolite:pcrn',
#   'Reactome': 'https://identifiers.org/reactome:R-ALL-390274',
#   'SwissLipids': 'https://identifiers.org/SLM:000390084; https://www.swisslipids.org/#/entity/SLM:000390084',
#   'EnviPath': None,
# ...
#  {'KEGG_ID': 'C00233',
#   'CHEBI': 'https://identifiers.org/CHEBI:17865; https://identifiers.org/CHEBI:48430; http://purl.obolibrary.org/obo/CHEBI_12020; http://purl.obolibrary.org/obo/CHEBI_17865; http://purl.obolibrary.org/obo/CHEBI_1891; http://purl.obolibrary.org/obo/CHEBI_20438; http://purl.obolibrary.org/obo/CHEBI_41619; http://purl.obolibrary.org/obo/CHEBI_48430',
#   'BiGG Metabolite': 'https://identifiers.org/bigg.metabolite:4mop',
#   'HMDB': 'https://identifiers.org/hmdb:HMDB0000695; https://identifiers.org/hmdb:HMDB0000762; https://identifiers.org/hmdb:HMDB00695; https://identifiers.org/hmdb:HMDB00762',
#   'KEGG Compound': 'https://identifiers.org/kegg.compound:C00233',
#   'MetaCyc': 'https://identifiers.org/metacyc.compound:2K-4CH3-PENTANOATE',
#   'SABIORK': 'https://identifiers.org/sabiork.compound:1985; https://sabiork.h-its.org/newSearch?q=1985',
#   'SEED': 'https://identifiers.org/seed.compound:cpd00200; https://modelseed.org/biochem/compounds/M_cpd00200; https://modelseed.org/biochem/compounds/cpd00200',
#   'MNX': 'https://rdf.metanetx.org/chem/MNXM404',
#   'VMH': 'https://identifiers.org/vmhmetabolite:4mop',
#   'Reactome': 'https://identifiers.org/reactome:R-ALL-113598; https://identifiers.org/reactome:R-ALL-70701',
#   'SwissLipids': None,
#   'EnviPath': 'https://envipath.org/package/650babc9-9d68-4b73-9332-11972ca26f7b/compound/5e871a01-a329-4d3e-b004-4f31bc650c70',
#   'Extra Identifiers': 'http://bigg.ucsd.edu/universal/metabolites/4mop; http://bigg.ucsd.edu/universal/metabolites/M_4mop; https://identifiers.org/envipath:650babc9-9d68-4b73-9332-11972ca26f7b/compound/5e871a01-a329-4d3e-b004-4f31bc650c70; https://www.genome.jp/kegg/M_C00233; https://biocyc.org/compound?id=2K-4CH3-PENTANOATE; https://reactome.org/content/detail/R-ALL-113598; https://reactome.org/content/detail/R-ALL-70701; https://vmh.life/#metabolite/4mop'},
#  {'KEGG_ID': 'C01904',
#   'CHEBI': 'https://identifiers.org/CHEBI:18333; http://purl.obolibrary.org/obo/CHEBI_12912; http://purl.obolibrary.org/obo/CHEBI_18333; http://purl.obolibrary.org/obo/CHEBI_20916; http://purl.obolibrary.org/obo/CHEBI_4105',
#   'BiGG Metabolite': None,
#   'HMDB': 'https://identifiers.org/hmdb:HMDB0000568; https://identifiers.org/hmdb:HMDB00568',
#   'KEGG Compound': 'https://identifiers.org/kegg.compound:C01904',
#   'MetaCyc': None,
#   'SABIORK': 'https://identifiers.org/sabiork.compound:2333; https://sabiork.h-its.org/newSearch?q=2333',
#   'SEED': 'https://identifiers.org/seed.compound:cpd01307; https://modelseed.org/biochem/compounds/M_cpd01307; https://modelseed.org/biochem/compounds/cpd01307',
#   'MNX': 'https://rdf.metanetx.org/chem/MNXM1363545',
#   'VMH': 'https://identifiers.org/vmhmetabolite:abt_D',
#   'Reactome': None,
#   'SwissLipids': None,
#   'EnviPath': None,
#   'Extra Identifiers': 'https://www.genome.jp/kegg/M_C01904; https://vmh.life/#metabolite/abt_D'},
#  {'KEGG_ID': 'C00877',
#   'CHEBI': 'https://identifiers.org/CHEBI:15473; https://identifiers.org/CHEBI:57332; http://purl.obolibrary.org/obo/CHEBI_14031; http://purl.obolibrary.org/obo/CHEBI_14032; http://purl.obolibrary.org/obo/CHEBI_15473; http://purl.obolibrary.org/obo/CHEBI_23408; http://purl.obolibrary.org/obo/CHEBI_3928; http://purl.obolibrary.org/obo/CHEBI_41612; http://purl.obolibrary.org/obo/CHEBI_57332',
#   'BiGG Metabolite': 'https://identifiers.org/bigg.metabolite:b2coa',
#   'HMDB': 'https://identifiers.org/hmdb:HMDB0002009; https://identifiers.org/hmdb:HMDB0059627; https://identifiers.org/hmdb:HMDB02009; https://identifiers.org/hmdb:HMDB59627',
#   'KEGG Compound': 'https://identifiers.org/kegg.compound:C00877',
#   'MetaCyc': 'https://identifiers.org/metacyc.compound:CROTONYL-COA',
#   'SABIORK': None,
#   'SEED': 'https://identifiers.org/seed.compound:cpd00650; https://modelseed.org/biochem/compounds/M_cpd00650; https://modelseed.org/biochem/compounds/cpd00650',
#   'MNX': 'https://rdf.metanetx.org/chem/MNXM1364925',
#   'VMH': 'https://identifiers.org/vmhmetabolite:b2coa',
#   'Reactome': 'https://identifiers.org/reactome:R-ALL-71045; https://identifiers.org/reactome:R-ALL-77313',
#   'SwissLipids': 'https://identifiers.org/SLM:000001036; https://www.swisslipids.org/#/entity/SLM:000001036',
#   'EnviPath': 'https://envipath.org/package/32de3cf4-e3e6-4168-956e-32fa5ddb0ce1/compound/c0e5f008-6d8b-4b94-a265-03d19ff197f4; https://envipath.org/package/650babc9-9d68-4b73-9332-11972ca26f7b/compound/b84d64f0-9635-4e4a-ab40-722122d1d982',
#   'Extra Identifiers': 'http://bigg.ucsd.edu/universal/metabolites/M_b2coa; http://bigg.ucsd.edu/universal/metabolites/b2coa; https://identifiers.org/envipath:32de3cf4-e3e6-4168-956e-32fa5ddb0ce1/compound/c0e5f008-6d8b-4b94-a265-03d19ff197f4; https://identifiers.org/envipath:650babc9-9d68-4b73-9332-11972ca26f7b/compound
#   'HMDB': None,
#   'KEGG Compound': 'https://identifiers.org/kegg.compound:C04105; https://identifiers.org/kegg.compound:C14610',
#   'MetaCyc': 'https://identifiers.org/metacyc.compound:CPD-15124; https://identifiers.org/metacyc.compound:CPD-741',
#   'SABIORK': 'https://identifiers.org/sabiork.compound:7082; https://sabiork.h-its.org/newSearch?q=7082',
#   'SEED': 'https://identifiers.org/seed.compound:cpd02536; https://identifiers.org/seed.compound:cpd19162; https://modelseed.org/biochem/compounds/M_cpd02536; https://modelseed.org/biochem/compounds/M_cpd19162; https://modelseed.org/biochem/compounds/cpd02536; https://modelseed.org/biochem/compounds/cpd19162',
#   'MNX': 'https://rdf.metanetx.org/chem/MNXM726703',
#   'VMH': 'https://identifiers.org/vmhmetabolite:25d5o2a; https://identifiers.org/vmhmetabolite:mucl',
#   'Reactome': None,
#   'SwissLipids': None,
#   'EnviPath': None,
#   'Extra Identifiers': 'https://www.genome.jp/kegg/C14610; https://www.genome.jp/kegg/M_C04105; https://www.genome.jp/kegg/M_C14610; https://biocyc.org/compound?id=CPD-15124; https://biocyc.org/compound?id=CPD-741; https://vmh.life/#metabolite/25d5o2a; https://vmh.life/#metabolite/mucl'},
#  {'KEGG_ID': 'C02588',
#   'CHEBI': 'https://identifiers.org/CHEBI:17616; http://purl.obolibrary.org/obo/CHEBI_12784; http://purl.obolibrary.org/obo/CHEBI_17616; http://purl.obolibrary.org/obo/CHEBI_26542; http://purl.obolibrary.org/obo/CHEBI_8819',
#   'BiGG Metabolite': None,
#   'HMDB': 'https://identifiers.org/hmdb:HMDB0003648; https://identifiers.org/hmdb:HMDB03648',
#   'KEGG Compound': 'https://identifiers.org/kegg.compound:C02588',
#   'MetaCyc': 'https://identifiers.org/metacyc.compound:CHOCOLA_A',
#   'SABIORK': 'https://identifiers.org/sabiork.compound:2455; https://sabiork.h-its.org/newSearch?q=2455',
#   'SEED': 'https://identifiers.org/seed.compound:cpd01691; https://modelseed.org/biochem/compounds/M_cpd01691; https://modelseed.org/biochem/compounds/cpd01691',
#   'MNX': 'https://rdf.metanetx.org/chem/MNXM1137721',
#   'VMH': None,
#   'Reactome': 'https://identifiers.org/reactome:R-ALL-2534404; https://identifiers.org/reactome:R-ALL-2534405; https://identifiers.org/reactome:R-ALL-2534407; https://identifiers.org/reactome:R-ALL-2864097; https://identifiers.org/reactome:R-ALL-975591',
#   'SwissLipids': 'https://identifiers.org/SLM:000000509; https://www.swisslipids.org/#/entity/SLM:000000509',
#   'EnviPath': None,
#   'Extra Identifiers': 'https://identifiers.org/kegg.drug:D00164; https://www.genome.jp/kegg/M_C02588; https://www.genome.jp/kegg/drug/D00164; https://www.genome.jp/kegg/drug/M_D00164; https://identifiers.org/lipidmaps:LMPR01090013; http://www.lipidmaps.org/data/LMSDRecord.php?LMID=LMPR01090013; https://biocyc.org/compound?id=CHOCOLA_A; https://reactome.org/content/detail/R-ALL-2534404; https://reactome.org/content/detail/R-ALL-2534405; https://reactome.org/content/detail/R-ALL-2534407; https://reactome.org/content/detail/R-ALL-2864097; https://reactome.org/content/detail/R-ALL-975591'},
#  {'KEGG_ID': 'C03127',
#   'CHEBI': None,
#   'BiGG Metabolite': None,
#   'HMDB': None,
#   'KEGG Compound': 'https://identifiers.org/kegg.compound:C03127',
#   'MetaCyc': None,
#   'SABIORK': None,
#   'SEED': None,
#   'MNX': 'https://rdf.metanetx.org/chem/MNXM741223',
#   'VMH': None,
#   'Reactome': None,
#   'SwissLipids': None,
#   'EnviPath': None,
#   'Extra Identifiers': 'https://www.genome.jp/kegg/M_C03127'},
#  {'KEGG_ID': 'C00041',
#   'CHEBI': 'http://purl.obolibrary.org/obo/CHEBI_57972; https://identifiers.org/CHEBI:16977; https://identifiers.org/CHEBI:229589; https://identifiers.org/CHEBI:32431; https://identifiers.org/CHEBI:32432; https://identifiers.org/CHEBI:57972; https://identifiers.org/CHEBI:76050; http://purl.obolibrary.org/obo/CHEBI_13069; http://purl.obolibrary.org/obo/CHEBI_16977; http://purl.obolibrary.org/obo/CHEBI_21216; http://purl.obolibrary.org/obo/CHEBI_229589; http://purl.obolibrary.org/obo/CHEBI_32431; http://purl.obolibrary.org/obo/CHEBI_32432; http://purl.obolibrary.org/obo/CHEBI_40734; http://purl.obolibrary.org/obo/CHEBI_40735; http://purl.obolibrary.org/obo/CHEBI_46308; http://purl.obolibrary.org/obo/CHEBI_6171; http://purl.obolibrary.org/obo/CHEBI_76050',
#   'BiGG Metabolite': 'https://identifiers.org/bigg.metabolite:ala__L',
#   'HMDB': 'https://identifiers.org/hmdb:HMDB0000161; https://identifiers.org/hmdb:HMDB00161',
#   'KEGG Compound': 'https://identifiers.org/kegg.compound:C00041',
#   'MetaCyc': 'https://identifiers.org/metacyc.compound:L-ALPHA-ALANINE',
#   'SABIORK': 'https://identifiers.org/sabiork.compound:67; https://sabiork.h-its.org/newSearch?q=67',
#   'SEED': 'https://identifiers.org/seed.compound:cpd00035; https://modelseed.org/biochem/compounds/M_cpd00035; https://modelseed.org/biochem/compounds/cpd00035',
#   'MNX': 'https://rdf.metanetx.org/chem/MNXM1105732',
#   'VMH': 'https://identifiers.org/vmhmetabolite:ala_L',
#   'Reactome': 'https://identifiers.org/reactome:R-ALL-29432; https://identifiers.org/reactome:R-ALL-352036; https://identifiers.org/reactome:R-ALL-379697; https://identifiers.org/reactome:R-ALL-389664',
#   'SwissLipids': None,
#   'EnviPath': 'https://envipath.org/package/650babc9-9d68-4b73-9332-11972ca26f7b/compound/1aad160f-1c5e-48e0-9473-6305321b31ed',
#   'Extra Identifiers': 'http://bigg.ucsd.edu/universal/metabolites/M_ala__L; http://bigg.ucsd.edu/universal/metabolites/ala-L; http://bigg.ucsd.edu/universal/metabolites/ala__L; https://identifiers.org/envipath:650babc9-9d68-4b73-9332-11972ca26f7b/compound/1aad160f-1c5e-48e0-9473-6305321b31ed; https://identifiers.org/kegg.drug:D00012; https://www.genome.jp/kegg/M_C00041; https://www.genome.jp/kegg/drug/D00012; https://www.genome.jp/kegg/drug/M_D00012; https://biocyc.org/compound?id=L-ALPHA-ALANINE; https://reactome.org/content/detail/R-ALL-29432; https://reactome.org/content/detail/R-ALL-352036; https://reactome.org/content/detail/R-ALL-379697; https://reactome.org/content/detail/R-ALL-389664; https://vmh.life/#metabolite/ala_L'},
#  {'KEGG_ID': 'C00137',
#   'CHEBI': 'https://identifiers.org/CHEBI:17268; http://purl.obolibrary.org/obo/CHEBI_10601; http://purl.obolibrary.org/obo/CHEBI_12826; http://purl.obolibrary.org/obo/CHEBI_12831; http://purl.obolibrary.org/obo/CHEBI_17268; http://purl.obolibrary.org/obo/CHEBI_25451; http://purl.obolibrary.org/obo/CHEBI_43559',
#   'BiGG Metabolite': 'https://identifiers.org/bigg.metabolite:inost',
#   'HMDB': 'https://identifiers.org/hmdb:HMDB0000211; https://identifiers.org/hmdb:HMDB0002256; https://identifiers.org/hmdb:HMDB00211; https://identifiers.org/hmdb:HMDB02256',
#   'KEGG Compound': 'https://identifiers.org/kegg.compound:C00137',
#   'MetaCyc': None,
#   'SABIORK': None,
#   'SEED': 'https://identifiers.org/seed.compound:cpd00121; https://modelseed.org/biochem/compounds/M_cpd00121; https://modelseed.org/biochem/compounds/cpd00121',
#   'MNX': 'https://rdf.metanetx.org/chem/MNXM1365428',
#   'VMH': 'https://identifiers.org/vmhmetabolite:inost',
#   'Reactome': 'https://identifiers.org/reactome:R-ALL-426910; https://identifiers.org/reactome:R-ALL-429130',
#   'SwissLipids': None,
#   'EnviPath': None,
#   'Extra Identifiers': 'http://bigg.ucsd.edu/universal/metabolites/M_inost; http://bigg.ucsd.edu/universal/metabolites/inost; https://identifiers.org/kegg.drug:D08079; https://www.genome.jp/kegg/M_C00137; https://www.genome.jp/kegg/drug/D08079; https://www.genome.jp/kegg/drug/M_D08079; https://reactome.org/content/detail/R-ALL-426910; https://reactome.org/content/detail/R-ALL-429130; https://vmh.life/#metabolite/inost'}]

# %%
def clean_multiple_uris(uris):
    """
    Cleans semicolon-separated URIs in a single cell.
    For example:
    'https://identifiers.org/bigg.metabolite:2mahmp; https://identifiers.org/seed:cpd02894'
    -> 'bigg.metabolite:2mahmp; seed:cpd02894'
    """
    if isinstance(uris, str):  # Ensure the value is a string
        # Split by the delimiter, clean each URI, and join them back
        return "; ".join([uri.split("/")[-1] for uri in uris.split("; ")])
    return uris  # Return as-is if not a string

# %%
mapped_identifiers = pd.DataFrame(all_results)

# %%
# Apply the cleaning function to all columns except KEGG_ID
for col in mapped_identifiers.columns:
    if col != "KEGG_ID":  # Skip cleaning for the KEGG_ID column
        mapped_identifiers[col] = mapped_identifiers[col].apply(clean_multiple_uris)

print(mapped_identifiers)
# Out:
#     KEGG_ID                                              CHEBI  \
# 0    C04752  CHEBI:16629; CHEBI:57841; CHEBI_11612; CHEBI_1...
# 1    C00407  CHEBI:17191; CHEBI:32604; CHEBI:32605; CHEBI:3...
# 2    C01545  CHEBI:17935; CHEBI_11268; CHEBI_17935; CHEBI_2...
# 3    C00417  CHEBI:16383; CHEBI:32805; CHEBI_10482; CHEBI_1...
# 4    C00197  CHEBI:17050; CHEBI:17794; CHEBI:57998; CHEBI:5...
# ..      ...                                                ...
# 598  C04105  CHEBI:18080; CHEBI:48068; CHEBI:58372; CHEBI:5...
# 599  C02588  CHEBI:17616; CHEBI_12784; CHEBI_17616; CHEBI_2...
# 600  C03127                                               None
# 601  C00041  CHEBI_57972; CHEBI:16977; CHEBI:229589; CHEBI:...
# 602  C00137  CHEBI:17268; CHEBI_10601; CHEBI_12826; CHEBI_1...
#
#                                        BiGG Metabolite  \
# 0                               bigg.metabolite:2mahmp
# 1                               bigg.metabolite:ile__L
# 2                                bigg.metabolite:octal
# 3    bigg.metabolite:HC00342; bigg.metabolite:acon;...
# 4                                  bigg.metabolite:3pg
# ..                                                 ...
# 598                                               None
# 599                                               None
# 600                                               None
# 601                             bigg.metabolite:ala__L
# 602                              bigg.metabolite:inost
#
#                                                   HMDB  \
# 0                                     hmdb:HMDB0304168
# 1    hmdb:HMDB0000172; hmdb:HMDB00172; hmdb:HMDB003...
# 2                     hmdb:HMDB0001140; hmdb:HMDB01140
# 3    hmdb:HMDB0000072; hmdb:HMDB0000461; hmdb:HMDB0...
# 4    hmdb:HMDB0000807; hmdb:HMDB0060180; hmdb:HMDB0...
# ..                                                 ...
# 598                                               None
# 599                   hmdb:HMDB0003648; hmdb:HMDB03648
# 600                                               None
# 601                   hmdb:HMDB0000161; hmdb:HMDB00161
# 602  hmdb:HMDB0000211; hmdb:HMDB0002256; hmdb:HMDB0...
#
#                                   KEGG Compound  \
# 0                          kegg.compound:C04752
# 1    kegg.compound:C00407; kegg.compound:C16434
# 2                          kegg.compound:C01545
# 3                          kegg.compound:C00417
# 4    kegg.compound:C00197; kegg.compound:C00597
# ..                                          ...
# 598  kegg.compound:C04105; kegg.compound:C14610
# 599                        kegg.compound:C02588
# 600                        kegg.compound:C03127
# 601                        kegg.compound:C00041
# 602                        kegg.compound:C00137
#
#                                                MetaCyc  \
# 0    metacyc.compound:AMINO-HYDROXYMETHYL-METHYLPYR...
# 1    metacyc.compound:CPD-12149; metacyc.compound:C...
# 2                             metacyc.compound:CPD-371
# 3                       metacyc.compound:CIS-ACONITATE
# 4                                 metacyc.compound:G3P
# ..                                                 ...
# 598  metacyc.compound:CPD-15124; metacyc.compound:C...
# 599                         metacyc.compound:CHOCOLA_A
# 600                                               None
# 601                   metacyc.compound:L-ALPHA-ALANINE
# 602                                               None
#
#                                                SABIORK  \
# 0              sabiork.compound:1832; newSearch?q=1832
# 1    sabiork.compound:23116; sabiork.compound:70; n...
# 2              sabiork.compound:5652; newSearch?q=5652
# 3              sabiork.compound:2043; newSearch?q=2043
# 4    sabiork.compound:21216; sabiork.compound:30; n...
# ..                                                 ...
# 598            sabiork.compound:7082; newSearch?q=7082
# 599            sabiork.compound:2455; newSearch?q=2455
# 600                                               None
# 601                sabiork.compound:67; newSearch?q=67
# 602                                               None
#
#                                                   SEED          MNX  \
# 0         seed.compound:cpd02894; M_cpd02894; cpd02894  MNXM1101289
# 1    seed.compound:cpd00322; seed.compound:cpd15139...  MNXM1366448
# 2    seed.compound:cpd01088; seed.compound:cpd15619...     MNXM2705
# 3         seed.compound:cpd00331; M_cpd00331; cpd00331  MNXM1092518
# 4    seed.compound:cpd00169; seed.compound:cpd30741...   MNXM727604
# ..                                                 ...          ...
# 598  seed.compound:cpd02536; seed.compound:cpd19162...   MNXM726703
# 599       seed.compound:cpd01691; M_cpd01691; cpd01691  MNXM1137721
# 600                                               None   MNXM741223
# 601       seed.compound:cpd00035; M_cpd00035; cpd00035  MNXM1105732
# 602       seed.compound:cpd00121; M_cpd00121; cpd00121  MNXM1365428
#
#                                              VMH  \
# 0                                           None
# 1                            vmhmetabolite:ile_L
# 2                                           None
# 3    vmhmetabolite:HC00342; vmhmetabolite:acon_C
# 4                              vmhmetabolite:3pg
# ..                                           ...
# 598    vmhmetabolite:25d5o2a; vmhmetabolite:mucl
# 599                                         None
# 600                                         None
# 601                          vmhmetabolite:ala_L
# 602                          vmhmetabolite:inost
#
#                                               Reactome  \
# 0                                                 None
# 1    reactome:R-ALL-113537; reactome:R-ALL-30102; r...
# 2                                                 None
# 3                                                 None
# 4         reactome:R-ALL-29728; reactome:R-ALL-6799493
# ..                                                 ...
# 598                                               None
# 599  reactome:R-ALL-2534404; reactome:R-ALL-2534405...
# 600                                               None
# 601  reactome:R-ALL-29432; reactome:R-ALL-352036; r...
# 602       reactome:R-ALL-426910; reactome:R-ALL-429130
#
#                       SwissLipids  \
# 0                            None
# 1                            None
# 2    SLM:000389951; SLM:000389951
# 3                            None
# 4    SLM:000489958; SLM:000489958
# ..                            ...
# 598                          None
# 599  SLM:000000509; SLM:000000509
# 600                          None
# 601                          None
# 602                          None
#
#                                               EnviPath  \
# 0                                                 None
# 1                                                 None
# 2    9dcb30dc-d751-4434-8d9c-68b4f5453145; 8421e286...
# 3                 643481e5-a35b-477e-8665-70f4dca66baa
# 4                 47064115-384f-43ee-b9e2-5e9d7aed5217
# ..                                                 ...
# 598                                               None
# 599                                               None
# 600                                               None
# 601               1aad160f-1c5e-48e0-9473-6305321b31ed
# 602                                               None
#
#                                      Extra Identifiers
# 0    2mahmp; M_2mahmp; M_C04752; compound?id=AMINO-...
# 1    M_ile__L; ile-L; ile__L; kegg.drug:D00065; C16...
# 2    M_octal; octal; 9dcb30dc-d751-4434-8d9c-68b4f5...
# 3    HC00342; M_HC00342; M_acon; M_acon_C; acon; ac...
# 4    3pg; M_3pg; 47064115-384f-43ee-b9e2-5e9d7aed52...
# ..                                                 ...
# 598  C14610; M_C04105; M_C14610; compound?id=CPD-15...
# 599  kegg.drug:D00164; M_C02588; D00164; M_D00164; ...
# 600                                           M_C03127
# 601  M_ala__L; ala-L; ala__L; 1aad160f-1c5e-48e0-94...
# 602  M_inost; inost; kegg.drug:D08079; M_C00137; D0...
#
# [603 rows x 14 columns]

# %%
# Remove the 'Extra Identifiers' column
mapped_identifiers = mapped_identifiers.drop(columns=["KEGG Compound"])

print(mapped_identifiers)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 2
#       1 # Remove the 'Extra Identifiers' column
# ----> 2 mapped_identifiers = mapped_identifiers.drop(columns=["KEGG Compound"])
#       4 print(mapped_identifiers)
#
# File ~/openTECRenv_sparql/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~/openTECRenv_sparql/lib/python3.12/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~/openTECRenv_sparql/lib/python3.12/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~/openTECRenv_sparql/lib/python3.12/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['KEGG Compound'] not found in axis"

# %%
mapped_identifiers.to_csv("openTECR_mapped_metabolites.csv", index=False)

# %% [markdown]
# ### Determining if any entries were not mapped

# %%
# Check for rows where all columns except KEGG_ID are empty
unmapped_kegg = mapped_identifiers[mapped_identifiers.drop(columns=["KEGG_ID"]).isnull().all(axis=1)]

# Count the number of unmapped KEGG IDs
num_unmapped = unmapped_kegg.shape[0]

print(f"Number of unmapped KEGG IDs: {num_unmapped}")
print("Unmapped KEGG IDs:")
print(unmapped_kegg)
# Out:
# Number of unmapped KEGG IDs: 0
# Unmapped KEGG IDs:
# Empty DataFrame
# Columns: [KEGG_ID, CHEBI, BiGG Metabolite, HMDB, MetaCyc, SABIORK, SEED, MNX, VMH, Reactome, SwissLipids, EnviPath, Extra Identifiers]
# Index: []
